# %% [markdown]
# <a href="https://colab.research.google.com/github/AmiriShavaki/KG-based-RAG-for-Multi-hop-QA/blob/main/src/Main_Pipeline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Proposed Method

# %% [markdown]
# ## Load the KG from Graph DB

# %% [markdown]
# ### Install langchain neo4j

# %%
# !pip install langchain neo4j openai wikipedia tiktoken langchain_openai langchain-community
# Out:
# Collecting langchain
#   Downloading langchain-0.3.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting neo4j
#   Downloading neo4j-5.25.0-py3-none-any.whl.metadata (5.7 kB)
# Collecting openai
#   Downloading openai-1.50.1-py3-none-any.whl.metadata (24 kB)
# Collecting wikipedia
#   Downloading wikipedia-1.4.0.tar.gz (27 kB)
#   Preparing metadata (setup.py) ... done
# Collecting tiktoken
#   Downloading tiktoken-0.7.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Collecting langchain_openai
#   Downloading langchain_openai-0.2.1-py3-none-any.whl.metadata (2.6 kB)
# Collecting langchain-community
#   Downloading langchain_community-0.3.1-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.0.35)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain) (3.10.5)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (4.0.3)
# Collecting langchain-core<0.4.0,>=0.3.6 (from langchain)
#   Downloading langchain_core-0.3.6-py3-none-any.whl.metadata (6.3 kB)
# Collecting langchain-text-splitters<0.4.0,>=0.3.0 (from langchain)
#   Downloading langchain_text_splitters-0.3.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting langsmith<0.2.0,>=0.1.17 (from langchain)
#   Downloading langsmith-0.1.129-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain) (1.26.4)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.9.2)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.32.3)
# Collecting tenacity!=8.4.0,<9.0.0,>=8.1.0 (from langchain)
#   Downloading tenacity-8.5.0-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: pytz in /usr/local/lib/python3.10/dist-packages (from neo4j) (2024.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai) (1.7.0)
# Collecting httpx<1,>=0.23.0 (from openai)
#   Downloading httpx-0.27.2-py3-none-any.whl.metadata (7.1 kB)
# Collecting jiter<1,>=0.4.0 (from openai)
#   Downloading jiter-0.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.6 kB)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai) (4.66.5)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.10/dist-packages (from openai) (4.12.2)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from wikipedia) (4.12.3)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.10/dist-packages (from tiktoken) (2024.9.11)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain-community)
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting pydantic-settings<3.0.0,>=2.4.0 (from langchain-community)
#   Downloading pydantic_settings-2.5.2-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.11.1)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (1.2.2)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Downloading marshmallow-3.22.0-py3-none-any.whl.metadata (7.2 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (2024.8.30)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->openai)
#   Downloading httpcore-1.0.5-py3-none-any.whl.metadata (20 kB)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<1,>=0.23.0->openai)
#   Downloading h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Collecting jsonpatch<2.0,>=1.33 (from langchain-core<0.4.0,>=0.3.6->langchain)
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.6->langchain) (24.1)
# Collecting orjson<4.0.0,>=3.9.14 (from langsmith<0.2.0,>=0.1.17->langchain)
#   Downloading orjson-3.10.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 kB 625.3 kB/s eta 0:00:00
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.23.4)
# Collecting python-dotenv>=0.21.0 (from pydantic-settings<3.0.0,>=2.4.0->langchain-community)
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (2.2.3)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain) (3.1.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->wikipedia) (2.6)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.6->langchain)
#   Downloading jsonpointer-3.0.0-py2.py3-none-any.whl.metadata (2.3 kB)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl.metadata (1.1 kB)
# Downloading langchain-0.3.1-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 7.1 MB/s eta 0:00:00
# Downloading neo4j-5.25.0-py3-none-any.whl (296 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.6/296.6 kB 16.4 MB/s eta 0:00:00
# Downloading openai-1.50.1-py3-none-any.whl (378 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 378.9/378.9 kB 21.3 MB/s eta 0:00:00
# Downloading tiktoken-0.7.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 36.5 MB/s eta 0:00:00
# Downloading langchain_openai-0.2.1-py3-none-any.whl (49 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 kB 3.6 MB/s eta 0:00:00
# Downloading langchain_community-0.3.1-py3-none-any.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 36.4 MB/s eta 0:00:00
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading httpx-0.27.2-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 5.2 MB/s eta 0:00:00
# Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 4.8 MB/s eta 0:00:00
# Downloading jiter-0.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (318 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 318.9/318.9 kB 13.9 MB/s eta 0:00:00
# Downloading langchain_core-0.3.6-py3-none-any.whl (399 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 399.9/399.9 kB 21.4 MB/s eta 0:00:00
# Downloading langchain_text_splitters-0.3.0-py3-none-any.whl (25 kB)
# Downloading langsmith-0.1.129-py3-none-any.whl (292 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 292.2/292.2 kB 17.2 MB/s eta 0:00:00
# Downloading pydantic_settings-2.5.2-py3-none-any.whl (26 kB)
# Downloading tenacity-8.5.0-py3-none-any.whl (28 kB)
# Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Downloading marshmallow-3.22.0-py3-none-any.whl (49 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.3/49.3 kB 2.9 MB/s eta 0:00:00
# Downloading orjson-3.10.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (141 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.9/141.9 kB 8.1 MB/s eta 0:00:00
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 3.6 MB/s eta 0:00:00
# Downloading jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Building wheels for collected packages: wikipedia
#   Building wheel for wikipedia (setup.py) ... done
#   Created wheel for wikipedia: filename=wikipedia-1.4.0-py3-none-any.whl size=11679 sha256=3edac8a1e50f07cad1330d54abd9d1bee116cf93d99e563a61a9afafcca75559
#   Stored in directory: /root/.cache/pip/wheels/5e/b6/c5/93f3dec388ae76edc830cb42901bb0232504dfc0df02fc50de
# Successfully built wikipedia
# Installing collected packages: tenacity, python-dotenv, orjson, neo4j, mypy-extensions, marshmallow, jsonpointer, jiter, h11, wikipedia, typing-inspect, tiktoken, jsonpatch, httpcore, pydantic-settings, httpx, dataclasses-json, openai, langsmith, langchain-core, langchain-text-splitters, langchain_openai, langchain, langchain-community
#   Attempting uninstall: tenacity
#     Found existing installation: tenacity 9.0.0
#     Uninstalling tenacity-9.0.0:
#       Successfully uninstalled tenacity-9.0.0
# Successfully installed dataclasses-json-0.6.7 h11-0.14.0 httpcore-1.0.5 httpx-0.27.2 jiter-0.5.0 jsonpatch-1.33 jsonpointer-3.0.0 langchain-0.3.1 langchain-community-0.3.1 langchain-core-0.3.6 langchain-text-splitters-0.3.0 langchain_openai-0.2.1 langsmith-0.1.129 marshmallow-3.22.0 mypy-extensions-1.0.0 neo4j-5.25.0 openai-1.50.1 orjson-3.10.7 pydantic-settings-2.5.2 python-dotenv-1.0.1 tenacity-8.5.0 tiktoken-0.7.0 typing-inspect-0.9.0 wikipedia-1.4.0

# %% [markdown]
# ### Connect to DB

# %%
from langchain.graphs import Neo4jGraph

url = input("Enter your Neo4j URL: ")

username = input("Enter your Neo4j username: ")
password = input("Enter your Neo4j password: ")

graph = Neo4jGraph(
    url=url,
    username=username,
    password=password
)

# %% [markdown]
# ### Fetch all relations in the graph

# %%
data = graph.query("Match (n)-[r]->(m) Return n,r,properties(r),m")

# %%
len(data)
# Out:
# 611

# %%
relations = []
for triplet in data:
    try:
        first_entity = triplet['n']['id']
    except:
        first_entity = triplet['n']['name']
    relation = triplet['r'][1]
    relation_properties = ' '.join(triplet['properties(r)'].values())
    try:
        second_entity = triplet['m']['id']
    except:
        second_entity = triplet['m']['name']
    relations.append((first_entity, relation, second_entity, relation_properties))

# %%
len(relations)
# Out:
# 611

# %% [markdown]
# ## Generating embeddings from relations
#
# model="text-embedding-ada-002"

# %% [markdown]
# ### OpenAI client

# %%
from openai import OpenAI
client = OpenAI(
    api_key=input("Enter your OpenAI API Key: "),
)

# %% [markdown]
# ### Generate embeddings

# %%
relations[0]
# Out:
# ('Karim Benzema', 'TOP_SCORER_IN', 'Real Madrid', '2020 La Liga season')

# %%
def get_embedding(text, model="text-embedding-ada-002"):
   text = text.replace("\n", " ")
   return client.embeddings.create(input = [text], model=model).data[0].embedding

rel_embeddings = []
for rel in relations:
    embedding = get_embedding(" ".join(rel))
    rel_embeddings.append((rel, embedding))

# %% [markdown]
# ## Index embeddings into vector database

# %% [markdown]
# ### Install faiss-cpu

# %%
! pip install faiss-cpu

# %% [markdown]
# ### Add index on embedding vectors

# %%
import faiss
import numpy as np

embeddings_np = np.array([embedding for _, embedding in rel_embeddings])

dimension = embeddings_np.shape[1]
index = faiss.IndexFlatL2(dimension)

index.add(embeddings_np)

embedding_to_rel_map = {i: triplet for i, (triplet, _) in enumerate(rel_embeddings)}

# %% [markdown]
# ## Retrieval

# %% [markdown]
# ### Questions

# %%
questions = [
    "What was the primary match t-shirt color of the winner of the Ballon d'Or in the season of 1998-1999?",
    "What is the home stadium of the team that won the UEFA Champions League in 2012?",
    "What was the jersey number of the player who was the top scorer in the 2002 FIFA World Cup?",
    "What was the main architectural style of the palace where the Treaty of Versailles was signed?",
    "Who was the captain of the team that won the ICC Cricket World Cup in 2011 and what was his primary role in the team?",
    "What was the primary aircraft model used by the airline that was the largest operator in Europe in 2010?",
    "What was the primary diet of the largest land animal found in Africa?",
    "What was the primary programming language used by the company that developed the Windows operating system in the 1980s?",
    "What was the main theme of the novel written by the author who won the Nobel Prize in Literature in 1954?",
    "What was the primary material used in the construction of the structure that is the tallest building in the world?",
    "What was the primary economic activity of the civilization that built the pyramids of Giza?",
    "What was the primary industry of the company whose CEO was named Time's Person of the Year in 1999?",
    "What was the main ingredient in the first synthetic plastic created?",
    "What was the main objective of the space mission that successfully landed humans on the Moon in 1969?",
    "What is the primary language spoken in the country that hosted the 2008 Summer Olympics?",
    "What was the primary match t-shirt color of the team that won the FIFA World Cup in 2010?",
    "Who was the main character in the novel that won the Pulitzer Prize for Fiction in 1961?",
    "What was the primary economic activity in the city that hosted the Summer Olympics in 2000?",
    "What was the main theme of the movie that won the Academy Award for Best Picture in 1994?",
    "What was the national team that the player who won the Golden Boot in the 2014 FIFA World Cup played for?",
    "What is the home stadium of the team that won the NBA Championship in 2016?",
    "What was the jersey number of the player who was named MVP of the 2006 NBA Finals?",
    "What was the main architectural style of the building where the Declaration of Independence was signed?",
    "Who was the captain of the team that won the FIFA Women's World Cup in 2019 and what was her primary position?",
    "What was the primary diet of the largest marine mammal found in the Indian Ocean and South Pacific Ocean?",
    "What was the main theme of the play written by the playwright who won the Pulitzer Prize for Drama in 1949?",
    "What was the primary material used in the construction of the bridge that connects San Francisco to Marin County?",
    "What was the main mission of the Mars rover mission launched by NASA in 2011?",
    "What is the primary language spoken in the country that won the Eurovision Song Contest in 2017?",
    "What was the home stadium of the team that won the La Liga title in 2014?",
    "What was the jersey number of the player who scored the winning goal in the 2010 FIFA World Cup Final?",
    "What was the architectural style of the cathedral where the coronation of the French kings took place?",
    "Who was the captain of the team that won the Stanley Cup in 2013",
    "What is the primary diet of the largest predator in the Arctic Ocean?",
    "What was the primary material used in the construction of the bridge that connects Brooklyn to Manhattan?",
    "What was the primary industry of the company whose CEO was named Time's Person of the Year in 1997?",
    "What is the primary language spoken in the country that won the Rugby World Cup in 2003?",
    "What was the primary economic activity in the city that hosted the Winter Olympics in 2002?",
    "What was the primary material used in the construction of the monument located in Washington, D.C. dedicated to the third president of the United States?",
    "What is the primary language spoken in the country that hosted the FIFA World Cup in 2006?",
    "What was the primary match t-shirt color of the team that won the Champions League in 2019?",
    "What are the primary colors of the team that won the Super Bowl in 2020?",
    "What are the primary colors of the team that won the NBA Finals in 2018?",
    "What is the primary color of the team that won the FIFA World Cup in 1998?",
    "What are the primary colors of the team that won the UEFA Europa League in 2016?",
    "What was the primary language spoken in the country that hosted the Summer Olympics in 2004?",
    "What was the primary jersey color of the team that won the NBA Championship in 2014?",
    "What is the home stadium of the team that won the English Premier League in 2013?",
    "What was the jersey number of the player who won the MVP award in the 2017 NFL season?",
    "What was the primary architectural style of the building where the United Nations Charter was signed?",
    "Who was the captain of the team that won the FIFA World Cup in 2014 and what was his primary position?",
    "What was the primary diet of the largest bird found in North America?",
    "What was the primary economic activity of the civilization that built Machu Picchu?",
    "What was the primary jersey color of the team that won the Super Bowl in 2015?",
    "What is the home stadium of the team that won the MLB World Series in 2016?",
    "What was the main theme of the film that won the Academy Award for Best Picture in 2003?",
    "What was the primary diet of the largest fish found in the ocean?",
    "What is the primary language spoken in the country that hosted the Winter Olympics in 2010?",
    "What was the primary match t-shirt color of the team that won the Copa America in 2019?",
    "What was the primary industry of the company that introduced the iPhone?",
    "What was the primary diet of the largest terrestrial carnivore in North America?",
    "What was the main architectural style of the building where the first United Nations General Assembly was held?",
    "What was the primary match t-shirt color of the team that won the NBA Finals in 2015?",
    "What was the primary mission of the space probe that first landed on a comet?",
    "What was the primary language spoken in the country that hosted the Winter Olympics in 2014?",
    "What was the main theme of the television series that won the Primetime Emmy Award for Outstanding Drama Series in 2018?",
    "What was the primary diet of the largest reptile found in the Nile River?",
    "What was the primary material used in the construction of the ship that completed the first successful circumnavigation of the Earth?",
    "What was the primary color of the uniform worn by the team that won the World Series in 2016?",
    "What was the main architectural style of the palace where the Congress of Vienna was held?",
    "What was the primary diet of the largest bird found in Australia?",
    "What was the primary language spoken in the country that won the Eurovision Song Contest in 2018?",
    "What was the primary match t-shirt color of the team that won the English Premier League in the 2017-2018 season?",
    "What was the primary material used in the construction of the ship that carried the Pilgrims to North America in 1620?",
    "What was the primary ingredient in the food that sustained sailors on long voyages during the Age of Exploration?",
    "What was the primary language spoken in the country that won the FIFA World Cup in 2014?",
    "What was the primary match t-shirt color of the team that won the Copa del Rey in 2021?",
    "What was the primary material used in the construction of the first artificial satellite launched into space?",
    "What was the primary match t-shirt color of the team that won the Serie A in the 2019-2020 season?",
    "What was the primary match t-shirt color of the team that won the FA Cup in 2019?",
    "What was the primary architectural style of the building where the Magna Carta was signed?",
    "What was the primary match t-shirt color of the team that won the Copa Libertadores in 2018?",
    "What was the primary language spoken in the country that hosted the Summer Olympics in 2012?",
    "What was the primary match t-shirt color of the team that won the Bundesliga in 2020?",
    "What was the primary language spoken in the country that won the Rugby World Cup in 1995?",
    "What was the primary architectural style of the church where the Battle of Hastings was commemorated?",
    "What was the primary match t-shirt color of the team that won the Copa del Rey in 2018?",
    "What was the primary diet of the largest marine predator found in the Southern Ocean?",
    "What was the primary match t-shirt color of the team that won the Premier League in 2015?",
    "What was the primary material used in the construction of the spacecraft that first landed humans on the Moon?",
    "What was the primary language spoken in the country that won the FIFA Women's World Cup in 2015?",
    "What was the primary match t-shirt color of the team that won the Serie A in 2021?",
    "What was the primary language spoken in the country that hosted the FIFA World Cup in 1994?",
    "What was the primary match t-shirt color of the team that won the UEFA Europa League in 2020?",
    "What is the home stadium of the team that won the French Ligue 1 in 2019?",
    "What was the primary jersey number of the player who won the Ballon d'Or in 2018?",
    "What was the primary match t-shirt color of the team that won the Copa America in 2021?",
    "What was the primary material used in the construction of the tower that is the tallest in Tokyo?",
    "What is the home stadium of the team that won the Italian Serie A in 2019?",
    "What was the primary diet of the largest predator in the Amazon River?",
    "What was the primary match t-shirt color of the team that won the FA Cup in 2021?",
    "What was the primary economic activity in the city that hosted the Winter Olympics in 2018?",
    "What was the primary match t-shirt color of the team that won the Copa Libertadores in 2021?",
    "What was the primary language spoken in the country that won the Eurovision Song Contest in 2019?",
    "What was the primary architectural style of the palace where the Potsdam Conference was held?",
    "What was the primary material used in the construction of the spaceship that carried the first human into space?",
    "What was the primary match t-shirt color of the team that won the FIFA Club World Cup in 2019?",
    "Who was the captain of the team that won the UEFA Champions League in 2005, and what was his primary position?",
    "What was the primary language spoken in the country that won the FIFA Women's World Cup in 1999, and who was the top scorer of that tournament?",
    "What was the main ingredient used in the creation of the first practical incandescent light bulb, and who was the inventor?",
    "Who was the main character in the novel that won the Booker Prize in 1981?",
    "What was the home stadium of the team that won the English Premier League in 2002?",
    "What was the primary color of the jersey worn by the team that won the FA Cup in 2004?",
    "What was the primary architectural style of the building where the first United States Congress met?",
    "What was the jersey number of the player who won the NBA MVP award in 2011?",
    "Who was the surgeon that performed the first implantation of the first artificial heart?",
    "Who was the captain of the team that won the Rugby World Cup in 2007?",
    "What is the primary language spoken in the country that won the Rugby World Cup in 2007?",
    "What was the primary color of the match t-shirt of the team that won the UEFA Europa League in 2013?",
    "Who was the main character in the novel that won the Pulitzer Prize for Fiction in 1980?",
    "What was the primary language spoken in the country that hosted the Winter Olympics in 1998?",
    "What was the primary color of the team that won the Super Bowl in 2018?",
    "Who was the captain of the team that won the Super Bowl in 2018",
    "Who was the manager of the team that won the FIFA World Cup in 1994?",
    "What was the primary color of the team that won the FIFA World Cup in 1994?",
    "What was the primary match t-shirt color of the team that won the Copa Libertadores in 2015?",
    "What was the primary language spoken in the country that hosted the Eurovision Song Contest in 2010?",
    "Who was the captain of the team that won the Stanley Cup in 2008?",
    "What was primary position of the captain of the team that won the Stanley Cup in 2008?",
    "What was the primary diet of the largest carnivorous dinosaur discovered?",
    "Where was the largest carnivorous dinosaur found?",
    "What was the primary color of the team that won the FA Cup in 2006?",
    "Who was the architect of the building where the first modern Olympic Games were held?",
    "What was the primary architectural style of the building where the first modern Olympic Games were held?",
    "Who was the captain of the team that won the Copa America in 2011?",
    "What was primary position of the captain of the team that won the Copa America in 2011?",
    "What was the primary color of the jersey worn by the team that won the FIFA World Cup in 2006?",
    "Who was captain of the team that won the FIFA World Cup in 2006?",
    "In which continent were the largest herbivorous dinosaur fossils discovered?",
    "What was the primary material used in the construction of the Statue of Liberty, and who was the sculptor?",
    "Who was the manager of the team that won the UEFA Champions League in 2013?",
    "What was the primary color of the team that won the UEFA Champions League in 2013?",
    "What was the primary language spoken in the country that hosted the World Expo in 1967",
    "What was the primary architectural style of the building where the Nuremberg Trials took place?",
    "In which country is the building where the Nuremberg Trials took place located?",
    "Who was the main character in the novel that won the Pulitzer Prize for Fiction in 1975?",
    "What was the main theme of the novel that won the Pulitzer Prize for Fiction in 1975?",
    "What was the primary material used in the construction of the Hoover Dam, and who was the president of the United States at the time?",
    "What was the primary color of the team that won the UEFA Europa League in 2017?",
    "Who was captain of the team that won the UEFA Europa League in 2017?",
    "What was the primary language spoken in the country that won the FIFA Women's World Cup in 2011?",
    "What was the primary material used in the construction of the Sydney Opera House, and who was the architect?",
    "What was the primary color of the match t-shirt of the team that won the English Premier League in 2016?",
    "Who was the manager of the team that won the FIFA World Cup in 1986?",
    "What was the primary color of the team that won the FIFA World Cup in 1986?",
    "What was the primary language spoken in the country that won the Rugby World Cup in 1999?",
    "Who was captain of the team that won the Rugby World Cup in 1999?",
    "What was the primary architectural style of the palace where the Potsdam Conference took place?",
    "In which country was the palace where the Potsdam Conference took place, located?",
    "What was the primary material used in the construction of the Leaning Tower of Pisa, and who was the architect?",
    "What was the primary diet of the largest predator in the Atlantic Ocean?",
    "What is scientific name of the largest predator in the Atlantic Ocean?",
    "Who was the captain of the team that won the NBA Finals in 2020?",
    "What was the primary color of the team that won the NBA Finals in 2020?",
    "What was the primary material used in the construction of the Eiffel Tower, and who was the engineer responsible for its design?",
    "What was the primary color of the team that won the Copa del Rey in 2020?",
    "What was the primary diet of the largest carnivore found in Africa?",
    "What was the primary color of the team that won the NBA Finals in 2013?",
    "What was the jersey number of the player who won the Golden Boot in the 2018 FIFA World Cup?",
    "Which club was the player who won the Golden Boot in the 2018 FIFA World Cup playing for that same year?",
    "Who was the captain of the team that won the 2016 Summer Olympics Men's Football Tournament?",
    "What was primary position of the captain of the team that won the 2016 Summer Olympics Men's Football Tournament?",
    "What was the primary material used in the construction of the Colosseum in Rome, and who was the emperor who commissioned its construction?",
    "Who was captain of the team that won the 1995 Rugby World Cup?",
    "What was the main architectural style of the building where the Treaty of Paris 1783 was signed?, and what was the country that ceded the territory in this treaty?",
    "What was the primary diet of the largest land mammal during the Pleistocene epoch?",
    "Where were the fossils of the largest land mammal during the Pleistocene epoch primarily discovered?",
    "What was the primary color of the uniform worn by the team that won the 2017 Copa Libertadores?",
    "Who was the coach of the team that won the 2017 Copa Libertadores?",
    "What was the main objective of the space mission that first landed humans on Mars, and which agency led this mission?",
    "What was the primary match t-shirt color of the team that won the Copa América in 2011?",
    "Who was the top scorer for the team that won the Copa América in 2011?",
    "What was the primary language spoken in the country that won the FIFA World Cup in 2002?",
    "Who was the head coach of the team that won the FIFA World Cup in 2002?",
    "What was the primary diet of the largest flying bird in history?",
    "Where have largest flying bird in history fossils been found?",
    "What was the primary material used in the construction of the Parthenon, and who was the architect responsible for its design?",
    "What was the primary architectural style of the building where the first United Nations General Assembly was held, and in which city is it located?",
    "What was the primary material used in the construction of the Berlin Wall, and which country was primarily responsible for its construction?",
    "What was the primary match t-shirt color of the team that won the FIFA Club World Cup in 2014, and who was their top scorer?",
    "What was the primary language spoken in the country that won the Eurovision Song Contest in 2010, and who was the winning artist?",
    "What was the primary color of the uniform worn by the team that won the Stanley Cup in 2019?",
    "Who was captain of the team that won the Stanley Cup in 2019?",
    "What was the primary diet of the largest land carnivore during the Cretaceous period?",
    "Where Were fossils of largest land carnivore during the Cretaceous period discovered?",
    "What was the primary language spoken in the country that won the Eurovision Song Contest in 2009, and who was the winner?",
    "Who was the captain of the team that won the FIFA World Cup in 2002?",
    "What was primary position of the captain of the team that won the FIFA World Cup in 2002?",
    "What was the primary color of the jersey worn by the team that won the World Series in 2017?",
    "During which era did the largest herbivorous dinosaur in North America live?",
    "Who was the captain of the team that won the La Liga in 2012?",
    "What was the primary color of the team that won the La Liga in 2012?",
    "What was the primary language spoken in the country that won the FIFA World Cup in 2018?",
    "Who was the director of the movie that won the Academy Award for Best Picture in 1994?",
    "What was the primary theme of the movie that won the Academy Award for Best Picture in 1994?",
    "Where was the building located in which the Declaration of Independence was signed?",
    "What was the primary diet of the largest carnivorous dinosaur in South America?",
    "What was the primary subject of the painting that sold for the highest price in 2020?",
    "Who was the captain of the team that won the UEFA Champions League in 2020?",
    "What was primary jersey color of the team that won the UEFA Champions League in 2020?",
    "Who was the top scorer of the team that won the Copa America in 2019?",
    "What was primary jersey color of the team that won the Copa America in 2019?",
    "Who was the manager of the team that won the FA Cup in 2018?",
    "What was the primary language spoken in the country that won the FIFA World Cup in 2010?",
    "Who was top scorer of the team that won the FIFA World Cup in 2010?",
    "Who was top scorer of the team that won the NBA Finals in 2015?",
    "Who was the captain of the team that won the Copa Libertadores in 2019?",
    "What was primary jersey color of the team that won the Copa Libertadores in 2019?",
    "What was the primary language spoken in the country that hosted the World Cup in 2014?",
    "Who was the top scorer of the team that won the La Liga in 2019?",
    "What was primary jersey color of the team that won the La Liga in 2019?",
    "Who was the manager of the team that won the Serie A in 2019?",
    "Who was the captain of the team that won the Champions League in 2021?",
    "What was the primary jersey color of the team that won the Champions League in 2021?",
    "Who was the captain of the team that won the Premier League in 2017?",
    "What was the primary jersey color of the team that won the Premier League in 2017?",
    "Who was the top scorer for the team that won the UEFA Europa League in 2019?",
    "What was the primary jersey color of the team that won the UEFA Europa League in 2019?",
    "Who was the captain of the team that won the Copa del Rey in 2019?",
    "What was primary jersey color of ther team that won the Copa del Rey in 2019?",
    "Who was the top scorer for the team that won the Bundesliga in 2020?",
    "What was the primary language spoken in the country that hosted the Summer Olympics in 1980?",
    "What was the primary economic activity of the civilization that built the city of Petra?",
    "Who was the captain of the team that won the Copa Libertadores in 2020?",
    "What was primary jersey color of the team that won the Copa Libertadores in 2020?",
    "Who was the top scorer for the team that won the La Liga in 2018?",
    "What was primary jersey color of the team that won the La Liga in 2018?",
    "Who was the top scorer for the team that won the La Liga in 2018?",
    "Who was the captain of the team that won the Serie A in 2020?",
    "What was the primary language spoken in the country that hosted the Winter Olympics in 2006?",
    "Who was the top scorer for the team that won the UEFA Champions League in 2018?",
    "What was primary jersey color of the team that won the UEFA Champions League in 2018?",
    "What was the primary economic activity of the civilization that built the city of Angkor?",
    "Who was the captain of the team that won the FIFA World Cup in 2018?",
    "What was primary jersey color of the team that won the FIFA World Cup in 2018?",
    "What was the primary language spoken in the country that hosted the Summer Olympics in 1972?",
    "Who was the top scorer for the team that won the La Liga in 2020?",
    "What was primary jersey color of the team that won the La Liga in 2020?",
    "Who was the captain of the team that won the FIFA Women's World Cup in 2015?",
    "What was primary jersey color of the team that won the FIFA Women's World Cup in 2015?",
    "What was the primary language spoken in the country that hosted the Winter Olympics in 1994?",
    "Who was the top scorer for the team that won the UEFA Europa League in 2020?",
    "What was the primary language spoken in the country that hosted the Summer Olympics in 1996?",
    "Who was the captain of the team that won the Premier League in 2018?",
    "Who was the top scorer for the team that won the Serie A in 2021",
    "Who was the captain of the team that won the Copa del Rey in 2020?",
    "What was the primary language spoken in the country that hosted the Summer Olympics in 1984?",
    "What was the primary language spoken in the country that hosted the Winter Olympics in 1988?",
    "What was the primary match t-shirt color of the team that won the MLS Cup in 2020?",
    "What was the primary language spoken in the country that hosted the World Expo in 2010?",
    "What was the primary architectural style of the building where the Treaty of Ghent was signed?",
    "What was the primary match t-shirt color of the team that won the Copa del Rey in 2022?",
    "What was the primary diet of the largest marsupial found in Australia?",
    "What was the primary language spoken in the country that won the Eurovision Song Contest in 2016?",
    "What was the primary match t-shirt color of the team that won the French Cup in 2021?",
    "What was the primary architectural style of the building where the Yalta Conference was held?",
    "What was the primary mission of the space probe that first visited Pluto?",
    "What was the primary language spoken in the country that hosted the FIFA Confederations Cup in 2013?",
    "What was the primary match t-shirt color of the team that won the English Premier League in the 2020-2021 season?",
    "What was the primary diet of the largest predator found in the Amazon rainforest?",
    "What was the primary material used in the construction of the first successful human-powered flight vehicle?",
    "What was the primary language spoken in the country that hosted the Commonwealth Games in 2018?",
    "What was the primary match t-shirt color of the team that won the Scottish Premiership in 2020?",
    "What was the primary architectural style of the building where the Congress of the Confederation was held?",
    "What was the primary language spoken in the country that hosted the FIFA U-20 World Cup in 2017?",
    "What was the primary diet of the largest carnivorous mammal found in South America?",
    "What was the primary material used in the construction of the spacecraft that first orbited Mercury?",
    "What was the primary architectural style of the building where the Kellogg-Briand Pact was signed?",
    "What was the primary material used in the construction of the first space station?",
    "What was the primary match t-shirt color of the team that won the DFB-Pokal in 2021?",
    "What was the primary architectural style of the building where the United States Constitution was drafted?",
    "What was the primary match t-shirt color of the team that won the French Ligue 1 in 2020?",
    "What was the primary diet of the largest herbivore found in South America?",
    "What was the primary match t-shirt color of the team that won the Copa Sudamericana in 2020?",
    "What was the primary language spoken in the country that hosted the 1986 FIFA World Cup?",
    "What was the primary architectural style of the building where the United States Bill of Rights was signed?",
    "What was the primary material used in the construction of the first human-made object to reach the Moon?",
    "What was the primary match t-shirt color of the team that won the FA Women's Super League in 2020?",
    "What was the primary diet of the largest marine predator found in the Pacific Ocean?",
    "What was the primary material used in the construction of the first successful passenger airplane?",
    "What was the primary match t-shirt color of the team that won the Eredivisie in 2021?",
    "What was the primary architectural style of the building where the Declaration of the Rights of Man and of the Citizen was drafted?",
    "What was the primary material used in the construction of the first skyscraper?",
    "What was the primary language spoken in the country that won the UEFA Euro Championship in 2016?",
    "What was the primary architectural style of the building where the Peace of Westphalia was signed?",
    "What was the primary language spoken in the country that hosted the FIFA Women's World Cup in 2019?"
]

# %% [markdown]
# ### Generate answer prompt

# %%
def generate_answer(question, retrieved_relations):
    formated_relations = list(map(lambda x:" ".join(x), retrieved_relations))
    prompt = "RETRIEVED RELATIONS:\n" + "\n".join(formated_relations)
    prompt += "\n\n" + "QUESTION:\n" + question
    prompt += "\n\n" + "INSTRUCTIONS:\n" + """Answer the users QUESTION using the RETRIEVED RELATIONS above.
Keep your answer ground in the facts of the RETRIEVED RELATIONS. it is guranteed retrieved relations are related to the question"""

    print()
    print()
    print("****************** generated prompt ******************")
    print(prompt)
    print("******************************************************")
    print()
    print()

    client = OpenAI(
        api_key=input("Enter your OpenAI API Key: "),
    )
    return client.chat.completions.create(
        messages=[
            {
                "role": "user",
                "content": prompt,
            }
        ],
        model="gpt-3.5-turbo",
    ).choices[0].message.content.replace("'", '').split(',')

# %% [markdown]
# ### Use LLM to extract the relations to search

# %%
from openai import OpenAI

client = OpenAI(
    api_key=input("Enter your OpenAI API Key: "),
)

def generate_search_relations(question):
    prompt = f"""Given the following user query: '{question}', suggest which relation I should search for in my knowledge graph. The relations are stored in the format \"Entity1 RelationName Entity2 propertiesOfRelation\", where:

Entity1 is the subject of the relation,
RelationName describes the connection between two entities,
Entity2 is the object of the relation,
propertiesOfRelation includes additional relevant details.
If the query provides clear entities or relation parts, suggest an appropriate relation format to search for, filling in placeholders (e.g. '?') for any missing elements. If only partial information is given, suggest the most likely relation string based on the available parts.

Example format: \"Karim Benzema  TOP_SCORER_IN  Real Madrid  2020 La Liga season\"

Give me each candidate relation in a separate line. (at least one, maximum five)
Do not include any explanations or apologies in your responses. Do not include any text except the relations.

Some of ENTITY or RELATION maybe not known from the question, so please put ? instead of them. Remember that proper format of a triplet is a RELATION

For example if I give you this question: "Who was top scorer of real madrid in 2020 La Liga season?" then you can give me this relation to retrieve: \"?  TOP_SCORER_IN  Real Madrid 2020  La Liga season\"
"""

    client = OpenAI(
        api_key=input("Enter your OpenAI API Key: "),
    )
    result = client.chat.completions.create(
            messages=[
                {
                    "role": "user",
                    "content": prompt,
                }
            ],
            model="gpt-4o",
        ).choices[0].message.content.replace('"', '').replace("'", '').replace('(', '').replace(')', '')
    return result.split('\n')

# %%
suggested_entity_relations = []

for query in questions:
    print(f"Query: {query}")
    suggestions = generate_search_relations(query)
    suggestions = [s for s in suggestions if s]
    print("Suggested entity-relations:")
    for i, sug in enumerate(suggestions):
        print(sug)
        suggestions[i] = sug.replace("?", "")
    suggested_entity_relations.append(suggestions)
    print("\n\n")
# Out:
# Query: What was the primary match t-shirt color of the winner of the Ballon d'Or in the season of 1998-1999?
# Suggested entity-relations:
# ?  WINNER_OF  Ballon dOr 1998-1999
# ?  PRIMARY_MATCH_TSHIRT_COLOR  ?  1998-1999 season
# ?  WINNER_OF  ?  propertiesOfRelation {primaryMatchTshirtColor: ?}
# ?  BALLON_DOR_WINNER  ?  1998-1999
# ?  TSHIRT_COLOR  ?  Ballon dOr winner 1998-1999
#
#
#
# Query: What is the home stadium of the team that won the UEFA Champions League in 2012?
# Suggested entity-relations:
# ?  WON  UEFA Champions League 2012
# ?  IS_HOME_STADIUM_OF  ?  name=?
# ?  HOME_STADIUM_OF  ?  2012 UEFA Champions League winner
# Chelsea WON  UEFA Champions League 2012
# Chelsea IS_HOME_STADIUM_OF  ?
#
#
#
# Query: What was the jersey number of the player who was the top scorer in the 2002 FIFA World Cup?
# Suggested entity-relations:
# ?  TOP_SCORER_IN  2002 FIFA World Cup  ?
# ?  JERSEY_NUMBER_OF  ?  ?
# ?  JERSEY_NUMBER_OF  ?  top scorer 2002 FIFA World Cup
# Top Scorer 2002 FIFA World Cup  JERSEY_NUMBER_OF  ?
# ?  TOP_SCORER_IN  2002 FIFA World Cup  ? JERSEY_NUMBER_OF ?
#
#
#
# Query: What was the main architectural style of the palace where the Treaty of Versailles was signed?
# Suggested entity-relations:
# Treaty of Versailles SIGNED_AT ? propertiesOfRelation
# Versailles Palace ARCHITECTURAL_STYLE ? propertiesOfRelation
# Treaty SIGNED AT Versailles_Palace propertiesOfRelation
# Versailles_Palace SIGNED_TREATY Treaty_of_Versailles propertiesOfRelation
# Treaty of Versailles LOCATION Versailles_Palace propertiesOfRelation
#
#
#
# Query: Who was the captain of the team that won the ICC Cricket World Cup in 2011 and what was his primary role in the team?
# Suggested entity-relations:
# ?  CAPTAIN_OF  ?  2011 ICC Cricket World Cup winner
# ?  PRIMARY_ROLE_IN_TEAM  ?  2011 ICC Cricket World Cup winner
# 2011 ICC Cricket World Cup winner  LED_BY  ?  ?
# ?  ROLE  ?  ICC Cricket World Cup 2011 winners
# ?  CAPTAIN_OF_WINNER  ?  ICC Cricket World Cup 2011
#
#
#
# Query: What was the primary aircraft model used by the airline that was the largest operator in Europe in 2010?
# Suggested entity-relations:
# ?  LARGEST_OPERATOR  Europe  2010
# ?  PRIMARY_AIRCRAFT_MODEL  ?  ?
# ?  USED_BY  ?
# ?  OPERATES  ?  PRIMARY_AIRCRAFT_MODEL
# ?  MOST_COMMON_AIRCRAFT  ?  ?
#
#
#
# Query: What was the primary diet of the largest land animal found in Africa?
# Suggested entity-relations:
# ?  PRIMARY_DIET_OF  LARGEST_LAND_ANIMAL_IN_AFRICA  ?
# LARGEST_LAND_ANIMAL_IN_AFRICA  HAS_DIET  ?  ?
#
#
#
# Query: What was the primary programming language used by the company that developed the Windows operating system in the 1980s?
# Suggested entity-relations:
# Windows ? DEVELOPED_BY Microsoft ?
# Microsoft ? DEVELOPED Windows ?
# Microsoft DEVELOPER_OF Windows ?
# Microsoft USED_PROGRAMMING_LANGUAGE ? 1980s
# Windows PRIMARY_PROGRAMMING_LANGUAGE ? 1980s
#
#
#
# Query: What was the main theme of the novel written by the author who won the Nobel Prize in Literature in 1954?
# Suggested entity-relations:
# 1954 WINNER_OF Nobel Prize in Literature ?
# ? AUTHOR_OF ? ?
# ? THEME_OF ? novel
# Hemingway WRITE ? ?
# ? MAIN_THEME ? novel
#
#
#
# Query: What was the primary material used in the construction of the structure that is the tallest building in the world?
# Suggested entity-relations:
# ?  PRIMARY_MATERIAL  Burj Khalifa  ?
# Burj Khalifa  PRIMARY_MATERIAL  ?  ?
# ?  CONSTRUCTION_MATERIAL  Burj Khalifa  ?
# Burj Khalifa  CONSTRUCTION_MATERIAL  ?  ?
# Burj Khalifa  MADE_OF  ?  ?
#
#
#
# Query: What was the primary economic activity of the civilization that built the pyramids of Giza?
# Suggested entity-relations:
# civilization that built the pyramids of Giza  PRIMARY_ECONOMIC_ACTIVITY ? ?
# pyramids of Giza BUILT_BY ? ?
# pyramids of Giza PRIMARY_ECONOMIC_ACTIVITY_ERA ?
# ? PRIMARY_ECONOMIC_ACTIVITY civilization that built the pyramids of Giza ?
# ? PRIMARY_ECONOMIC_ACTIVITY pyramids of Giza ?
#
#
#
# Query: What was the primary industry of the company whose CEO was named Time's Person of the Year in 1999?
# Suggested entity-relations:
# ?  CEO_OF  ?  Times Person of the Year 1999
# ?  PRIMARY_INDUSTRY_OF  ?  Times Person of the Year 1999
# ?  PERSON_OF_THE_YEAR  1999  ?
# ?  YEAR  PERSON_OF_THE_YEAR  ?  CEO of ?
#
#
#
# Query: What was the main ingredient in the first synthetic plastic created?
# Suggested entity-relations:
# ? PRIMARY_INGREDIENT_IN First_Synthetic_Plastic ?
# First_Synthetic_Plastic PRIMARY_INGREDIENT ? ?
# First_Synthetic_Plastic COMPOSED_OF ? ?
# ? COMPOSED_FIRST_SYNTHETIC_PLASTIC Primary_Ingredient ?
#
#
#
# Query: What was the main objective of the space mission that successfully landed humans on the Moon in 1969?
# Suggested entity-relations:
# ? OBJECTIVE_OF Apollo 11 ?
# Apollo 11 LANDING Moon 1969
#
#
#
# Query: What is the primary language spoken in the country that hosted the 2008 Summer Olympics?
# Suggested entity-relations:
# ?  HOSTED  2008 Summer Olympics  ?
# ?  PRIMARY_LANGUAGE  ?  ?
#
#
#
# Query: What was the primary match t-shirt color of the team that won the FIFA World Cup in 2010?
# Suggested entity-relations:
# ?  WINNER_OF  FIFA World Cup 2010
# ?  PRIMARY_MATCH_T_SHIRT_COLOR_OF  ?  FIFA World Cup 2010 winner
#
#
#
# Query: Who was the main character in the novel that won the Pulitzer Prize for Fiction in 1961?
# Suggested entity-relations:
# ?  MAIN_CHARACTER_IN  ?  Pulitzer Prize for Fiction 1961
# ?  MAIN_CHARACTER_IN  To Kill a Mockingbird  ?
#
#
#
# Query: What was the primary economic activity in the city that hosted the Summer Olympics in 2000?
# Suggested entity-relations:
# Sydney PRIMARY_ECONOMIC_ACTIVITY ?
# Sydney HOSTED Summer Olympics 2000
# ? HOSTED Summer Olympics 2000
# Sydney ? ? PRIMARY_ECONOMIC_ACTIVITY
# ? PRIMARY_ECONOMIC_ACTIVITY Sydney ?
#
#
#
# Query: What was the main theme of the movie that won the Academy Award for Best Picture in 1994?
# Suggested entity-relations:
# 1994 Academy Award for Best Picture ? ? ?
# ? THEME_OF ? ?
# 1994 Academy Award for Best Picture HAS_THEME ? ?
# ? WON 1994 Academy Award for Best Picture ?
# ? MAIN_THEME_OF ? 1994 Academy Award for Best Picture
#
#
#
# Query: What was the national team that the player who won the Golden Boot in the 2014 FIFA World Cup played for?
# Suggested entity-relations:
# ?  WON_GOLDEN_BOOT  2014 FIFA World Cup  ?
# ?  PLAYED_FOR  ?  national team
# ?  WON_GOLDEN_BOOT  ?  ?
# ?  PLAYED_FOR  national_team_of_Golden_Boot_winner_2014  ?
#
#
#
# Query: What is the home stadium of the team that won the NBA Championship in 2016?
# Suggested entity-relations:
# ?  WON  NBA Championship 2016
# ?  HOME_STADIUM  ? ?
# Team that won  NBA Championship 2016  ? ?
# Team that won  HAS_HOME_STADIUM  ? ?
# ?  HOME_STADIUM  Team that won NBA Championship 2016
#
#
#
# Query: What was the jersey number of the player who was named MVP of the 2006 NBA Finals?
# Suggested entity-relations:
# 2006 NBA Finals  MVP  ?
# ?  JERSEY_NUMBER  ? propertiesOfRelation
#
#
#
# Query: What was the main architectural style of the building where the Declaration of Independence was signed?
# Suggested entity-relations:
# ?  MAIN_ARCHITECTURAL_STYLE_OF  ? {Place = building where the Declaration of Independence was signed}
# ?  ARCHITECTURAL_STYLE_OF  ? {Landmark = Independence Hall}
# ?  STYLE_OF  Independence Hall ?
# Independence Hall  ARCHITECTURAL_STYLE  ?
# ?  MAIN_STYLE  Independence Hall {Event = Declaration of Independence signing}
#
#
#
# Query: Who was the captain of the team that won the FIFA Women's World Cup in 2019 and what was her primary position?
# Suggested entity-relations:
# ?  CAPTAIN_OF  ?  2019 FIFA Womens World Cup
# ?  WON  ?  2019 FIFA Womens World Cup
# ?  TEAM_CAPTAIN  ?  position=?
# United States  WON  ?  2019 FIFA Womens World Cup
# ?  PRIMARY_POSITION  ?  position=?
#
#
#
# Query: What was the primary diet of the largest marine mammal found in the Indian Ocean and South Pacific Ocean?
# Suggested entity-relations:
# Largest marine mammal  PRIMARY_DIET  ?  Indian Ocean and South Pacific Ocean
# ?  DIET  Largest marine mammal  Indian Ocean and South Pacific Ocean
# ?  DIET  Largest marine mammal  ?
# Largest marine mammal  DIET  ?  ?
#
#
#
# Query: What was the main theme of the play written by the playwright who won the Pulitzer Prize for Drama in 1949?
# Suggested entity-relations:
# ?  WON Pulitzer Prize for Drama  1949
# ?  WRITTEN_BY  ?
# ?  THEME_OF  ?
#
#
#
# Query: What was the primary material used in the construction of the bridge that connects San Francisco to Marin County?
# Suggested entity-relations:
# ?  PRIMARY_MATERIAL_USED_IN_CONSTRUCTION_OF  ? propertiesOfRelation
# San Francisco PRIMARY_MATERIAL_USED_IN_CONSTRUCTION_OF ? propertiesOfRelation
# ? PRIMARY_MATERIAL_USED_IN_CONSTRUCTION_OF ? connects_to Marin County
# San Francisco PRIMARY_MATERIAL_USED_IN_CONSTRUCTION_OF ? connects_to Marin County
# ? PRIMARY_MATERIAL_USED_IN_CONSTRUCTION_OF San Francisco propertiesOfRelation
#
#
#
# Query: What was the main mission of the Mars rover mission launched by NASA in 2011?
# Suggested entity-relations:
# ?  MAIN_MISSION_OF  Mars rover mission  propertiesOfRelation
# Mars rover mission  LAUNCHED_BY  NASA  2011
# Mars rover mission  MAIN_MISSION  ?  2011
# ?  MAIN_MISSION_OF  Mars rover mission launched by NASA  2011
# NASA  LAUNCH_YEAR  Mars rover mission  2011
#
#
#
# Query: What is the primary language spoken in the country that won the Eurovision Song Contest in 2017?
# Suggested entity-relations:
# ? WINNER_OF Eurovision Song Contest 2017
# ? PRIMARY_LANGUAGE ? ?
# Eurovision Song Contest 2017 WINNER ? ?
# ? OFFICIAL_LANGUAGE ? ?
#
#
#
# Query: What was the home stadium of the team that won the La Liga title in 2014?
# Suggested entity-relations:
# ?  WON_TITLE  La Liga  2014
# ?  WON_TITLE  La Liga  ?
# ?  HOME_STADIUM  ?  ?
#
#
#
# Query: What was the jersey number of the player who scored the winning goal in the 2010 FIFA World Cup Final?
# Suggested entity-relations:
# ?  SCORED_WINNING_GOAL  2010 FIFA World Cup Final  ?
# ?  JERSEY_NUMBER  ?  ?  ?SCORED_WINNING_GOAL  2010 FIFA World Cup Final
# 2010 FIFA World Cup Final  WINNING_GOAL_SCORED_BY  ?  jersey_number ?
# ?  SCORED_WINNING_GOAL  2010 FIFA World Cup Final  jersey_number ?
# ?  JERSEY_NUMBER  ?  2010 FIFA World Cup Final WINNING_GOAL_SCORER
#
#
#
# Query: What was the architectural style of the cathedral where the coronation of the French kings took place?
# Suggested entity-relations:
# ? CORONATION_LOCATION ? ?
# ? ARCHITECTURAL_STYLE ? ?
# ? CORONATION_SITE ? ?
# Reims Cathedral HAS_ARCHITECTURAL_STYLE ? ?
# Reims Cathedral CORONATION_SITE_OF French Kings ?
#
#
#
# Query: Who was the captain of the team that won the Stanley Cup in 2013
# Suggested entity-relations:
# ?  CAPTAIN_OF_TEAM  ?  won Stanley Cup 2013
# ?  CAPTAIN_OF_TEAM  ?  2013 Stanley Cup winner
#
#
#
# Query: What is the primary diet of the largest predator in the Arctic Ocean?
# Suggested entity-relations:
# Largest predator in Arctic Ocean  PRIMARY_DIET  ? ?
# Largest predator in Arctic Ocean  CONSUMES  ? ?
# Largest predator in Arctic Ocean  FEEDS_ON  ? ?
#
#
#
# Query: What was the primary material used in the construction of the bridge that connects Brooklyn to Manhattan?
# Suggested entity-relations:
# ?  MATERIAL_USED  Brooklyn Bridge  ?
# Brooklyn Bridge  MATERIAL_CONNECTS  Manhattan  ?
# Brooklyn  MATERIAL_USED_IN_CONSTRUCTION  Manhattan  ?
# Brooklyn Bridge  PRIMARY_MATERIAL  ?  ?
#
#
#
# Query: What was the primary industry of the company whose CEO was named Time's Person of the Year in 1997?
# Suggested entity-relations:
# ?  CEO_OF  ?  {was named Times Person of the Year in 1997}
# ?  INDUSTRY_OF  ?  {CEO was named Times Person of the Year in 1997}
#
#
#
# Query: What is the primary language spoken in the country that won the Rugby World Cup in 2003?
# Suggested entity-relations:
# ?  WON  Rugby World Cup 2003
# ?  PRIMARY_LANGUAGE  ?
# ?  SPOKEN_LANGUAGE_OF  ?
# Country  WON  Rugby World Cup 2003
# Country  PRIMARY_LANGUAGE  ?
#
#
#
# Query: What was the primary economic activity in the city that hosted the Winter Olympics in 2002?
# Suggested entity-relations:
# ?  HOSTED  Winter Olympics 2002
# Winter Olympics 2002  HOSTED_BY  ?
# ?  PRIMARY_ECONOMIC_ACTIVITY  ?  Winter Olympics 2002
# Salt Lake City  PRIMARY_ECONOMIC_ACTIVITY  ?
#
#
#
# Query: What was the primary material used in the construction of the monument located in Washington, D.C. dedicated to the third president of the United States?
# Suggested entity-relations:
# Third president of the United States  PRIMARY_MATERIAL_OF  ?  propertiesOfRelation
# ?  PRIMARY_MATERIAL_USED_IN_CONSTRUCTION  Monument in Washington, D.C.  propertiesOfRelation
# Monument in Washington, D.C.  DEDICATED_TO  Third president of the United States  propertiesOfRelation
# Monument in Washington, D.C.  PRIMARY_MATERIAL  ?  propertiesOfRelation
# Monument in Washington, D.C.  PRIMARY_MATERIAL_USED  Third president of the United States  propertiesOfRelation
#
#
#
# Query: What is the primary language spoken in the country that hosted the FIFA World Cup in 2006?
# Suggested entity-relations:
# ? HOSTED  2006_FIFA_World_Cup  ?
# Germany OFFICIAL_LANGUAGE  ? ?
#
#
#
# Query: What was the primary match t-shirt color of the team that won the Champions League in 2019?
# Suggested entity-relations:
# ?  WON  2019 UEFA Champions League ?
# 2019 UEFA Champions League  PRIMARY_MATCH_T_SHIRT_COLOR  ? ?
#
#
#
# Query: What are the primary colors of the team that won the Super Bowl in 2020?
# Suggested entity-relations:
# Super Bowl LIV  WINNER  ? propertiesOfRelation
# ?  WINNER  Super Bowl LIV propertiesOfRelation
# Super Bowl LIV CHAMPION_COLORS ? propertiesOfRelation
# ? PRIMARY_COLORS_TEAM Super Bowl LIV propertiesOfRelation
#
#
#
# Query: What are the primary colors of the team that won the NBA Finals in 2018?
# Suggested entity-relations:
# ? WON NBA Finals 2018 ?
# ? PRIMARY_COLORS_OF ? ?
#
#
#
# Query: What is the primary color of the team that won the FIFA World Cup in 1998?
# Suggested entity-relations:
# ?  TEAM_PRIMARY_COLOR  France  1998 FIFA World Cup Winner
# France  TEAM_PRIMARY_COLOR  ?  1998 FIFA World Cup Winner
# ?  TEAM_WON  1998 FIFA World Cup  France
#
#
#
# Query: What are the primary colors of the team that won the UEFA Europa League in 2016?
# Suggested entity-relations:
# ?  WON  UEFA Europa League  2016
# ?  COLORS_OF  ?   primary colors
# ?  COLORS_OF  Sevilla FC   ?  primary colors
#
#
#
# Query: What was the primary language spoken in the country that hosted the Summer Olympics in 2004?
# Suggested entity-relations:
# ? HOSTED  2004 Summer Olympics ?
# ? PRIMARY_LANGUAGE_OF ? ?
# ? CAPITAL_OF  Greece ?
# Greece HOSTED  2004 Summer Olympics ?
# Greek PRIMARY_LANGUAGE_OF Greece ?
#
#
#
# Query: What was the primary jersey color of the team that won the NBA Championship in 2014?
# Suggested entity-relations:
# ?  WIN_NBA_CHAMPIONSHIP  ?  2014
# ?  TEAM_JERSEY_COLOR  ?  ?
# ?  WIN_NBA_CHAMPIONSHIP  ?  2014 team
# ?  PRIMARY_JERSEY_COLOR  ?  WIN_NBA_CHAMPIONSHIP 2014
# ?  WIN_NBA_CHAMPIONSHIP  ?  ?
#
#
#
# Query: What is the home stadium of the team that won the English Premier League in 2013?
# Suggested entity-relations:
# ?  WINNER_OF  English Premier League 2013
# ?  HOME_STADIUM  ?  ?
#
#
#
# Query: What was the jersey number of the player who won the MVP award in the 2017 NFL season?
# Suggested entity-relations:
# ?  WON_MVP_AWARD  ?  2017 NFL season
# ?  JERSEY_NUMBER_OF  ?  won MVP award 2017 NFL season
#
#
#
# Query: What was the primary architectural style of the building where the United Nations Charter was signed?
# Suggested entity-relations:
# ?  ARCHITECTURAL_STYLE  ?  United Nations Charter building
# United Nations Charter building  ARCHITECTURAL_STYLE  ?  ?
#
#
#
# Query: Who was the captain of the team that won the FIFA World Cup in 2014 and what was his primary position?
# Suggested entity-relations:
# ?  CAPTAIN_OF  ?  won FIFA World Cup 2014
# ?  POSITION_OF  ?  captain of team won FIFA World Cup 2014
#
#
#
# Query: What was the primary diet of the largest bird found in North America?
# Suggested entity-relations:
# ?  PRIMARY_DIET_OF  largest bird found in North America  ?
# largest bird found in North America  PRIMARY_DIET  ?  ?
# ?  DIET  largest bird found in North America  ?
# largest bird found in North America  CONSUMES  ?  PRIMARY
# largest bird found in North America  FEEDS_ON  ?  PRIMARY
#
#
#
# Query: What was the primary economic activity of the civilization that built Machu Picchu?
# Suggested entity-relations:
# civilization that built Machu Picchu primary_economic_activity ? propertiesOfRelation
# Machu Picchu BUILT_BY ? propertiesOfRelation
# ? ASSOCIATED_WITH Machu Picchu propertiesOfRelation
# ? ENGAGED_IN primary_economic_activity propertiesOfRelation
# ? ECONOMIC_ACTIVITY Machu Picchu propertiesOfRelation
#
#
#
# Query: What was the primary jersey color of the team that won the Super Bowl in 2015?
# Suggested entity-relations:
# ?  WIN_SUPER_BOWL_IN  ?  2015
# ?  PRIMARY_JERSEY_COLOR  ?  Super Bowl 2015 winner
#
#
#
# Query: What is the home stadium of the team that won the MLB World Series in 2016?
# Suggested entity-relations:
# ?  WINNER_OF  MLB World Series 2016
# ?  HOME_STADIUM_OF  Chicago Cubs  ?
# Chicago Cubs  HOME_STADIUM_OF  ?  ?
# Chicago Cubs  WINNER_OF  MLB World Series 2016
# ?  HOME_STADIUM_OF  ?  WINNER OF MLB World Series 2016
#
#
#
# Query: What was the main theme of the film that won the Academy Award for Best Picture in 2003?
# Suggested entity-relations:
# ? WINNER_OF Academy Award for Best Picture 2003 ?
# ? THEME_OF ? ? Academy Award for Best Picture 2003
# ? WON Academy Award for Best Picture 2003 THEME
#
#
#
# Query: What was the primary diet of the largest fish found in the ocean?
# Suggested entity-relations:
# ?  PRIMARY_DIET_OF  ?  largest fish in the ocean
# largest fish in the ocean  PRIMARY_DIET  ?  ?
#
#
#
# Query: What is the primary language spoken in the country that hosted the Winter Olympics in 2010?
# Suggested entity-relations:
# ?  HOSTED  2010 Winter Olympics  ?
# Country  PRIMARY_LANGUAGE  ?  ?
#
#
#
# Query: What was the primary match t-shirt color of the team that won the Copa America in 2019?
# Suggested entity-relations:
# ? WON ? 2019 Copa America
# ? PRIMARY_COLOR ? 2019 MATCH_T_SHIRT
#
#
#
# Query: What was the primary industry of the company that introduced the iPhone?
# Suggested entity-relations:
# ? INDUSTRY_OF Apple ?
# Apple INTRODUCED iPhone ?
# iPhone PRODUCT_OF Apple ?
#
#
#
# Query: What was the primary diet of the largest terrestrial carnivore in North America?
# Suggested entity-relations:
# ?  PRIMARY_DIET_OF  largest_terrestrial_carnivore_in_North_America  ?
# largest_terrestrial_carnivore_in_North_America  PRIMARY_DIET  ?  ?
#
#
#
# Query: What was the main architectural style of the building where the first United Nations General Assembly was held?
# Suggested entity-relations:
# First United Nations General Assembly  HELD_AT  ?  ?
# ?  ARCHITECTURAL_STYLE  ?  ?
# ?  HELD_AT  First United Nations General Assembly  ?
# ?  ARCHITECTURAL_STYLE  First United Nations General Assembly Building  ?
# First United Nations General Assembly Building  ARCHITECTURAL_STYLE  ?  ?
#
#
#
# Query: What was the primary match t-shirt color of the team that won the NBA Finals in 2015?
# Suggested entity-relations:
# ?  PRIMARY_MATCH_T_SHIRT_COLOR_OF  ?  WIN NBA Finals 2015
#
#
#
# Query: What was the primary mission of the space probe that first landed on a comet?
# Suggested entity-relations:
# ?  PRIMARY_MISSION_OF  ?  landed on a comet
# ?  FIRST_LANDED_ON  comet  ?
# space probe  PRIMARY_MISSION  ?  ?
#
#
#
# Query: What was the primary language spoken in the country that hosted the Winter Olympics in 2014?
# Suggested entity-relations:
# ? HOSTED  Winter Olympics 2014
# ? HOSTED Winter Olympics ? propertiesOfRelation=2014
# Winter Olympics HELD_IN ? propertiesOfRelation=2014
# Sochi HOSTED Winter Olympics 2014
# ? PRIMARY_LANGUAGE ? propertiesOfRelation=Host of 2014 Winter Olympics
#
#
#
# Query: What was the main theme of the television series that won the Primetime Emmy Award for Outstanding Drama Series in 2018?
# Suggested entity-relations:
# ?  WINNER_OF  Primetime Emmy Award for Outstanding Drama Series 2018
# ?  MAIN_THEME_OF  ?  ?
# The Americans  MAIN_THEME_OF  ?  ?
#
#
#
# Query: What was the primary diet of the largest reptile found in the Nile River?
# Suggested entity-relations:
# ?  PRIMARY_DIET_OF  largest reptile found in the Nile River ?
# largest reptile found in the Nile River  PRIMARY_DIET  ? ?
#
#
#
# Query: What was the primary material used in the construction of the ship that completed the first successful circumnavigation of the Earth?
# Suggested entity-relations:
# ship_that_completed_first_circumnavigation primary_material ? ?
# ? completed first_successful_circumnavigation_of_Earth properties_of_ship_including_material
# first_successful_circumnavigation primary_material ship_that_completed_it ?
# ship_that_completed_first_circumnavigation  material_used ? ?
# Magellans_ship primary_material ? ?
#
#
#
# Query: What was the primary color of the uniform worn by the team that won the World Series in 2016?
# Suggested entity-relations:
# ?  PRIMARY_COLOR_OF_UNIFORM  ?  2016 World Series winner
# ?  PRIMARY_COLOR_OF_UNIFORM  Chicago Cubs 2016 World Series
# Chicago Cubs  WON  ?  2016 World Series
#
#
#
# Query: What was the main architectural style of the palace where the Congress of Vienna was held?
# Suggested entity-relations:
# ?  ARCHITECTURAL_STYLE_OF  ?Palace  ?Congress_of_Vienna
# ?Palace  LOCATION_OF  Congress_of_Vienna  ?
#
#
#
# Query: What was the primary diet of the largest bird found in Australia?
# Suggested entity-relations:
# ?  PRIMARY_DIET_OF  largest bird found in Australia  ?
# largest bird found in Australia  HAS_DIET  ?  ?
#
#
#
# Query: What was the primary language spoken in the country that won the Eurovision Song Contest in 2018?
# Suggested entity-relations:
# ?  WINNER_OF  Eurovision Song Contest 2018
# ?  PRIMARY_LANGUAGE_SPOKEN_IN  ?  ?
# ?  LANGUAGE_OF_COUNTRY  Eurovision Song Contest Winner 2018
#
#
#
# Query: What was the primary match t-shirt color of the team that won the English Premier League in the 2017-2018 season?
# Suggested entity-relations:
# ? WON ? English Premier League 2017-2018 season
# ? PRIMARY_MATCH_TSHIRT_COLOR ? 2017-2018 season
# ? WON English Premier League ?
# Manchester City PRIMARY_MATCH_TSHIRT_COLOR ? 2017-2018 season
#
#
#
# Query: What was the primary material used in the construction of the ship that carried the Pilgrims to North America in 1620?
# Suggested entity-relations:
# ?  PRIMARY_MATERIAL_USED_IN_CONSTRUCTION  ?  ship carried Pilgrims 1620 North America
#
#
#
# Query: What was the primary ingredient in the food that sustained sailors on long voyages during the Age of Exploration?
# Suggested entity-relations:
# ?sustained  ?  sailors  Age of Exploration
# food  ?  sailors  Age of Exploration
# ?sustained  ingredient  ? propertiesOfRelation
# ?  ?  sailors  ? Food
#
#
#
# Query: What was the primary language spoken in the country that won the FIFA World Cup in 2014?
# Suggested entity-relations:
# ?  WON_FIFA_WORLD_CUP_IN  2014 ?
# ?  PRIMARY_LANGUAGE  ? ?
#
#
#
# Query: What was the primary match t-shirt color of the team that won the Copa del Rey in 2021?
# Suggested entity-relations:
# ? WINNER_OF Copa del Rey 2021
# ? PRIMARY_COLOR_OF_TSHIRT ? ? winner
# ? ? ? ? color
#
#
#
# Query: What was the primary material used in the construction of the first artificial satellite launched into space?
# Suggested entity-relations:
# first artificial satellite  primary_material_used  ?  ?
# ?  primary_material_used  first artificial satellite  ?
# first artificial satellite  constructed_from  ?  ?
# ?  constructed_from  first artificial satellite  ?
# first artificial satellite  primary_material_used_in_construction  ?  ?
#
#
#
# Query: What was the primary match t-shirt color of the team that won the Serie A in the 2019-2020 season?
# Suggested entity-relations:
# ?  PRIMARY_MATCH_T_SHIRT_COLOR  ?  2019-2020 Serie A season
# ?  WON  Serie A  2019-2020 season
# ?  PRIMARY_MATCH_T_SHIRT_COLOR  ?  ?
#
#
#
# Query: What was the primary match t-shirt color of the team that won the FA Cup in 2019?
# Suggested entity-relations:
# ?  WON  FA Cup  2019
# ?  PRIMARY_MATCH_T_SHIRT_COLOR  ?  ?
#
#
#
# Query: What was the primary architectural style of the building where the Magna Carta was signed?
# Suggested entity-relations:
# ?  ARCHITECTURAL_STYLE_OF  Building where Magna Carta was signed  ?
# Building where Magna Carta was signed  ARCHITECTURAL_STYLE  ?  ?
# ?  SITE_OF_SIGNING  Magna Carta  ?
# ?  ARCHITECTURE_OF_SITE  Site of Magna Carta signing  ?
#
#
#
# Query: What was the primary match t-shirt color of the team that won the Copa Libertadores in 2018?
# Suggested entity-relations:
# ?  WINNER_OF  Copa Libertadores 2018
# ?  PRIMARY_COLOR_OF  ?   Copa Libertadores 2018 winner
# Copa Libertadores 2018 winner  PRIMARY_MATCH_TSHIRT_COLOR  ?
#
#
#
# Query: What was the primary language spoken in the country that hosted the Summer Olympics in 2012?
# Suggested entity-relations:
# ? HOSTED Summer Olympics 2012
# ? PRIMARY_LANGUAGE ? United Kingdom
#
#
#
# Query: What was the primary match t-shirt color of the team that won the Bundesliga in 2020?
# Suggested entity-relations:
# ? WON Bundesilga 2020 properties
# ? PRIMARY_MATCH_TSHIRT_COLOR ? 2020 season
# ? MATCH_TSHIRT_COLOR_OF_TEAM ? 2020 Bundesliga season
# Bayern Munich PRIMARY_MATCH_TSHIRT_COLOR ? 2020 season
# Bayern Munich MATCH_TSHIRT_COLOR ? ?
#
#
#
# Query: What was the primary language spoken in the country that won the Rugby World Cup in 1995?
# Suggested entity-relations:
# ?  WINNER_OF  Rugby World Cup 1995
# ?  PRIMARY_LANGUAGE_OF  ?  country
# South Africa  PRIMARY_LANGUAGE  ?
#
#
#
# Query: What was the primary architectural style of the church where the Battle of Hastings was commemorated?
# Suggested entity-relations:
# Battle of Hastings  COMMEMORATED_AT  ? ?
# Battle of Hastings  ARCHITECTURAL_STYLE  ? ?
# ?  ARCHITECTURAL_STYLE  Church of the Battle of Hastings ?
# ?  COMMEMORATED_AT  Church of the Battle of Hastings ?
#
#
#
# Query: What was the primary match t-shirt color of the team that won the Copa del Rey in 2018?
# Suggested entity-relations:
# ?  WINNER_OF  Copa del Rey 2018
# ?  PRIMARY_SHIRT_COLOR_OF  ?  ?  Copa del Rey 2018
# ?  PRIMARY_MATCH_COLOR  ?  ?  Copa del Rey 2018
# ?  WON_COPA_DEL_REY  2018  ?
# ?  TEAM_COLOR  ?  ?  Copa del Rey 2018
#
#
#
# Query: What was the primary diet of the largest marine predator found in the Southern Ocean?
# Suggested entity-relations:
# ?  PRIMARY_DIET_OF  largest marine predator found in the Southern Ocean  ?
# largest marine predator found in the Southern Ocean  DIET_INCLUDES  ?  ?
#
#
#
# Query: What was the primary match t-shirt color of the team that won the Premier League in 2015?
# Suggested entity-relations:
# ?  PRIMARY_MATCH_T_SHIRT_COLOR  ?  Premier League 2015
# Leicester City  PRIMARY_MATCH_T_SHIRT_COLOR  ?  Premier League 2015
# Leicester City  WON  Premier League 2015
# Leicester City  TEAM_COLOR  ?  Premier League 2015
#
#
#
# Query: What was the primary material used in the construction of the spacecraft that first landed humans on the Moon?
# Suggested entity-relations:
# ?  MATERIAL_USED_IN_CONSTRUCTION  ?  {first landed humans on the Moon}
# ?  MATERIAL_USED_IN_CONSTRUCTION  spacecraft  {first landed humans on the Moon}
# spacecraft  MATERIAL_USED_IN_CONSTRUCTION  ?  {first landed humans on the Moon}
# Apollo 11  MATERIAL_USED_IN_CONSTRUCTION  ?  {first landed humans on the Moon}
# Lunar Module  MATERIAL_USED_IN_CONSTRUCTION  ?  {first landed humans on the Moon}
#
#
#
# Query: What was the primary language spoken in the country that won the FIFA Women's World Cup in 2015?
# Suggested entity-relations:
# ?  WINNER_OF  FIFA Womens World Cup 2015
# ?  PRIMARY_LANGUAGE_SPOKEN_IN  ? ?  WINNER_OF  FIFA Womens World Cup 2015
#
#
#
# Query: What was the primary match t-shirt color of the team that won the Serie A in 2021?
# Suggested entity-relations:
# ? WON Serie A 2021 primaryMatchTshirtColor ?
# ? WON Serie A ? primaryMatchTshirtColor ?
# ? PRIMARY_MATCH_TSHIRT_COLOR_IN Serie A 2021
# ? PRIMARY_MATCH_TSHIRT_COLOR_IN Serie A ?
#
#
#
# Query: What was the primary language spoken in the country that hosted the FIFA World Cup in 1994?
# Suggested entity-relations:
# ? HOSTED_BY ? 1994 FIFA World Cup
# ? HOSTED_BY ? 1994
# ? HOSTED_THE_FIFA_WORLD_CUP ? 1994
# ? PRIMARY_LANGUAGE_SPOKEN ? English
# United States PRIMARY_LANGUAGE_SPOKEN ? ?
#
#
#
# Query: What was the primary match t-shirt color of the team that won the UEFA Europa League in 2020?
# Suggested entity-relations:
# ? WINNER_OF ?  UEFA Europa League 2020
# ? PRIMARY_MATCH_TSHIRT_COLOR_OF ?  UEFA Europa League 2020
#
#
#
# Query: What is the home stadium of the team that won the French Ligue 1 in 2019?
# Suggested entity-relations:
# ? WON French Ligue 1 2019
# ? HOME_STADIUM ?
# ? HOME_STADIUM 2019 French Ligue 1 Champion
#
#
#
# Query: What was the primary jersey number of the player who won the Ballon d'Or in 2018?
# Suggested entity-relations:
# Luka Modrić  PRIMARY_JERSEY_NUMBER  ?  Ballon dOr 2018 winner
# Luka Modrić  WON_AWARD  Ballon dOr  2018
# Luka Modrić  PLAYER_NUMBER  Real Madrid  ?
# Luka Modrić  AWARD_YEAR  Ballon dOr 2018
# Luka Modrić  TEAM_JERSEY  ?  Ballon dOr 2018 winner
#
#
#
# Query: What was the primary match t-shirt color of the team that won the Copa America in 2021?
# Suggested entity-relations:
# ?  PRIMARY_MATCH_TSHIRT_COLOR_OF  TeamThatWonCopaAmerica2021  ?
#
#
#
# Query: What was the primary material used in the construction of the tower that is the tallest in Tokyo?
# Suggested entity-relations:
# ?  PRIMARY_MATERIAL_USED_IN  tallest tower in Tokyo ?
# tallest tower in Tokyo  PRIMARY_MATERIAL_USED ?
#
#
#
# Query: What is the home stadium of the team that won the Italian Serie A in 2019?
# Suggested entity-relations:
# ?  WON  Italian Serie A 2019
# ?  STADIUM  ?  properties
#
#
#
# Query: What was the primary diet of the largest predator in the Amazon River?
# Suggested entity-relations:
# ?  PRIMARY_DIET_OF  largest predator in Amazon River ?
# largest predator in Amazon River  PRIMARY_DIET_IS  ? ?
# largest predator in Amazon River  DIET_INCLUDES  ? ?
# largest predator in Amazon River  DIETARY_HABIT  ? ?
# largest predator in Amazon River  CONSUMES  ? ?
#
#
#
# Query: What was the primary match t-shirt color of the team that won the FA Cup in 2021?
# Suggested entity-relations:
# ?  WINNER_OF  FA Cup 2021
# ?  PRIMARY_MATCH_TSHIRT_COLOR  ?  ?
#
#
#
# Query: What was the primary economic activity in the city that hosted the Winter Olympics in 2018?
# Suggested entity-relations:
# ?  HOSTED  Winter Olympics 2018
# Winter Olympics 2018  HOST_CITY  ?
# ?  PRIMARY_ECONOMIC_ACTIVITY  ?  year: 2018, event: Winter Olympics
# ?  PRIMARY_ECONOMIC_ACTIVITY  Host City of Winter Olympics 2018
# Host City of Winter Olympics 2018  PRIMARY_ECONOMIC_ACTIVITY  ?
#
#
#
# Query: What was the primary match t-shirt color of the team that won the Copa Libertadores in 2021?
# Suggested entity-relations:
# ? WON Copa_Libertadores 2021
# ? PRIMARY_MATCH_T_SHIRT_COLOR ? 2021
#
#
#
# Query: What was the primary language spoken in the country that won the Eurovision Song Contest in 2019?
# Suggested entity-relations:
# ?  WINNER_OF  Eurovision Song Contest 2019
# ?  PRIMARY_LANGUAGE  ?  ?
# Eurovision Song Contest 2019  WINNER  ?  ?
# ?  SPOKEN_LANGUAGE  ?  ?
#
#
#
# Query: What was the primary architectural style of the palace where the Potsdam Conference was held?
# Suggested entity-relations:
# Potsdam Conference HELD_AT ?  propertiesOfRelation
# ? PRIMARY_ARCHITECTURAL_STYLE_OF Potsdam Conference palace propertiesOfRelation
# ? PRIMARY_ARCHITECTURAL_STYLE_OF ?  palace propertiesOfRelation
# Potsdam Conference HELD_AT  palace WITH_PRIMARY_ARCHITECTURAL_STYLE ? propertiesOfRelation
# ? LOCATED_IN Potsdam  WITH_PRIMARY_ARCHITECTURAL_STYLE ? propertiesOfRelation
#
#
#
# Query: What was the primary material used in the construction of the spaceship that carried the first human into space?
# Suggested entity-relations:
# ?  PRIMARY_MATERIAL_USED_IN_CONSTRUCTION  Vostok 1  ?
# Yuri Gagarin  PRIMARY_MATERIAL_USED_IN_CONSTRUCTION  ?  ?
# ?  PRIMARY_MATERIAL_USED_IN_CONSTRUCTION  first manned spaceship  ?
#
#
#
# Query: What was the primary match t-shirt color of the team that won the FIFA Club World Cup in 2019?
# Suggested entity-relations:
# ?  MATCH_TSHIRT_COLOR  ?  2019 FIFA Club World Cup
# Liverpool  MATCH_TSHIRT_COLOR  ?  2019 FIFA Club World Cup
# ?  WINNER_OF  2019 FIFA Club World Cup  MATCH_TSHIRT_COLOR
# Liverpool  WINNER_OF  2019 FIFA Club World Cup  MATCH_TSHIRT_COLOR
# Liverpool  PRIMARY_MATCH_TSHIRT_COLOR  ?  2019 FIFA Club World Cup
#
#
#
# Query: Who was the captain of the team that won the UEFA Champions League in 2005, and what was his primary position?
# Suggested entity-relations:
# ?  CAPTAIN_OF  TeamThatWonUEFAChampionsLeague2005  ?
# TeamThatWonUEFAChampionsLeague2005  WON  UEFA Champions League 2005
# ?  PRIMARY_POSITION  CaptainOfTeamThatWonUEFAChampionsLeague2005  ?
# CaptainOfTeamThatWonUEFAChampionsLeague2005  CAPTAIN_OF  TeamThatWonUEFAChampionsLeague2005  ?
# CaptainOfTeamThatWonUEFAChampionsLeague2005  PRIMARY_POSITION  ?  ?
#
#
#
# Query: What was the primary language spoken in the country that won the FIFA Women's World Cup in 1999, and who was the top scorer of that tournament?
# Suggested entity-relations:
# ?  WINNER_OF  1999 FIFA Womens World Cup  ?
# ?  PRIMARY_LANGUAGE_SPOKEN_IN  ?  ?
# ?  TOP_SCORER_IN  1999 FIFA Womens World Cup  ?
#
#
#
# Query: What was the main ingredient used in the creation of the first practical incandescent light bulb, and who was the inventor?
# Suggested entity-relations:
# Edison CREATED_FIRST_PRACTICAL_INCANDESCENT_LIGHT_BULB ? ?
# ? MAIN_INGREDIENT_IN_FIRST_PRACTICAL_INCANDESCENT_LIGHT_BULB Incandescent_Light_Bulb ?
#
#
#
# Query: Who was the main character in the novel that won the Booker Prize in 1981?
# Suggested entity-relations:
# ?  MAIN_CHARACTER_OF  ?  novel won Booker Prize 1981
# ?  WON_BOOKER_PRIZE  1981  properties novel
# ?  MAIN_CHARACTER_OF  ?  ? 1981 Booker Prize novel
#
#
#
# Query: What was the home stadium of the team that won the English Premier League in 2002?
# Suggested entity-relations:
# ?  HOME_STADIUM_OF  ?team  properties: English Premier League winner 2002
# ?team  WON  ?trophy  properties: 2002, English Premier League
# ?team  HOME_STADIUM  ?stadium  properties: 2002, English Premier League winner
# ?match  PLAYED_AT  ?stadium  properties: winning team, English Premier League 2002
# ?team  VENUE  ?stadium  properties: 2002, English Premier League champion
#
#
#
# Query: What was the primary color of the jersey worn by the team that won the FA Cup in 2004?
# Suggested entity-relations:
# ?  WON  FA Cup  2004
# ?  PRIMARY_COLOR_OF_JERSEY  FA Cup Winner  2004
# FA Cup WINNER ?  2004
# FA Cup Winner  PRIMARY_COLOR_OF_JERSEY  ?  2004
# FA Cup  WINNER  ?  2004
#
#
#
# Query: What was the primary architectural style of the building where the first United States Congress met?
# Suggested entity-relations:
# First United States Congress  MET_IN  ?  ?
# ?  PRIMARY_ARCHITECTURAL_STYLE_OF  ?  ?
# ?  PRIMARY_ARCHITECTURAL_STYLE_OF  Building Where First United States Congress Met  ?
#
#
#
# Query: What was the jersey number of the player who won the NBA MVP award in 2011?
# Suggested entity-relations:
# ?  WON_AWARD  NBA MVP 2011
# ?  OWNED_JERSEY_NUMBER  ? ?
#
#
#
# Query: Who was the surgeon that performed the first implantation of the first artificial heart?
# Suggested entity-relations:
# ?  PERFORMED_SURGERY_FOR  First Artificial Heart Implantation  ?
# Doctor ?  PERFORMED  First Artificial Heart Implantation  ?
# ?  PERFORMED  First Artificial Heart Implantation  propertiesOfRelation
#
#
#
# Query: Who was the captain of the team that won the Rugby World Cup in 2007?
# Suggested entity-relations:
# ?  CAPTAIN_OF_TEAM  ?  Rugby World Cup 2007
# ?  WON_RUGBY_WORLD_CUP  ?  2007
# ?  PLAYER_OF_TEAM  ?  Rugby World Cup 2007
# ?  PARTICIPATED_IN  Rugby World Cup 2007
# ?  LEADER_OF_TEAM  ?  Rugby World Cup 2007
#
#
#
# Query: What is the primary language spoken in the country that won the Rugby World Cup in 2007?
# Suggested entity-relations:
# ? WINNER_OF Rugby World Cup 2007
# ? PRIMARY_LANGUAGE ? ?
#
#
#
# Query: What was the primary color of the match t-shirt of the team that won the UEFA Europa League in 2013?
# Suggested entity-relations:
# ?  WINNER_OF  UEFA Europa League  2013
# ?  PRIMARY_COLOR_OF  ?  match t-shirt
# ?  MATCH_T_SHIRT_COLOR_OF  WINNING_TEAM  ? 2013 UEFA Europa League
#
#
#
# Query: Who was the main character in the novel that won the Pulitzer Prize for Fiction in 1980?
# Suggested entity-relations:
# ?  MAIN_CHARACTER_IN  ?  won Pulitzer Prize for Fiction in 1980
# ?  WON  Pulitzer Prize for Fiction 1980
# ?  MAIN_CHARACTER_IN  novel  Pulitzer Prize for Fiction 1980
# novel  WON  Pulitzer Prize for Fiction 1980
# ?  MAIN_CHARACTER_IN  novel  won Pulitzer Prize for Fiction 1980
#
#
#
# Query: What was the primary language spoken in the country that hosted the Winter Olympics in 1998?
# Suggested entity-relations:
#  ? HOSTED  Winter Olympics 1998
#  Winter Olympics 1998 HOSTED_BY ?
#  ? PRIMARY_LANGUAGE ? Winter Olympics 1998
#  ? HOSTED Winter Olympics 1998 primary_language ?
#  Winter Olympics 1998 HOSTED_BY ? primary_language ?
#
#
#
# Query: What was the primary color of the team that won the Super Bowl in 2018?
# Suggested entity-relations:
# ? WON Super Bowl 2018
# ? PRIMARY_COLOR ? team that won the Super Bowl in 2018
#
#
#
# Query: Who was the captain of the team that won the Super Bowl in 2018
# Suggested entity-relations:
# ?  CAPTAIN_OF  ?  2018 Super Bowl winner
# ?  WON  Super Bowl 2018
# ?  CAPTAIN_OF  ?  Super Bowl 2018
# ?  TEAM_CAPTAIN  ?  2018 Super Bowl winner
#
#
#
# Query: Who was the manager of the team that won the FIFA World Cup in 1994?
# Suggested entity-relations:
# ?  MANAGER_OF  ?  FIFA World Cup 1994 winner
# FIFA World Cup 1994 winner  MANAGER_IS  ?
#
#
#
# Query: What was the primary color of the team that won the FIFA World Cup in 1994?
# Suggested entity-relations:
# ?  WINNER_OF  FIFA World Cup 1994
# ?  PRIMARY_COLOR_OF  ? 1994
# ?  COLOR_OF_TEAM_OF_WINNER  ? 1994
#
#
#
# Query: What was the primary match t-shirt color of the team that won the Copa Libertadores in 2015?
# Suggested entity-relations:
# ? PRIMARY_MATCH_TSHIRT_COLOR ? 2015
# ? WON ? 2015 Copa Libertadores
# ? PRIMARY_MATCH_TSHIRT_COLOR ? propertiesOfWinningTeam
# ? TEAM_WON 2015 Copa Libertadores
#
#
#
# Query: What was the primary language spoken in the country that hosted the Eurovision Song Contest in 2010?
# Suggested entity-relations:
# ?  HOSTED_EUROVISION_CONTEST  ?  2010
# ?  PRIMARY_LANGUAGE_SPOKEN  ?  ?
# ?  HOSTED_EUROVISION_CONTEST  ?  ?
# ?  HOSTED_EUROVISION_CONTEST  ?
# ?  PRIMARY_LANGUAGE_SPOKEN  ?
#
#
#
# Query: Who was the captain of the team that won the Stanley Cup in 2008?
# Suggested entity-relations:
# ?  CAPTAIN_OF  ?  Stanley Cup 2008
# ?  WON  Stanley Cup  2008
# ?  CAPTAIN_OF  ?  2008
# Detroit Red Wings  CAPTAIN_OF  ?  2008
# Detroit Red Wings  WON  Stanley Cup  2008
#
#
#
# Query: What was primary position of the captain of the team that won the Stanley Cup in 2008?
# Suggested entity-relations:
# ? CAPTAIN_OF ? Stanley Cup 2008
# ? PRIMARY_POSITION_OF ? CAPTAIN
# ? WINNER_OF Stanley Cup 2008 ?
# Stanley Cup WINNER_TEAM 2008 ?
# Stanley Cup 2008 CAPTAIN ? PRIMARY_POSITION ?
#
#
#
# Query: What was the primary diet of the largest carnivorous dinosaur discovered?
# Suggested entity-relations:
# ?  PRIMARY_DIET_OF  ? propertiesOfRelation
# ?  PRIMARY_DIET_OF  largest_carnivorous_dinosaur propertiesOfRelation
# largest_carnivorous_dinosaur  PRIMARY_DIET ? propertiesOfRelation
# largest_carnivorous_dinosaur  DIET ? propertiesOfRelation
#
#
#
# Query: Where was the largest carnivorous dinosaur found?
# Suggested entity-relations:
# ?  DISCOVERED_IN  ?
# ?  LARGEST_CARNIVOROUS_DINOSAUR_FOUND_IN  ?
# ?  FOUND_IN  ?
# Largest_carnivorous_dinosaur  DISCOVERY_LOCATION  ?
#
#
#
# Query: What was the primary color of the team that won the FA Cup in 2006?
# Suggested entity-relations:
# ?  WON_FA_CUP_IN  2006  propertiesOfRelation
# ?  PRIMARY_COLOR  ?  ?
#
#
#
# Query: Who was the architect of the building where the first modern Olympic Games were held?
# Suggested entity-relations:
# ?  ARCHITECT_OF  ?  ?
# ?  ARCHITECT_OF  ?  first modern Olympic Games
# first modern Olympic Games  HELD_AT  ?  ?
# ?  ARCHITECT  ?  first modern Olympic Games
# ?  ARCHITECT  ?  building
#
#
#
# Query: What was the primary architectural style of the building where the first modern Olympic Games were held?
# Suggested entity-relations:
# ?  PRIMARY_ARCHITECTURAL_STYLE_OF  ?  first modern Olympic Games
# first modern Olympic Games  HELD_AT  ?  ?
# ?  PRIMARY_ARCHITECTURAL_STYLE_OF  ?  building where the first modern Olympic Games were held
# first modern Olympic Games  HELD_AT  building with architectural style  ?
# building with architectural style  HOSTED  first modern Olympic Games  ?
#
#
#
# Query: Who was the captain of the team that won the Copa America in 2011?
# Suggested entity-relations:
# ?  CAPTAIN_OF  Team  Copa America 2011 Winners
# Team  CAPTAIN_OF  ?  2011 Copa America Winners
# Team  WON  Copa America  Captain 2011
# ?  WON_AS_CAPTAIN  Copa America 2011
# ?  CAPTAIN_OF  Copa America 2011 winning team
#
#
#
# Query: What was primary position of the captain of the team that won the Copa America in 2011?
# Suggested entity-relations:
# Uruguay CAPTAIN_OF Copa America 2011
# ? CAPTAIN_OF_TEAM Uruguay Copa America 2011
# ? PRIMARY_POSITION ? CAPTAIN_OF_TEAM Uruguay
#
#
#
# Query: What was the primary color of the jersey worn by the team that won the FIFA World Cup in 2006?
# Suggested entity-relations:
# ?  PRIMARY_COLOR_OF_JERSEY  TeamWonFIFAWorldCup2006  ?
# TeamWonFIFAWorldCup2006  PRIMARY_COLOR_OF_JERSEY  ?  ?
# Italy  PRIMARY_COLOR_OF_JERSEY  ?  2006 FIFA World Cup
# Italy  WON_FIFA_WORLD_CUP  2006  ?
# Italy  PRIMARY_COLOR_OF_JERSEY  ?  ?
#
#
#
# Query: Who was captain of the team that won the FIFA World Cup in 2006?
# Suggested entity-relations:
# ?  CAPTAIN_OF  Team_that_won_FIFA_World_Cup  2006
# ?  CAPTAIN_OF  Italy_national_team  2006_FIFA_World_Cup
#
#
#
# Query: In which continent were the largest herbivorous dinosaur fossils discovered?
# Suggested entity-relations:
# ?  FOSSIL_DISCOVERED_IN  ?  largest herbivorous dinosaur
# largest herbivorous dinosaur  FOSSIL_DISCOVERED_IN  ?  ?
# ?  FOSSIL_DISCOVERED_IN  ?  ? continent largest herbivorous dinosaur
# largest herbivorous dinosaur  FOSSIL_DISCOVERED_IN  ?  continent
# largest herbivorous dinosaur  DISCOVERED_IN  ?  continent
#
#
#
# Query: What was the primary material used in the construction of the Statue of Liberty, and who was the sculptor?
# Suggested entity-relations:
# Statue of Liberty  PRIMARY_MATERIAL  ? ?
# ?  SCULPTOR_OF  Statue of Liberty ?
#
#
#
# Query: Who was the manager of the team that won the UEFA Champions League in 2013?
# Suggested entity-relations:
# ?  MANAGER_OF  ?  2013 UEFA Champions League winner
# ?  MANAGER_OF  Bayern Munich  2013 UEFA Champions League
# Bayern Munich  WON  UEFA Champions League  2013
# ?  MANAGER_OF  Bayern Munich  won 2013 UEFA Champions League
# Bayern Munich  WINNER_OF  UEFA Champions League  2013
#
#
#
# Query: What was the primary color of the team that won the UEFA Champions League in 2013?
# Suggested entity-relations:
# ? WON UEFA Champions League 2013
# ? PRIMARY_COLOR_OF ? Red
# Bayern Munich WON UEFA Champions League 2013
#
#
#
# Query: What was the primary language spoken in the country that hosted the World Expo in 1967
# Suggested entity-relations:
# ? HOSTED World Expo 1967 propertiesOfRelation
# World Expo 1967 HOSTED_BY ? propertiesOfRelation
# ? PRIMARY_LANGUAGE_OF ? propertiesOfRelation
#
#
#
# Query: What was the primary architectural style of the building where the Nuremberg Trials took place?
# Suggested entity-relations:
# ?  PRIMARY_ARCHITECTURAL_STYLE_OF  Nuremberg Trials Building  ?
#
#
#
# Query: In which country is the building where the Nuremberg Trials took place located?
# Suggested entity-relations:
# Nuremberg Trials LOCATED_IN ? ?
# ? LOCATED_IN Nuremberg Trials ?
# Building Nuremberg Trials LOCATED_IN ?
# Nuremberg Trials HELD_IN Building ?
# ? COUNTRY_OF Nuremberg Trials Building ?
#
#
#
# Query: Who was the main character in the novel that won the Pulitzer Prize for Fiction in 1975?
# Suggested entity-relations:
# ?  MAIN_CHARACTER_IN  ?  novel won Pulitzer Prize for Fiction 1975
# ?  WON_PULITZER_PRIZE_FOR_FICTION  1975 ?
# ?  WON_PULITZER_PRIZE_FOR_FICTION  ? ?
# ?  MAIN_CHARACTER_IN  ? ?
# novel  WON_PULITZER_PRIZE_FOR_FICTION  1975 ?
#
#
#
# Query: What was the main theme of the novel that won the Pulitzer Prize for Fiction in 1975?
# Suggested entity-relations:
# ? WINNER_OF Pulitzer_Prize_for_Fiction 1975 ?
# ? MAIN_THEME_OF ? 1975 Pulitzer_Prize_for_Fiction_winner
#
#
#
# Query: What was the primary material used in the construction of the Hoover Dam, and who was the president of the United States at the time?
# Suggested entity-relations:
# ?  PRIMARY_MATERIAL_USED  Hoover Dam  ?
# ?  PRESIDENT_DURING_CONSTRUCTION  Hoover Dam  ?
#
#
#
# Query: What was the primary color of the team that won the UEFA Europa League in 2017?
# Suggested entity-relations:
# 2017 UEFA Europa League  WINNER  ?
# ?  TEAM_COLOR  2017 UEFA Europa League WINNER
# ?  PRIMARY_COLOR  2017 UEFA Europa League WINNER
# 2017 UEFA Europa League WINNER  PRIMARY_COLOR  ?
# ?  WINNER_OF  2017 UEFA Europa League
#
#
#
# Query: Who was captain of the team that won the UEFA Europa League in 2017?
# Suggested entity-relations:
# ?  CAPTAIN_OF  team  2017 UEFA Europa League
# ?  WINNER_OF  UEFA Europa League  2017
# ?  CAPTAIN_OF_WINNER  UEFA Europa League  2017
# team  CAPTAIN  ?  2017 UEFA Europa League
# ?  CAPTAIN_OF  ?  2017 UEFA Europa League winner team
#
#
#
# Query: What was the primary language spoken in the country that won the FIFA Women's World Cup in 2011?
# Suggested entity-relations:
# ?  WON  FIFA Womens World Cup 2011
# FIFA Womens World Cup 2011  LANGUAGE_SPOKEN  ?
# ?  PRIMARY_LANGUAGE  ?  country_that_won_FIFA_Womens_World_Cup_2011
#
#
#
# Query: What was the primary material used in the construction of the Sydney Opera House, and who was the architect?
# Suggested entity-relations:
# ?  PRIMARY_MATERIAL_USED_IN  Sydney Opera House  ?
# ?  ARCHITECT_OF  Sydney Opera House  ?
#
#
#
# Query: What was the primary color of the match t-shirt of the team that won the English Premier League in 2016?
# Suggested entity-relations:
# Leicester City  WON  English Premier League  2016 season
# Leicester City  TEAM_COLOR  ?  2016 season
#
#
#
# Query: Who was the manager of the team that won the FIFA World Cup in 1986?
# Suggested entity-relations:
# ?  MANAGER_OF_TEAM  ?  1986 FIFA World Cup
# Argentina  MANAGER_OF_TEAM  ?  1986 FIFA World Cup
# ?  MANAGED_BY  ?  1986 FIFA World Cup
# ?  WON  1986 FIFA World Cup  MANAGED_BY ?
#
#
#
# Query: What was the primary color of the team that won the FIFA World Cup in 1986?
# Suggested entity-relations:
# ?  WON  1986 FIFA World Cup  ?
# 1986 FIFA World Cup  PRIMARY_COLOR  ?  ?
# Team  WON  1986 FIFA World Cup  PRIMARY_COLOR  ?
#
#
#
# Query: What was the primary language spoken in the country that won the Rugby World Cup in 1999?
# Suggested entity-relations:
# 1999 RUGBY_WORLD_CUP_WINNER ? ? ?
# ? PRIMARY_LANGUAGE ? ?
# ? PRIMARY_LANGUAGE 1999_RUGBY_WORLD_CUP_WINNER ?
# ? SPEAKS_PRIMARY_LANGUAGE ? ?
# RUGBY_WORLD_CUP_WINNER SPEAKS ? LANGUAGE
#
#
#
# Query: Who was captain of the team that won the Rugby World Cup in 1999?
# Suggested entity-relations:
# ?  CAPTAIN_OF  ?  Rugby World Cup 1999
# ?  WON  Rugby World Cup 1999  ?
# Rugby World Cup 1999  CAPTAIN_OF  ?
# ?  CAPTAIN_OF_TEAM  ?  Rugby World Cup 1999
# Rugby World Cup 1999  WON_BY  ?
#
#
#
# Query: What was the primary architectural style of the palace where the Potsdam Conference took place?
# Suggested entity-relations:
# Potsdam Conference TOOK_PLACE_IN ? ?
# ? LOCATED_AT Palace ?
# Palace ARCHITECTURAL_STYLE ? ?
#
#
#
# Query: In which country was the palace where the Potsdam Conference took place, located?
# Suggested entity-relations:
# ? HELD_AT ?
# Potsdam_Conference HELD_AT ?
# Potsdam_Conference LOCATION ?
# ? LOCATED_IN ?
#
#
#
# Query: What was the primary material used in the construction of the Leaning Tower of Pisa, and who was the architect?
# Suggested entity-relations:
# ?  PRIMARY_MATERIAL_USED  Leaning Tower of Pisa  ?
# ?  ARCHITECT_OF  Leaning Tower of Pisa  ?
#
#
#
# Query: What was the primary diet of the largest predator in the Atlantic Ocean?
# Suggested entity-relations:
# ?  PRIMARY_DIET_OF  largest predator in the Atlantic Ocean  ?
# largest predator in the Atlantic Ocean  PRIMARY_DIET  ?  ?
# largest predator in the Atlantic Ocean  DIET  ?  ?
#
#
#
# Query: What is scientific name of the largest predator in the Atlantic Ocean?
# Suggested entity-relations:
# ?  SCIENTIFIC_NAME_OF  the largest predator in the Atlantic Ocean  ?
# the largest predator in the Atlantic Ocean  SCIENTIFIC_NAME  ?  ?
#
#
#
# Query: Who was the captain of the team that won the NBA Finals in 2020?
# Suggested entity-relations:
# ?  CAPTAIN_OF  ?  NBA Finals 2020 Winners
# ?  CAPTAIN_OF  ?  2020 NBA Finals Winner
# ?  CAPTAIN_OF  ?  Los Angeles Lakers 2020
# ?  LEADER_OF  ?  2020 NBA Champions
# ?  CAPTAIN_OF  ?  NBA Champions 2020
#
#
#
# Query: What was the primary color of the team that won the NBA Finals in 2020?
# Suggested entity-relations:
# ?  WINNER_OF  NBA Finals  2020
# NBA Finals 2020 HAS_TEAM_COLOR ? ?
# Lakers  PRIMARY_COLOR  ?  2020
# ?  HAS_WON  NBA Finals  2020
# ?  HAS_COLOR  Lakers  2020
#
#
#
# ...
# Suggested entity-relations:
# ?  HOSTED_OLYMPICS_IN  ?  1972 Summer Olympics
# ?  COUNTRY_LANGUAGE  ?  ?
# Munich  HOSTED_OLYMPICS_IN  ?  ?
# ?  EVENT_HOST_CITY  Munich  ?
#
#
#
# Query: Who was the top scorer for the team that won the La Liga in 2020?
# Suggested entity-relations:
# ?  TOP_SCORER_IN  ?  2020 La Liga season
# ?  TOP_SCORER_IN  Real Madrid  2020 La Liga season
# Real Madrid  WON_LA_LIGA  ?  2020 La Liga season
# ?  IS_TOP_SCORER  Real Madrid  2020 La Liga season
#
#
#
# Query: What was primary jersey color of the team that won the La Liga in 2020?
# Suggested entity-relations:
# ?  WON_LA_LIGA  ?  2020
# ?  PRIMARY_JERSEY_COLOR  ?  2020
#
#
#
# Query: Who was the captain of the team that won the FIFA Women's World Cup in 2015?
# Suggested entity-relations:
# ?  CAPTAIN_OF  ?  2015 FIFA Womens World Cup winner
# ?  CAPTAIN_OF  2015 FIFA Womens World Cup winner  ?
# ?  CAPTAIN_OF  ?  2015 FIFA Womens World Cup
# ?  CAPTAIN_OF  ?  2015 FIFA Womens World Cup
# ?  CAPTAIN_OF  2015 FIFA Womens World Cup  ?
#
#
#
# Query: What was primary jersey color of the team that won the FIFA Women's World Cup in 2015?
# Suggested entity-relations:
# ?  PRIMARY_JERSEY_COLOR  Team_that_won_FIFA_Womens_World_Cup_2015  ?
# Team_that_won_FIFA_Womens_World_Cup_2015  PRIMARY_JERSEY_COLOR  ?  ?
#
#
#
# Query: What was the primary language spoken in the country that hosted the Winter Olympics in 1994?
# Suggested entity-relations:
# ? HOSTED  Winter Olympics 1994
# ? PRIMARY_LANGUAGE_SPOKEN ? ?
# ? PRIMARY_LANGUAGE_SPOKEN Norway ?
#
#
#
# Query: Who was the top scorer for the team that won the UEFA Europa League in 2020?
# Suggested entity-relations:
# ?  TOP_SCORER_FOR  ?  2020 UEFA Europa League
# ?  TOP_SCORER_FOR  TeamThatWonUEFAEuropaLeague  2020 season
# TopScorer  TOP_SCORER_FOR  ?  2020 UEFA Europa League
# ?  TOP_SCORER_FOR  WinningTeamOfUEFAEuropaLeague  2020 season
# ?  TOP_SCORER  ?  2020 UEFA Europa League
#
#
#
# Query: What was the primary language spoken in the country that hosted the Summer Olympics in 1996?
# Suggested entity-relations:
# ? HOSTED_SUMMER_OLYMPICS_IN ? 1996
# ? PRIMARY_LANGUAGE_SPOKEN ? ?
#
#
#
# Query: Who was the captain of the team that won the Premier League in 2018?
# Suggested entity-relations:
# ?  CAPTAIN_OF  ?  Premier League 2018
# ?  WON  Premier League  Premier League 2018
# ?  CAPTAIN_OF  ?  2018
# ?  WON  Premier League  2018
# ?  CAPTAIN_OF  TEAM  ?  Premier League 2018
#
#
#
# Query: Who was the top scorer for the team that won the Serie A in 2021
# Suggested entity-relations:
# ?  TOP_SCORER_IN  ?  2021 Serie A season
#
#
#
# Query: Who was the captain of the team that won the Copa del Rey in 2020?
# Suggested entity-relations:
# ?  CAPTAIN_OF  ?  Copa del Rey 2020
# ?  WON  Copa del Rey 2020  ?
# ?  LEADER_OF  ?  Copa del Rey 2020
# Team ?  WINNER_OF  Copa del Rey 2020
# ?  HELD_TITLE  ?  Copa del Rey 2020
#
#
#
# Query: What was the primary language spoken in the country that hosted the Summer Olympics in 1984?
# Suggested entity-relations:
# ?  HOSTED  Summer Olympics 1984
# ?  HOSTED  Summer Olympics ?  ?
# ?  PRIMARY_LANGUAGE_SPOKEN  ?
#
#
#
# Query: What was the primary language spoken in the country that hosted the Winter Olympics in 1988?
# Suggested entity-relations:
# ?  HOSTED  Winter Olympics 1988
# Winter Olympics 1988  HOSTED_BY  ?
# ?  PRIMARY_LANGUAGE  ?  host_country
# host_country  PRIMARY_LANGUAGE  ?
# Winter Olympics 1988  PRIMARY_LANGUAGE  ?
#
#
#
# Query: What was the primary match t-shirt color of the team that won the MLS Cup in 2020?
# Suggested entity-relations:
# ?  PRIMARY_MATCH_T_SHIRT_COLOR  ?  team=team_that_won_the_MLS_Cup_2020
#
#
#
# Query: What was the primary language spoken in the country that hosted the World Expo in 2010?
# Suggested entity-relations:
# ? HOSTED_WORLD_EXPO  2010  ?
# ? PRIMARY_LANGUAGE_SPOKEN_IN ? ?
# 2010 HOSTED_WORLD_EXPO ? ?
# ? HOSTED_WORLD_EXPO World Expo 2010
# ? PRIMARY_LANGUAGE_SPOKEN ? ?
#
#
#
# Query: What was the primary architectural style of the building where the Treaty of Ghent was signed?
# Suggested entity-relations:
# Treaty of Ghent  SIGNING_LOCATION  ?  ?
# ?  ARCHITECTURAL_STYLE  ?  ?
# ?  ARCHITECTURAL_STYLE  Treaty of Ghent SIGNING_LOCATION  ?
# Treaty of Ghent SIGNING_LOCATION ARCHITECTURAL_STYLE ?
# `?` LOCATED_IN `?` `?`
#
#
#
# Query: What was the primary match t-shirt color of the team that won the Copa del Rey in 2022?
# Suggested entity-relations:
# Copa del Rey 2022  WON_BY  ?
# ?  PRIMARY_COLOR  ?  Copa del Rey 2022 winner
# ?  MATCH_T_SHIRT_COLOR  Copa del Rey 2022 winner  PRIMARY
#
#
#
# Query: What was the primary diet of the largest marsupial found in Australia?
# Suggested entity-relations:
# ?  DIET_OF  largest marsupial found in Australia  ?
#
#
#
# Query: What was the primary language spoken in the country that won the Eurovision Song Contest in 2016?
# Suggested entity-relations:
# ?  WON  Eurovision Song Contest 2016
# Eurovision Song Contest 2016  ?  ? ? ? ?
# ?  OFFICIAL_LANGUAGE_OF  ?
# ?  PRIMARY_LANGUAGE_OF  ?
# ?  SPOKEN_LANGUAGE_IN  ?
#
#
#
# Query: What was the primary match t-shirt color of the team that won the French Cup in 2021?
# Suggested entity-relations:
# ?  PRIMARY_MATCH_TSHIRT_COLOR_OF  ?  2021 French Cup
# ?  WINNER_OF  French Cup  2021
# ?  TEAM_COLOR  ?  2021 MATCH
#
#
#
# Query: What was the primary architectural style of the building where the Yalta Conference was held?
# Suggested entity-relations:
# Yalta Conference HELD_IN ?
# ? LOCATED_IN Livadia Palace
# Livadia Palace ARCHITECTURAL_STYLE ?
# Livadia Palace HAS_EVENT Yalta Conference
# Yalta Conference LOCATED_IN Livadia Palace
#
#
#
# Query: What was the primary mission of the space probe that first visited Pluto?
# Suggested entity-relations:
# ?  PRIMARY_MISSION_OF  ?  first probe to visit Pluto
# ?  PRIMARY_MISSION_OF  space probe  first visited Pluto
# first probe to visit Pluto  PRIMARY_MISSION  ?  ?
# space probe  PRIMARY_MISSION  ?  first visited Pluto
#
#
#
# Query: What was the primary language spoken in the country that hosted the FIFA Confederations Cup in 2013?
# Suggested entity-relations:
# ? HOSTED_CONFEDERATIONS_CUP  ?  2013 FIFA Confederations Cup
# ? OFFICIAL_LANGUAGE_OF ? propertiesOfLanguage
# Brazil HOSTED_CONFEDERATIONS_CUP ? 2013 FIFA Confederations Cup
# ? HOSTED_CONFEDERATIONS_CUP  Brazil ?
# Portuguese OFFICIAL_LANGUAGE_OF Brazil ?
#
#
#
# Query: What was the primary match t-shirt color of the team that won the English Premier League in the 2020-2021 season?
# Suggested entity-relations:
# ?  PRIMARY_MATCH_T_SHIRT_COLOR  English Premier League 2020-2021 season
# ?  WINNER_OF  English Premier League  2020-2021 season
# ?  color_of_uniform  Team_that_won 2020-2021 English Premier League
# Team_that_won_the_2020-2021_EPL  PRIMARY_MATCH_T_SHIRT_COLOR  ?
# Team_that_won_the_2020-2021_EPL  UNIFORM_COLOR  ?
#
#
#
# Query: What was the primary diet of the largest predator found in the Amazon rainforest?
# Suggested entity-relations:
# ?  PRIMARY_DIET  largest predator found in the Amazon rainforest ?
# largest predator found in the Amazon rainforest  HAS_DIET  ? ?
# largest predator found in the Amazon rainforest  FEEDS_ON  ? ?
# largest predator found in the Amazon rainforest  EATS  ? ?
# largest predator found in the Amazon rainforest  CONSUMES  ? ?
#
#
#
# Query: What was the primary material used in the construction of the first successful human-powered flight vehicle?
# Suggested entity-relations:
# ?  PRIMARY_MATERIAL_USED_IN  first_successful_human_powered_flight_vehicle  ?
# first_successful_human_powered_flight_vehicle  CONSTRUCTED_WITH_MATERIAL  ?  ?
# first_successful_human_powered_flight_vehicle  MAKER  ?  is_constructed_of:primary_material
# first_successful_human_powered_flight_vehicle  HAS_PRIMARY_MATERIAL  ?  ?
# ?  USED_IN_CONSTRUCTION_OF  first_successful_human_powered_flight_vehicle  primary_material
#
#
#
# Query: What was the primary language spoken in the country that hosted the Commonwealth Games in 2018?
# Suggested entity-relations:
# ? HOSTED Commonwealth Games 2018
# ? SPOKEN_IN ? primary_language
# Commonwealth Games 2018 HOSTED_BY ?
# ? PRIMARY_LANGUAGE ?
#
#
#
# Query: What was the primary match t-shirt color of the team that won the Scottish Premiership in 2020?
# Suggested entity-relations:
# ?  WON  Scottish Premiership 2020
# ?  PRIMARY_MATCH_T_SHIRT_COLOR  ?  2020 Scottish Premiership Scottish Premiership winners
# Scottish Premiership  WINNER  ?  2020
# ?  T_SHIRT_COLOR  ?  2020 Scottish Premiership winner
#
#
#
# Query: What was the primary architectural style of the building where the Congress of the Confederation was held?
# Suggested entity-relations:
# ?  ARCHITECTURAL_STYLE_OF  ?  Congress of the Confederation
# Congress of the Confederation  HELD_IN  ?  primary architectural style
# Building where Congress of the Confederation was held  ARCHITECTURAL_STYLE  ?
# Congress of the Confederation  HELD_IN  Building with ? architectural style
# Building where Congress of the Confederation was held  ?  primary architectural style
#
#
#
# Query: What was the primary language spoken in the country that hosted the FIFA U-20 World Cup in 2017?
# Suggested entity-relations:
# ? HOSTED FIFA_U-20_WORLD_CUP 2017 ?
# ? PRIMARY_LANGUAGE_SPOKEN  ? ?
#
#
#
# Query: What was the primary diet of the largest carnivorous mammal found in South America?
# Suggested entity-relations:
# ?  PRIMARY_DIET_OF  largest_carnivorous_mammal_South_America  ?
# largest_carnivorous_mammal_South_America  DIET_INCLUDES  ?  ?
# largest_carnivorous_mammal_South_America  PRIMARY_DIET  ?  ?
# ?  DIETARY_PREFERENCES  largest_carnivorous_mammal_South_America  ?
# largest_carnivorous_mammal_South_America  CONSUMES  ?  ?
#
#
#
# Query: What was the primary material used in the construction of the spacecraft that first orbited Mercury?
# Suggested entity-relations:
# ?  PRIMARY_MATERIAL_USED  ? ?
# ?  PRIMARY_MATERIAL_USED_IN_CONSTRUCTION  ?
# ?  MATERIAL_USED_IN  ? ?
# ?  MATERIAL_USED_IN_CONSTRUCTION  ?
# ?  PRIMARY_CONSTRUCTION_MATERIAL  ?
#
#
#
# Query: What was the primary architectural style of the building where the Kellogg-Briand Pact was signed?
# Suggested entity-relations:
# ?  PRIMARY_ARCHITECTURAL_STYLE_OF  ?  propertiesOfRelation
# Kellogg-Briand Pact  SIGNED_AT  ?  propertiesOfRelation
# ?  PRIMARY_ARCHITECTURAL_STYLE_OF  ?  Kellogg-Briand Pact signing location
# Building  PRIMARY_ARCHITECTURAL_STYLE_OF  Kellogg-Briand Pact signing location  ?
# Kellogg-Briand Pact signing location  HAS_ARCHITECTURAL_STYLE  ?  propertiesOfRelation
#
#
#
# Query: What was the primary material used in the construction of the first space station?
# Suggested entity-relations:
# ?  PRIMARY_MATERIAL_USED_IN_CONSTRUCTION  ?  first space station
# first space station  PRIMARY_MATERIAL_USED_IN_CONSTRUCTION  ?
# first space station  CONSTRUCTED_WITH  ?
# ?  MATERIAL_USED_IN  first space station
# first space station  BUILT_WITH  ?
#
#
#
# Query: What was the primary match t-shirt color of the team that won the DFB-Pokal in 2021?
# Suggested entity-relations:
# ? WINNER_OF DFB-Pokal 2021  ?
# ? TEAM_COLOR  ?  primary match t-shirt color
# ? WINNER_OF DFB-Pokal 2021  primary match t-shirt color
#
#
#
# Query: What was the primary architectural style of the building where the United States Constitution was drafted?
# Suggested entity-relations:
# ?  ARCHITECTURAL_STYLE_OF  Building_Where_US_Constitution_Was_Drafted  ?
# United_States_Constitution  DRAFTED_IN  ?  Architectural_Style
# Building_Where_US_Constitution_Was_Drafted  ARCHITECTURAL_FEATURE  ?  Architectural_Style
# Independence_Hall  LOCATION_OF  United_States_Constitution_Drafting  Architectural_Style
# ?  ARCHITECTURAL_STYLE_OF  Independence_Hall  ?
#
#
#
# Query: What was the primary match t-shirt color of the team that won the French Ligue 1 in 2020?
# Suggested entity-relations:
# ?  WON  French Ligue 1  2020
# ?  PRIMARY_COLOR  ?  2020
# ?  UNIFORM  ?  French Ligue 1 2020
# French Ligue 1  WON_BY  ?  2020
#
#
#
# Query: What was the primary diet of the largest herbivore found in South America?
# Suggested entity-relations:
# ? DIET_OF LARGEST_HERBIVORE_SOUTH_AMERICA ?
# LARGEST_HERBIVORE_SOUTH_AMERICA DIET ? ?
# ? LARGEST_HERBIVORE_SOUTH_AMERICA ? ?
# LARGEST_HERBIVORE_SOUTH_AMERICA HAS_DIET ? ?
# LARGEST_HERBIVORE_SOUTH_AMERICA PRIMARY_DIET ? ?
#
#
#
# Query: What was the primary match t-shirt color of the team that won the Copa Sudamericana in 2020?
# Suggested entity-relations:
# ? WON Copa Sudamericana 2020
# ? PRIMARY_MATCH_TSHIRT_COLOR ? Copa Sudamericana 2020
# ? WON ? Copa Sudamericana PRIMARY_MATCH_TSHIRT_COLOR
# 2020 Copa Sudamericana WON ? PRIMARY_MATCH_TSHIRT_COLOR
# ? WON ? Copa Sudamericana PRIMARY_MATCH_TSHIRT_COLOR ?
#
#
#
# Query: What was the primary language spoken in the country that hosted the 1986 FIFA World Cup?
# Suggested entity-relations:
# ? HOSTED 1986 FIFA World Cup ?
# 1986 FIFA World Cup PRIMARY_LANGUAGE ?
#
#
#
# Query: What was the primary architectural style of the building where the United States Bill of Rights was signed?
# Suggested entity-relations:
# ?  PRIMARY_ARCHITECTURAL_STYLE_OF  ?  United States Bill of Rights
# United States Bill of Rights  SIGNED_AT  ?  PRIMARY_ARCHITECTURAL_STYLE_OF
# United States Bill of Rights  PRIMARY_ARCHITECTURAL_STYLE_OF  ?  building
# building  PRIMARY_ARCHITECTURAL_STYLE  ?  United States Bill of Rights
# United States Bill of Rights  SIGNED_AT  building  PRIMARY_ARCHITECTURAL_STYLE
#
#
#
# Query: What was the primary material used in the construction of the first human-made object to reach the Moon?
# Suggested entity-relations:
# ?  MATERIAL_USED_IN_CONSTRUCTION  ? ?
# ?  MATERIAL_USED_IN_CONSTRUCTION  first_human_made_object_to_reach_the_Moon  ?
# first_human_made_object_to_reach_the_Moon  MATERIAL_USED_IN_CONSTRUCTION  ? ?
#
#
#
# Query: What was the primary match t-shirt color of the team that won the FA Women's Super League in 2020?
# Suggested entity-relations:
# ? WON_TITLE  ?  FA Womens Super League 2020
# ? PRIMARY_MATCH_T_SHIRT_COLOR ? ?
# ? PRIMARY_MATCH_T_SHIRT_COLOR ? FA Womens Super League 2020
#
#
#
# Query: What was the primary diet of the largest marine predator found in the Pacific Ocean?
# Suggested entity-relations:
# ?  PRIMARY_DIET_OF  largest marine predator  ?
# largest marine predator  FOUND_IN  Pacific Ocean  ?
# largest marine predator  DIET  ?  ?
# ?  DIET  largest marine predator  ?
#
#
#
# Query: What was the primary material used in the construction of the first successful passenger airplane?
# Suggested entity-relations:
# ?  PRIMARY_MATERIAL_USED  ? propertiesOfRelation
# First successful passenger airplane  PRIMARY_MATERIAL_USED  ? propertiesOfRelation
#
#
#
# Query: What was the primary match t-shirt color of the team that won the Eredivisie in 2021?
# Suggested entity-relations:
# ?  WINNER_OF  Eredivisie 2021
# ?  PRIMARY_MATCH_T_SHIRT_COLOR_OF  ?  Eredivisie 2021
# Eredivisie WINNER_IN ? PRIMARY_MATCH_T_SHIRT_COLOR_OF 2021
# ?  WINNER_OF  Eredivisie 2021 PRIMARY_MATCH_T_SHIRT_COLOR_OF ?
# ?  WINNER_OF  Eredivisie 2021 TEAM_COLOR ?  PRIMARY_MATCH_T_SHIRT
#
#
#
# Query: What was the primary architectural style of the building where the Declaration of the Rights of Man and of the Citizen was drafted?
# Suggested entity-relations:
# ? ARCHITECTURAL_STYLE_OF ?
# Declaration of the Rights of Man and of the Citizen DRAFTED_IN ?
# ? ARCHITECTURAL_STYLE_OF Declaration of the Rights of Man and of the Citizen
# ? ARCHITECTURAL_STYLE_OF building ?
# Declaration of the Rights of Man and of the Citizen CREATED_AT ?
#
#
#
# Query: What was the primary material used in the construction of the first skyscraper?
# Suggested entity-relations:
# ?  PRIMARY_MATERIAL_USED_IN_CONSTRUCTION  first skyscraper  ?
# first skyscraper  PRIMARY_MATERIAL  ?  ?
# ?  USED_IN_CONSTRUCTION  first skyscraper  ?
#
#
#
# Query: What was the primary language spoken in the country that won the UEFA Euro Championship in 2016?
# Suggested entity-relations:
# ?  WINNER_OF  UEFA Euro Championship 2016
# Portugal  PRIMARY_LANGUAGE  ?
#
#
#
# Query: What was the primary architectural style of the building where the Peace of Westphalia was signed?
# Suggested entity-relations:
# ?  SIGNED_AT  Peace_of_Westphalia  ?
# Peace_of_Westphalia  SIGNED_AT  ?  ?
# Building  ARCHITECTURAL_STYLE  ?  ?
# Peace_of_Westphalia  SIGNED_AT  ?  ARCHITECTURAL_STYLE ?
#
#
#
# Query: What was the primary language spoken in the country that hosted the FIFA Women's World Cup in 2019?
# Suggested entity-relations:
# ?  HOSTED  2019 FIFA Womens World Cup  ?
# ?  PRIMARY_LANGUAGE_SPOKEN_IN  ?  2019
# ?  HOSTS_PRIMARY_LANGUAGE  2019 FIFA Womens World Cup  ?

# %%
answers = []

for i, question in enumerate(questions):
    print(f"Query {i+1} out of {len(questions)}:")
    print(f"    - Query: {questions[i]}")
    print(f"    - Retrieved pairs:")
    query_embeddings = [np.array(get_embedding(search_candidate)).reshape(1, -1) for search_candidate in suggested_entity_relations[i]]
    retrieved_pairs = []
    for suggestion in query_embeddings:
        D, I = index.search(np.array(suggestion).reshape(1, -1), k=5)
        for idx in I[0]:
            if idx != -1:
                print(f"      - {relations[idx]}")
                retrieved_pairs.append(relations[idx])
    answers.append("".join(generate_answer(question, retrieved_pairs)))
    print(f"    - Answer: {answers[-1]}")
# Out:
# Streaming output truncated to the last 5000 lines.
#       - ('Paris Saint-Germain', 'SHIRT_COLOUR', 'Blue', '')
#       - ('Real Madrid', 'SHIRT_COLOUR', 'White', '')
#       - ('Chelsea', 'SHIRT_COLOUR', 'Blue', '')
#       - ('Sevilla', 'WON', 'Uefa Europa League', '2020')
#       - ('Chelsea', 'WON', 'Champions League', '2021')
#       - ('Bayern Munich', 'WON', 'Bundesliga', '2020')
#       - ('Real Madrid', 'WON', 'Uefa Champions League', '2018')
#       - ('Real Madrid', 'WON', 'La Liga', '2020')
#       - ('Bayern Munich', 'SHIRT_COLOUR', 'Red', '')
#       - ('Chelsea', 'WON', 'Champions League', '2021')
#       - ('Paris Saint-Germain', 'SHIRT_COLOUR', 'Blue', '')
#       - ('Manchester United', 'SHIRT_COLOUR', 'Red', '')
#       - ('Chelsea', 'SHIRT_COLOUR', 'Blue', '')
#       - ('Bayern Munich', 'SHIRT_COLOUR', 'Red', '')
#       - ('Bayern Munich', 'WON', 'Bundesliga', '2020')
#       - ('Manuel Neuer', 'HAS_CAPTAINED', 'Bayern Munich', '2020')
#       - ('Bayern Munich', 'WON', 'Uefa Champions League', '2013')
#       - ('Borussia Dortmund', 'SHIRT_COLOUR', 'Yellow', '')
#       - ('Bayern Munich', 'WON', 'Bundesliga', '2020')
#       - ('Bayern Munich', 'WON', 'Uefa Champions League', '2013')
#       - ('Sevilla', 'WON', 'Uefa Europa League', '2020')
#       - ('Real Madrid', 'WON', 'La Liga', '2020')
#       - ('Borussia Dortmund', 'WON', 'Dfb-Pokal', '2021')
#
#
# ****************** generated prompt ******************
# RETRIEVED RELATIONS:
# Bayern Munich SHIRT_COLOUR Red
# Chelsea WON Champions League 2021
# Paris Saint-Germain SHIRT_COLOUR Blue
# Real Madrid SHIRT_COLOUR White
# Chelsea SHIRT_COLOUR Blue
# Sevilla WON Uefa Europa League 2020
# Chelsea WON Champions League 2021
# Bayern Munich WON Bundesliga 2020
# Real Madrid WON Uefa Champions League 2018
# Real Madrid WON La Liga 2020
# Bayern Munich SHIRT_COLOUR Red
# Chelsea WON Champions League 2021
# Paris Saint-Germain SHIRT_COLOUR Blue
# Manchester United SHIRT_COLOUR Red
# Chelsea SHIRT_COLOUR Blue
# Bayern Munich SHIRT_COLOUR Red
# Bayern Munich WON Bundesliga 2020
# Manuel Neuer HAS_CAPTAINED Bayern Munich 2020
# Bayern Munich WON Uefa Champions League 2013
# Borussia Dortmund SHIRT_COLOUR Yellow
# Bayern Munich WON Bundesliga 2020
# Bayern Munich WON Uefa Champions League 2013
# Sevilla WON Uefa Europa League 2020
# Real Madrid WON La Liga 2020
# Borussia Dortmund WON Dfb-Pokal 2021
#
# QUESTION:
# What was primary jersey color of the team that won the UEFA Champions League in 2020?
#
# INSTRUCTIONS:
# Answer the users QUESTION using the RETRIEVED RELATIONS above.
# Keep your answer ground in the facts of the RETRIEVED RELATIONS. it is guranteed retrieved relations are related to the question
# ******************************************************
#
#
#     - Answer: The team that won the UEFA Champions League in 2020 was Bayern Munich and their primary jersey color is red.
# Query 211 out of 296:
#     - Query: Who was the top scorer of the team that won the Copa America in 2019?
#     - Retrieved pairs:
#       - ('Luis Suárez', 'WON', '2011 Copa América', 'top scorer')
#       - ('Brazil', 'WON', 'Copa America', '2019')
#       - ('Lionel Messi', 'TOP_SCORER', 'Barcelona', '2019 La Liga season')
#       - ('Lionel Messi', 'TOP_SCORER_IN', 'Barcelona', '2018')
#       - ('Cristiano Ronaldo', 'TOP_SCORER_IN', '2014 Fifa Club World Cup', '')
#       - ('Brazil', 'WON', 'Copa America', '2019')
#       - ('Luis Suárez', 'WON', '2011 Copa América', 'top scorer')
#       - ('Lionel Messi', 'TOP_SCORER', 'Barcelona', '2019 La Liga season')
#       - ('Lionel Messi', 'TOP_SCORER_IN', 'Barcelona', '2018')
#       - ('Cristiano Ronaldo', 'TOP_SCORER_IN', '2014 Fifa Club World Cup', '')
#       - ('Brazil', 'WON', 'Copa America', '2019')
#       - ('Luis Suárez', 'WON', '2011 Copa América', 'top scorer')
#       - ('Lionel Messi', 'TOP_SCORER', 'Barcelona', '2019 La Liga season')
#       - ('Argentina', 'WON', 'Copa America', '2021')
#       - ('Lionel Messi', 'TOP_SCORER_IN', 'Barcelona', '2018')
#       - ('Lionel Messi', 'TOP_SCORER', 'Barcelona', '2019 La Liga season')
#       - ('Lionel Messi', 'TOP_SCORER_IN', 'Barcelona', '2018')
#       - ('Luis Suárez', 'WON', '2011 Copa América', 'top scorer')
#       - ('Brazil', 'WON', 'Copa America', '2019')
#       - ('Cristiano Ronaldo', 'TOP_SCORER_IN', '2014 Fifa Club World Cup', '')
#       - ('Brazil', 'WON', 'Copa America', '2019')
#       - ('Lionel Messi', 'TOP_SCORER', 'Barcelona', '2019 La Liga season')
#       - ('Luis Suárez', 'WON', '2011 Copa América', 'top scorer')
#       - ('Argentina', 'WON', 'Copa America', '2021')
#       - ('Lionel Messi', 'TOP_SCORER_IN', 'Barcelona', '2018')
#
#
# ****************** generated prompt ******************
# RETRIEVED RELATIONS:
# Luis Suárez WON 2011 Copa América top scorer
# Brazil WON Copa America 2019
# Lionel Messi TOP_SCORER Barcelona 2019 La Liga season
# Lionel Messi TOP_SCORER_IN Barcelona 2018
# Cristiano Ronaldo TOP_SCORER_IN 2014 Fifa Club World Cup
# Brazil WON Copa America 2019
# Luis Suárez WON 2011 Copa América top scorer
# Lionel Messi TOP_SCORER Barcelona 2019 La Liga season
# Lionel Messi TOP_SCORER_IN Barcelona 2018
# Cristiano Ronaldo TOP_SCORER_IN 2014 Fifa Club World Cup
# Brazil WON Copa America 2019
# Luis Suárez WON 2011 Copa América top scorer
# Lionel Messi TOP_SCORER Barcelona 2019 La Liga season
# Argentina WON Copa America 2021
# Lionel Messi TOP_SCORER_IN Barcelona 2018
# Lionel Messi TOP_SCORER Barcelona 2019 La Liga season
# Lionel Messi TOP_SCORER_IN Barcelona 2018
# Luis Suárez WON 2011 Copa América top scorer
# Brazil WON Copa America 2019
# Cristiano Ronaldo TOP_SCORER_IN 2014 Fifa Club World Cup
# Brazil WON Copa America 2019
# Lionel Messi TOP_SCORER Barcelona 2019 La Liga season
# Luis Suárez WON 2011 Copa América top scorer
# Argentina WON Copa America 2021
# Lionel Messi TOP_SCORER_IN Barcelona 2018
#
# QUESTION:
# Who was the top scorer of the team that won the Copa America in 2019?
#
# INSTRUCTIONS:
# Answer the users QUESTION using the RETRIEVED RELATIONS above.
# Keep your answer ground in the facts of the RETRIEVED RELATIONS. it is guranteed retrieved relations are related to the question
# ******************************************************
#
#
#     - Answer: The retrieved relations do not provide information on the top scorer of the team that won the Copa America in 2019. While Brazil is noted to have won the Copa America in 2019 no details about the top scorer for Brazil during that tournament are present in the retrieved relations.
# Query 212 out of 296:
#     - Query: What was primary jersey color of the team that won the Copa America in 2019?
#     - Retrieved pairs:
#       - ('Brazil', 'WON', 'Copa America', '2019')
#       - ('Argentina', 'WON', 'Copa America', '2021')
#       - ('Brazilian National Team', 'SHIRT_COLOUR', 'Yellow', '')
#       - ('Everton', 'WON', '2019 Copa America', 'Brazil')
#       - ('Argentina', 'SHIRT_COLOUR', 'Light Blue And White', '')
#       - ('Brazil', 'WON', 'Copa America', '2019')
#       - ('Brazilian National Team', 'SHIRT_COLOUR', 'Yellow', '')
#       - ('Brazil', 'HOSTED', 'Fifa World Cup', '2014')
#       - ('Uruguay', 'SHIRT_COLOUR', 'Sky Blue', '')
#       - ('Everton', 'WON', '2019 Copa America', 'Brazil')
#       - ('Brazil', 'WON', 'Copa America', '2019')
#       - ('Brazilian National Team', 'SHIRT_COLOUR', 'Yellow', '')
#       - ('Everton', 'WON', '2019 Copa America', 'Brazil')
#       - ('Flamengo', 'WON', 'Copa Libertadores', '2019')
#       - ('Argentina', 'WON', 'Copa America', '2021')
#
#
# ****************** generated prompt ******************
# RETRIEVED RELATIONS:
# Brazil WON Copa America 2019
# Argentina WON Copa America 2021
# Brazilian National Team SHIRT_COLOUR Yellow
# Everton WON 2019 Copa America Brazil
# Argentina SHIRT_COLOUR Light Blue And White
# Brazil WON Copa America 2019
# Brazilian National Team SHIRT_COLOUR Yellow
# Brazil HOSTED Fifa World Cup 2014
# Uruguay SHIRT_COLOUR Sky Blue
# Everton WON 2019 Copa America Brazil
# Brazil WON Copa America 2019
# Brazilian National Team SHIRT_COLOUR Yellow
# Everton WON 2019 Copa America Brazil
# Flamengo WON Copa Libertadores 2019
# Argentina WON Copa America 2021
#
# QUESTION:
# What was primary jersey color of the team that won the Copa America in 2019?
#
# INSTRUCTIONS:
# Answer the users QUESTION using the RETRIEVED RELATIONS above.
# Keep your answer ground in the facts of the RETRIEVED RELATIONS. it is guranteed retrieved relations are related to the question
# ******************************************************
#
#
#     - Answer: The team that won the Copa America in 2019 was Brazil. According to the retrieved relations the primary jersey color of the Brazilian National Team is yellow. Therefore the primary jersey color of the team that won the Copa America in 2019 was yellow.
# Query 213 out of 296:
#     - Query: Who was the manager of the team that won the FA Cup in 2018?
#     - Retrieved pairs:
#       - ('Chelsea', 'WON', 'Fa Cup', '2018')
#       - ('Manchester City', 'WON', 'Fa Cup', '2019')
#       - ('Manchester United', 'WON', 'Fa Cup', '2004')
#       - ('Liverpool', 'WON', 'Fa Cup', '2006')
#       - ('Manchester City', 'WON', 'Premier League', '2018')
#       - ('Chelsea', 'WON', 'Fa Cup', '2018')
#       - ('Manchester City', 'WON', 'Fa Cup', '2019')
#       - ('Leicester City', 'WON', 'Fa Cup', '2021')
#       - ('Manchester United', 'WON', 'Fa Cup', '2004')
#       - ('Manchester City', 'WON', 'Premier League', '2018')
#       - ('Chelsea', 'WON', 'Fa Cup', '2018')
#       - ('Manchester City', 'WON', 'Fa Cup', '2019')
#       - ('Liverpool', 'WON', 'Fa Cup', '2006')
#       - ('Manchester United', 'WON', 'Fa Cup', '2004')
#       - ('Manchester City', 'WON', 'Premier League', '2018')
#       - ('Chelsea', 'WON', 'Fa Cup', '2018')
#       - ('Manchester City', 'WON', 'Fa Cup', '2019')
#       - ('Manchester United', 'WON', 'Fa Cup', '2004')
#       - ('Liverpool', 'WON', 'Fa Cup', '2006')
#       - ('Leicester City', 'WON', 'Fa Cup', '2021')
#       - ('Chelsea', 'WON', 'Fa Cup', '2018')
#       - ('Manchester City', 'WON', 'Fa Cup', '2019')
#       - ('Leicester City', 'WON', 'Fa Cup', '2021')
#       - ('Manchester United', 'WON', 'Fa Cup', '2004')
#       - ('Liverpool', 'WON', 'Fa Cup', '2006')
#
#
# ****************** generated prompt ******************
# RETRIEVED RELATIONS:
# Chelsea WON Fa Cup 2018
# Manchester City WON Fa Cup 2019
# Manchester United WON Fa Cup 2004
# Liverpool WON Fa Cup 2006
# Manchester City WON Premier League 2018
# Chelsea WON Fa Cup 2018
# Manchester City WON Fa Cup 2019
# Leicester City WON Fa Cup 2021
# Manchester United WON Fa Cup 2004
# Manchester City WON Premier League 2018
# Chelsea WON Fa Cup 2018
# Manchester City WON Fa Cup 2019
# Liverpool WON Fa Cup 2006
# Manchester United WON Fa Cup 2004
# Manchester City WON Premier League 2018
# Chelsea WON Fa Cup 2018
# Manchester City WON Fa Cup 2019
# Manchester United WON Fa Cup 2004
# Liverpool WON Fa Cup 2006
# Leicester City WON Fa Cup 2021
# Chelsea WON Fa Cup 2018
# Manchester City WON Fa Cup 2019
# Leicester City WON Fa Cup 2021
# Manchester United WON Fa Cup 2004
# Liverpool WON Fa Cup 2006
#
# QUESTION:
# Who was the manager of the team that won the FA Cup in 2018?
#
# INSTRUCTIONS:
# Answer the users QUESTION using the RETRIEVED RELATIONS above.
# Keep your answer ground in the facts of the RETRIEVED RELATIONS. it is guranteed retrieved relations are related to the question
# ******************************************************
#
#
#     - Answer: The retrieved relations indicate that Chelsea won the FA Cup in 2018. The manager of Chelsea during their 2018 FA Cup victory was Antonio Conte.
# Query 214 out of 296:
#     - Query: What was the primary language spoken in the country that won the FIFA World Cup in 2010?
#     - Retrieved pairs:
#       - ('Spain', 'PRIMARY_LANGUAGE_SPOKEN_IN', 'Spanish', '')
#       - ('Portugal', 'PRIMARY_LANGUAGE_SPOKEN_IN', 'Portuguese', '')
#       - ('Mexico', 'PRIMARY_LANGUAGE_SPOKEN_IN', 'Spanish', '')
#       - ('United Kingdom', 'PRIMARY_LANGUAGE_SPOKEN_IN', 'English', '')
#       - ('Greece', 'PRIMARY_LANGUAGE_SPOKEN_IN', 'Greek', '')
#       - ('Spain', 'WON', '2010 Fifa World Cup', '')
#       - ('Spain', 'WON', 'Fifa World Cup', '2010')
#       - ('Spain', 'WON', 'Euro 2012', '')
#       - ('Spain', 'WON', 'Euro 2008', '')
#       - ('Spain', 'WON', 'Euro Cup', '2012')
#       - ('Spain', 'PRIMARY_LANGUAGE_SPOKEN_IN', 'Spanish', '')
#       - ('Portugal', 'PRIMARY_LANGUAGE_SPOKEN_IN', 'Portuguese', '')
#       - ('Mexico', 'PRIMARY_LANGUAGE_SPOKEN_IN', 'Spanish', '')
#       - ('English', 'PRIMARY_LANGUAGE_SPOKEN_IN', 'England', '')
#       - ('United States', 'PRIMARY_LANGUAGE_SPOKEN_IN', 'English', '')
#
#
# ****************** generated prompt ******************
# RETRIEVED RELATIONS:
# Spain PRIMARY_LANGUAGE_SPOKEN_IN Spanish
# Portugal PRIMARY_LANGUAGE_SPOKEN_IN Portuguese
# Mexico PRIMARY_LANGUAGE_SPOKEN_IN Spanish
# United Kingdom PRIMARY_LANGUAGE_SPOKEN_IN English
# Greece PRIMARY_LANGUAGE_SPOKEN_IN Greek
# Spain WON 2010 Fifa World Cup
# Spain WON Fifa World Cup 2010
# Spain WON Euro 2012
# Spain WON Euro 2008
# Spain WON Euro Cup 2012
# Spain PRIMARY_LANGUAGE_SPOKEN_IN Spanish
# Portugal PRIMARY_LANGUAGE_SPOKEN_IN Portuguese
# Mexico PRIMARY_LANGUAGE_SPOKEN_IN Spanish
# English PRIMARY_LANGUAGE_SPOKEN_IN England
# United States PRIMARY_LANGUAGE_SPOKEN_IN English
#
# QUESTION:
# What was the primary language spoken in the country that won the FIFA World Cup in 2010?
#
# INSTRUCTIONS:
# Answer the users QUESTION using the RETRIEVED RELATIONS above.
# Keep your answer ground in the facts of the RETRIEVED RELATIONS. it is guranteed retrieved relations are related to the question
# ******************************************************
#
#
#     - Answer: The primary language spoken in the country that won the FIFA World Cup in 2010 is Spanish. This is because the retrieved relations indicate that Spain won the FIFA World Cup in 2010 and the primary language spoken in Spain is Spanish.
# Query 215 out of 296:
#     - Query: Who was top scorer of the team that won the FIFA World Cup in 2010?
#     - Retrieved pairs:
#       - ('David Villa', 'TOP_SCORER_IN', 'Spain', '2010 FIFA World Cup')
#       - ('Spain', 'WON', 'Fifa World Cup', '2010')
#       - ('Spain', 'WON', '2010 Fifa World Cup', '')
#       - ('Cristiano Ronaldo', 'TOP_SCORER_IN', '2014 Fifa Club World Cup', '')
#       - ('Lionel Messi', 'TOP_SCORER_IN', 'Barcelona', '2018')
#       - ('Spain', 'WON', '2010 Fifa World Cup', '')
#       - ('Spain', 'WON', 'Fifa World Cup', '2010')
#       - ('Spain', 'WON', 'Euro 2012', '')
#       - ('Spain', 'WON', 'Euro Cup', '2012')
#       - ('Spain', 'WON', 'Euro 2008', '')
#       - ('David Villa', 'TOP_SCORER_IN', 'Spain', '2010 FIFA World Cup')
#       - ('Cristiano Ronaldo', 'TOP_SCORER_IN', '2014 Fifa Club World Cup', '')
#       - ('Golden Boot', 'AWARDED_TO', '2014 Fifa World Cup', '')
#       - ('Spain', 'WON', '2010 Fifa World Cup', '')
#       - ('Spain', 'WON', 'Fifa World Cup', '2010')
#       - ('David Villa', 'TOP_SCORER_IN', 'Spain', '2010 FIFA World Cup')
#       - ('Spain', 'WON', 'Fifa World Cup', '2010')
#       - ('Spain', 'WON', '2010 Fifa World Cup', '')
#       - ('Cristiano Ronaldo', 'TOP_SCORER_IN', '2014 Fifa Club World Cup', '')
#       - ('Lionel Messi', 'TOP_SCORER', 'Barcelona', '2019 La Liga season')
#       - ('David Villa', 'TOP_SCORER_IN', 'Spain', '2010 FIFA World Cup')
#       - ('Spain', 'WON', 'Fifa World Cup', '2010')
#       - ('Spain', 'WON', '2010 Fifa World Cup', '')
#       - ('Cristiano Ronaldo', 'TOP_SCORER_IN', '2014 Fifa Club World Cup', '')
#       - ('Golden Boot', 'AWARDED_TO', '2014 Fifa World Cup', '')
#
#
# ****************** generated prompt ******************
# RETRIEVED RELATIONS:
# David Villa TOP_SCORER_IN Spain 2010 FIFA World Cup
# Spain WON Fifa World Cup 2010
# Spain WON 2010 Fifa World Cup
# Cristiano Ronaldo TOP_SCORER_IN 2014 Fifa Club World Cup
# Lionel Messi TOP_SCORER_IN Barcelona 2018
# Spain WON 2010 Fifa World Cup
# Spain WON Fifa World Cup 2010
# Spain WON Euro 2012
# Spain WON Euro Cup 2012
# Spain WON Euro 2008
# David Villa TOP_SCORER_IN Spain 2010 FIFA World Cup
# Cristiano Ronaldo TOP_SCORER_IN 2014 Fifa Club World Cup
# Golden Boot AWARDED_TO 2014 Fifa World Cup
# Spain WON 2010 Fifa World Cup
# Spain WON Fifa World Cup 2010
# David Villa TOP_SCORER_IN Spain 2010 FIFA World Cup
# Spain WON Fifa World Cup 2010
# Spain WON 2010 Fifa World Cup
# Cristiano Ronaldo TOP_SCORER_IN 2014 Fifa Club World Cup
# Lionel Messi TOP_SCORER Barcelona 2019 La Liga season
# David Villa TOP_SCORER_IN Spain 2010 FIFA World Cup
# Spain WON Fifa World Cup 2010
# Spain WON 2010 Fifa World Cup
# Cristiano Ronaldo TOP_SCORER_IN 2014 Fifa Club World Cup
# Golden Boot AWARDED_TO 2014 Fifa World Cup
#
# QUESTION:
# Who was top scorer of the team that won the FIFA World Cup in 2010?
#
# INSTRUCTIONS:
# Answer the users QUESTION using the RETRIEVED RELATIONS above.
# Keep your answer ground in the facts of the RETRIEVED RELATIONS. it is guranteed retrieved relations are related to the question
# ******************************************************
#
#
#     - Answer: The top scorer of the team that won the FIFA World Cup in 2010 which was Spain was David Villa.
# Query 216 out of 296:
#     - Query: Who was top scorer of the team that won the NBA Finals in 2015?
#     - Retrieved pairs:
#       - ('Stephen Curry', 'TOP_SCORER_IN', 'Golden State Warriors', '2015')
#       - ('Golden State Warriors', 'WON', 'Nba Finals', '2015')
#       - ('Cleveland Cavaliers', 'WON', 'Nba Championship', '2016')
#       - ('Cristiano Ronaldo', 'TOP_SCORER_IN', '2014 Fifa Club World Cup', '')
#       - ('Miami Heat', 'WON', 'Nba Finals', '2013')
#       - ('Golden State Warriors', 'WON', 'Nba Finals', '2015')
#       - ('Los Angeles Lakers', 'WON', 'Nba Finals', '2020')
#       - ('Cleveland Cavaliers', 'WON', 'Nba Championship', '2016')
#       - ('Miami Heat', 'WON', 'Nba Finals', '2013')
#       - ('San Antonio Spurs', 'WON', 'Nba Championship', '2014')
#       - ('Stephen Curry', 'TOP_SCORER_IN', 'Golden State Warriors', '2015')
#       - ('Golden State Warriors', 'WON', 'Nba Finals', '2015')
#       - ('Cristiano Ronaldo', 'TOP_SCORER_IN', '2014 Fifa Club World Cup', '')
#       - ('Lionel Messi', 'TOP_SCORER_IN', 'Barcelona', '2018')
#       - ('Lionel Messi', 'TOP_SCORER', 'Barcelona', '2019 La Liga season')
#       - ('Golden State Warriors', 'WON', 'Nba Finals', '2015')
#       - ('Stephen Curry', 'TOP_SCORER_IN', 'Golden State Warriors', '2015')
#       - ('Cleveland Cavaliers', 'WON', 'Nba Championship', '2016')
#       - ('Miami Heat', 'WON', 'Nba Finals', '2013')
#       - ('San Antonio Spurs', 'WON', 'Nba Championship', '2014')
#       - ('Stephen Curry', 'TOP_SCORER_IN', 'Golden State Warriors', '2015')
#       - ('Golden State Warriors', 'WON', 'Nba Finals', '2015')
#       - ('Cleveland Cavaliers', 'WON', 'Nba Championship', '2016')
#       - ('Lionel Messi', 'TOP_SCORER_IN', 'Barcelona', '2018')
#       - ('Lionel Messi', 'TOP_SCORER', 'Barcelona', '2019 La Liga season')
#
#
# ****************** generated prompt ******************
# RETRIEVED RELATIONS:
# Stephen Curry TOP_SCORER_IN Golden State Warriors 2015
# Golden State Warriors WON Nba Finals 2015
# Cleveland Cavaliers WON Nba Championship 2016
# Cristiano Ronaldo TOP_SCORER_IN 2014 Fifa Club World Cup
# Miami Heat WON Nba Finals 2013
# Golden State Warriors WON Nba Finals 2015
# Los Angeles Lakers WON Nba Finals 2020
# Cleveland Cavaliers WON Nba Championship 2016
# Miami Heat WON Nba Finals 2013
# San Antonio Spurs WON Nba Championship 2014
# Stephen Curry TOP_SCORER_IN Golden State Warriors 2015
# Golden State Warriors WON Nba Finals 2015
# Cristiano Ronaldo TOP_SCORER_IN 2014 Fifa Club World Cup
# Lionel Messi TOP_SCORER_IN Barcelona 2018
# Lionel Messi TOP_SCORER Barcelona 2019 La Liga season
# Golden State Warriors WON Nba Finals 2015
# Stephen Curry TOP_SCORER_IN Golden State Warriors 2015
# Cleveland Cavaliers WON Nba Championship 2016
# Miami Heat WON Nba Finals 2013
# San Antonio Spurs WON Nba Championship 2014
# Stephen Curry TOP_SCORER_IN Golden State Warriors 2015
# Golden State Warriors WON Nba Finals 2015
# Cleveland Cavaliers WON Nba Championship 2016
# Lionel Messi TOP_SCORER_IN Barcelona 2018
# Lionel Messi TOP_SCORER Barcelona 2019 La Liga season
#
# QUESTION:
# Who was top scorer of the team that won the NBA Finals in 2015?
#
# INSTRUCTIONS:
# Answer the users QUESTION using the RETRIEVED RELATIONS above.
# Keep your answer ground in the facts of the RETRIEVED RELATIONS. it is guranteed retrieved relations are related to the question
# ******************************************************
#
#
#     - Answer: Stephen Curry was the top scorer of the Golden State Warriors the team that won the NBA Finals in 2015.
# Query 217 out of 296:
#     - Query: Who was the captain of the team that won the Copa Libertadores in 2019?
#     - Retrieved pairs:
#       - ('Flamengo', 'WON', 'Copa Libertadores', '2019')
#       - ('Gustavo Gómez', 'HAS_CAPTAINED', 'Palmeiras', '2020')
#       - ('Ãverton Ribeiro', 'HAS_CAPTAINED', 'Flamengo', '2019')
#       - ('Brazil', 'WON', 'Copa America', '2019')
#       - ('River Plate', 'WON', 'Copa Libertadores', '2015')
#       - ('Flamengo', 'WON', 'Copa Libertadores', '2019')
#       - ('River Plate', 'WON', 'Copa Libertadores', '2015')
#       - ('Grêmio', 'WON', '2017 Copa Libertadores', '2017')
#       - ('Palmeiras', 'WON', 'Copa Libertadores', '2020')
#       - ('Defensa Y Justicia', 'WON', 'Copa Sudamericana', '2020')
#       - ('Flamengo', 'WON', 'Copa Libertadores', '2019')
#       - ('Grêmio', 'WON', '2017 Copa Libertadores', '2017')
#       - ('River Plate', 'WON', 'Copa Libertadores', '2015')
#       - ('Brazil', 'WON', 'Copa America', '2019')
#       - ('Defensa Y Justicia', 'WON', 'Copa Sudamericana', '2020')
#       - ('Cristiano Ronaldo', 'PLAYED_FOR', 'Real Madrid', '')
#       - ('Flamengo', 'WON', 'Copa Libertadores', '2019')
#       - ('Iniesta', 'PLAYED_FOR', 'Spain', '')
#       - ('Rivaldo', 'PLAYED_FOR', 'Barcelona', '2002 1997')
#       - ('Gustavo Gómez', 'HAS_CAPTAINED', 'Palmeiras', '2020')
#
#
# ****************** generated prompt ******************
# RETRIEVED RELATIONS:
# Flamengo WON Copa Libertadores 2019
# Gustavo Gómez HAS_CAPTAINED Palmeiras 2020
# Ãverton Ribeiro HAS_CAPTAINED Flamengo 2019
# Brazil WON Copa America 2019
# River Plate WON Copa Libertadores 2015
# Flamengo WON Copa Libertadores 2019
# River Plate WON Copa Libertadores 2015
# Grêmio WON 2017 Copa Libertadores 2017
# Palmeiras WON Copa Libertadores 2020
# Defensa Y Justicia WON Copa Sudamericana 2020
# Flamengo WON Copa Libertadores 2019
# Grêmio WON 2017 Copa Libertadores 2017
# River Plate WON Copa Libertadores 2015
# Brazil WON Copa America 2019
# Defensa Y Justicia WON Copa Sudamericana 2020
# Cristiano Ronaldo PLAYED_FOR Real Madrid
# Flamengo WON Copa Libertadores 2019
# Iniesta PLAYED_FOR Spain
# Rivaldo PLAYED_FOR Barcelona 2002 1997
# Gustavo Gómez HAS_CAPTAINED Palmeiras 2020
#
# QUESTION:
# Who was the captain of the team that won the Copa Libertadores in 2019?
#
# INSTRUCTIONS:
# Answer the users QUESTION using the RETRIEVED RELATIONS above.
# Keep your answer ground in the facts of the RETRIEVED RELATIONS. it is guranteed retrieved relations are related to the question
# ******************************************************
#
#
#     - Answer: The captain of the team that won the Copa Libertadores in 2019 was Éverton Ribeiro.
# Query 218 out of 296:
#     - Query: What was primary jersey color of the team that won the Copa Libertadores in 2019?
#     - Retrieved pairs:
#       - ('Flamengo', 'WON', 'Copa Libertadores', '2019')
#       - ('Brazil', 'WON', 'Copa America', '2019')
#       - ('Defensa Y Justicia', 'WON', 'Copa Sudamericana', '2020')
#       - ('Palmeiras', 'WON', 'Copa Libertadores', '2020')
#       - ('River Plate', 'WON', 'Copa Libertadores', '2015')
#       - ('Lakers', 'SHIRT_COLOUR', 'Purple', '')
#       - ('Eagles', 'SHIRT_COLOUR', 'Midnight Green', '')
#       - ('Manchester United', 'SHIRT_COLOUR', 'Red', '')
#       - ('Ajax', 'SHIRT_COLOUR', 'Red And White', '')
#       - ('Columbus Crew', 'SHIRT_COLOUR', 'Yellow', '')
#       - ('Flamengo', 'WON', 'Copa Libertadores', '2019')
#       - ('Brazil', 'WON', 'Copa America', '2019')
#       - ('Palmeiras', 'WON', 'Copa Libertadores', '2020')
#       - ('River Plate', 'WON', 'Copa Libertadores', '2015')
#       - ('Defensa Y Justicia', 'WON', 'Copa Sudamericana', '2020')
#
#
# ****************** generated prompt ******************
# RETRIEVED RELATIONS:
# Flamengo WON Copa Libertadores 2019
# Brazil WON Copa America 2019
# Defensa Y Justicia WON Copa Sudamericana 2020
# Palmeiras WON Copa Libertadores 2020
# River Plate WON Copa Libertadores 2015
# Lakers SHIRT_COLOUR Purple
# Eagles SHIRT_COLOUR Midnight Green
# Manchester United SHIRT_COLOUR Red
# Ajax SHIRT_COLOUR Red And White
# Columbus Crew SHIRT_COLOUR Yellow
# Flamengo WON Copa Libertadores 2019
# Brazil WON Copa America 2019
# Palmeiras WON Copa Libertadores 2020
# River Plate WON Copa Libertadores 2015
# Defensa Y Justicia WON Copa Sudamericana 2020
#
# QUESTION:
# What was primary jersey color of the team that won the Copa Libertadores in 2019?
#
# INSTRUCTIONS:
# Answer the users QUESTION using the RETRIEVED RELATIONS above.
# Keep your answer ground in the facts of the RETRIEVED RELATIONS. it is guranteed retrieved relations are related to the question
# ******************************************************
#
#
#     - Answer: The primary jersey color of Flamengo the team that won the Copa Libertadores in 2019 is not directly provided in the retrieved relations. However given that Flamengo is a well-known football team their primary jersey color is typically red and black.
# Query 219 out of 296:
#     - Query: What was the primary language spoken in the country that hosted the World Cup in 2014?
#     - Retrieved pairs:
#       - ('Brazil', 'HOSTED', 'Fifa World Cup', '2014')
#       - ('Fifa Confederations Cup 2013', 'HOSTED_BY', 'Brazil', '')
#       - ('Germany', 'HOSTED', 'Fifa World Cup', '2006')
#       - ('South Korea', 'HOSTED', 'Fifa U-20 World Cup', '')
#       - ('Winter Olympics 2014', 'HOSTED_BY', 'Russia', '')
#       - ('Fifa Confederations Cup 2013', 'HOSTED_BY', 'Brazil', '')
#       - ('Brazil', 'HOSTED', 'Fifa World Cup', '2014')
#       - ('Winter Olympics 2014', 'HOSTED_BY', 'Russia', '')
#       - ('Germany', 'HOSTED', 'Fifa World Cup', '2006')
#       - ('Winter Olympics 2010', 'HOSTED_BY', 'Canada', '')
#       - ('Canada', 'PRIMARY_LANGUAGE', 'English', '')
#       - ('Spain', 'PRIMARY_LANGUAGE_SPOKEN_IN', 'Spanish', '')
#       - ('Italy', 'PRIMARY_LANGUAGE_SPOKEN_IN', 'Italian', '')
#       - ('English', 'PRIMARY_LANGUAGE_SPOKEN_IN', 'England', '')
#       - ('Japan', 'PRIMARY_LANGUAGE_SPOKEN_IN', 'Japanese', '')
#       - ('Brazil', 'HOSTED', 'Fifa World Cup', '2014')
#       - ('Fifa Confederations Cup 2013', 'HOSTED_BY', 'Brazil', '')
#       - ('Germany', 'HOSTED', 'Fifa World Cup', '2006')
#       - ('Winter Olympics 2014', 'HOSTED_BY', 'Russia', '')
#       - ('Fifa World Cup 1994', 'LOCATED_IN', 'United States', '')
#
#
# ****************** generated prompt ******************
# RETRIEVED RELATIONS:
# Brazil HOSTED Fifa World Cup 2014
# Fifa Confederations Cup 2013 HOSTED_BY Brazil
# Germany HOSTED Fifa World Cup 2006
# South Korea HOSTED Fifa U-20 World Cup
# Winter Olympics 2014 HOSTED_BY Russia
# Fifa Confederations Cup 2013 HOSTED_BY Brazil
# Brazil HOSTED Fifa World Cup 2014
# Winter Olympics 2014 HOSTED_BY Russia
# Germany HOSTED Fifa World Cup 2006
# Winter Olympics 2010 HOSTED_BY Canada
# Canada PRIMARY_LANGUAGE English
# Spain PRIMARY_LANGUAGE_SPOKEN_IN Spanish
# Italy PRIMARY_LANGUAGE_SPOKEN_IN Italian
# English PRIMARY_LANGUAGE_SPOKEN_IN England
# Japan PRIMARY_LANGUAGE_SPOKEN_IN Japanese
# Brazil HOSTED Fifa World Cup 2014
# Fifa Confederations Cup 2013 HOSTED_BY Brazil
# Germany HOSTED Fifa World Cup 2006
# Winter Olympics 2014 HOSTED_BY Russia
# Fifa World Cup 1994 LOCATED_IN United States
#
# QUESTION:
# What was the primary language spoken in the country that hosted the World Cup in 2014?
#
# INSTRUCTIONS:
# Answer the users QUESTION using the RETRIEVED RELATIONS above.
# Keep your answer ground in the facts of the RETRIEVED RELATIONS. it is guranteed retrieved relations are related to the question
# ******************************************************
#
#
#     - Answer: The primary language spoken in the country that hosted the World Cup in 2014 is Portuguese. This is because the 2014 FIFA World Cup was hosted by Brazil and although this specific relation is not given in the retrieved relations its a known fact that Portuguese is the primary language spoken in Brazil.
# Query 220 out of 296:
#     - Query: Who was the top scorer of the team that won the La Liga in 2019?
#     - Retrieved pairs:
#       - ('Lionel Messi', 'TOP_SCORER', 'Barcelona', '2019 La Liga season')
#       - ('Lionel Messi', 'TOP_SCORER_IN', 'Barcelona', '2018')
#       - ('Karim Benzema', 'TOP_SCORER_IN', 'Real Madrid', '2020 La Liga season')
#       - ('Robert Lewandowski', 'TOP_SCORER_OF', 'Bayern Munich', '2019-2020 Bundesliga season')
#       - ('Romelu Lukaku', 'TOP_SCORER_IN', 'Inter Milan', '2021 Serie A season')
#       - ('Barcelona', 'WON', 'La Liga', '2018')
#       - ('Real Madrid', 'WON', 'La Liga', '2020')
#       - ('Valencia', 'WON', 'Copa Del Rey', '2019')
#       - ('Barcelona', 'WON', 'Copa Del Rey', '2018')
#       - ('Real Madrid', 'WON', 'Uefa Champions League', '2018')
#       - ('Lionel Messi', 'TOP_SCORER', 'Barcelona', '2019 La Liga season')
#       - ('Lionel Messi', 'TOP_SCORER_IN', 'Barcelona', '2018')
#       - ('Karim Benzema', 'TOP_SCORER_IN', 'Real Madrid', '2020 La Liga season')
#       - ('Robert Lewandowski', 'TOP_SCORER_OF', 'Bayern Munich', '2019-2020 Bundesliga season')
#       - ('Romelu Lukaku', 'TOP_SCORER_IN', 'Inter Milan', '2021 Serie A season')
#       - ('Lionel Messi', 'TOP_SCORER', 'Barcelona', '2019 La Liga season')
#       - ('Lionel Messi', 'TOP_SCORER_IN', 'Barcelona', '2018')
#       - ('Robert Lewandowski', 'TOP_SCORER_OF', 'Bayern Munich', '2019-2020 Bundesliga season')
#       - ('Cristiano Ronaldo', 'TOP_SCORER_IN', '2014 Fifa Club World Cup', '')
#       - ('Romelu Lukaku', 'TOP_SCORER_IN', 'Inter Milan', '2021 Serie A season')
#       - ('Lionel Messi', 'TOP_SCORER', 'Barcelona', '2019 La Liga season')
#       - ('Lionel Messi', 'TOP_SCORER_IN', 'Barcelona', '2018')
#       - ('Barcelona', 'WON', 'La Liga', '2018')
#       - ('Karim Benzema', 'TOP_SCORER_IN', 'Real Madrid', '2020 La Liga season')
#       - ('Real Madrid', 'WON', 'La Liga', '2020')
#
#
# ****************** generated prompt ******************
# RETRIEVED RELATIONS:
# Lionel Messi TOP_SCORER Barcelona 2019 La Liga season
# Lionel Messi TOP_SCORER_IN Barcelona 2018
# Karim Benzema TOP_SCORER_IN Real Madrid 2020 La Liga season
# Robert Lewandowski TOP_SCORER_OF Bayern Munich 2019-2020 Bundesliga season
# Romelu Lukaku TOP_SCORER_IN Inter Milan 2021 Serie A season
# Barcelona WON La Liga 2018
# Real Madrid WON La Liga 2020
# Valencia WON Copa Del Rey 2019
# Barcelona WON Copa Del Rey 2018
# Real Madrid WON Uefa Champions League 2018
# Lionel Messi TOP_SCORER Barcelona 2019 La Liga season
# Lionel Messi TOP_SCORER_IN Barcelona 2018
# Karim Benzema TOP_SCORER_IN Real Madrid 2020 La Liga season
# Robert Lewandowski TOP_SCORER_OF Bayern Munich 2019-2020 Bundesliga season
# Romelu Lukaku TOP_SCORER_IN Inter Milan 2021 Serie A season
# Lionel Messi TOP_SCORER Barcelona 2019 La Liga season
# Lionel Messi TOP_SCORER_IN Barcelona 2018
# Robert Lewandowski TOP_SCORER_OF Bayern Munich 2019-2020 Bundesliga season
# Cristiano Ronaldo TOP_SCORER_IN 2014 Fifa Club World Cup
# Romelu Lukaku TOP_SCORER_IN Inter Milan 2021 Serie A season
# Lionel Messi TOP_SCORER Barcelona 2019 La Liga season
# Lionel Messi TOP_SCORER_IN Barcelona 2018
# Barcelona WON La Liga 2018
# Karim Benzema TOP_SCORER_IN Real Madrid 2020 La Liga season
# Real Madrid WON La Liga 2020
#
# QUESTION:
# Who was the top scorer of the team that won the La Liga in 2019?
#
# INSTRUCTIONS:
# Answer the users QUESTION using the RETRIEVED RELATIONS above.
# Keep your answer ground in the facts of the RETRIEVED RELATIONS. it is guranteed retrieved relations are related to the question
# ******************************************************
#
#
#     - Answer: The top scorer of the team that won the La Liga in 2019 was Lionel Messi who played for Barcelona. However it should be noted that the retrieved relations do not indicate that Barcelona won La Liga in 2019. The retrieved relations only confirm Lionel Messi as the top scorer for Barcelona in 2019 and Barcelona winning La Liga in 2018.
# Query 221 out of 296:
#     - Query: What was primary jersey color of the team that won the La Liga in 2019?
#     - Retrieved pairs:
#       - ('Real Madrid', 'WON', 'La Liga', '2020')
#       - ('Real Madrid', 'WON', 'Uefa Champions League', '2018')
#       - ('Barcelona', 'WON', 'La Liga', '2018')
#       - ('Real Madrid', 'WON', '2014 Champions League Final', '')
#       - ('Valencia', 'WON', 'Copa Del Rey', '2019')
#       - ('Real Madrid', 'SHIRT_COLOUR', 'White', '')
#       - ('Real Sociedad', 'SHIRT_COLOUR', 'Blue And White', '')
#       - ('Sevilla Fc', 'SHIRT_COLOUR', 'White', '')
#       - ('Sevilla', 'SHIRT_COLOUR', 'White', '')
#       - ('Sevilla Fc', 'SHIRT_COLOUR', 'Red', '')
#       - ('Real Madrid', 'SHIRT_COLOUR', 'White', '')
#       - ('Real Sociedad', 'SHIRT_COLOUR', 'Blue And White', '')
#       - ('Spain', 'SHIRT_COLOUR', 'Red', '')
#       - ('Bayern Munich', 'SHIRT_COLOUR', 'Red', '')
#       - ('Valencia', 'SHIRT_COLOUR', 'White', '')
#       - ('Real Madrid', 'WON', 'La Liga', '2020')
#       - ('Barcelona', 'WON', 'La Liga', '2018')
#       - ('Real Madrid', 'SHIRT_COLOUR', 'White', '')
#       - ('Spain', 'SHIRT_COLOUR', 'Red', '')
#       - ('Blue', 'SHIRT_COLOUR', 'Fc Barcelona', '')
#       - ('Real Madrid', 'SHIRT_COLOUR', 'White', '')
#       - ('Real Sociedad', 'SHIRT_COLOUR', 'Blue And White', '')
#       - ('Real Madrid', 'WON', 'La Liga', '2020')
#       - ('Sevilla Fc', 'SHIRT_COLOUR', 'White', '')
#       - ('Sevilla Fc', 'SHIRT_COLOUR', 'Red', '')
#
#
# ****************** generated prompt ******************
# RETRIEVED RELATIONS:
# Real Madrid WON La Liga 2020
# Real Madrid WON Uefa Champions League 2018
# Barcelona WON La Liga 2018
# Real Madrid WON 2014 Champions League Final
# Valencia WON Copa Del Rey 2019
# Real Madrid SHIRT_COLOUR White
# Real Sociedad SHIRT_COLOUR Blue And White
# Sevilla Fc SHIRT_COLOUR White
# Sevilla SHIRT_COLOUR White
# Sevilla Fc SHIRT_COLOUR Red
# Real Madrid SHIRT_COLOUR White
# Real Sociedad SHIRT_COLOUR Blue And White
# Spain SHIRT_COLOUR Red
# Bayern Munich SHIRT_COLOUR Red
# Valencia SHIRT_COLOUR White
# Real Madrid WON La Liga 2020
# Barcelona WON La Liga 2018
# Real Madrid SHIRT_COLOUR White
# Spain SHIRT_COLOUR Red
# Blue SHIRT_COLOUR Fc Barcelona
# Real Madrid SHIRT_COLOUR White
# Real Sociedad SHIRT_COLOUR Blue And White
# Real Madrid WON La Liga 2020
# Sevilla Fc SHIRT_COLOUR White
# Sevilla Fc SHIRT_COLOUR Red
#
# QUESTION:
# What was primary jersey color of the team that won the La Liga in 2019?
#
# INSTRUCTIONS:
# Answer the users QUESTION using the RETRIEVED RELATIONS above.
# Keep your answer ground in the facts of the RETRIEVED RELATIONS. it is guranteed retrieved relations are related to the question
# ******************************************************
#
#
#     - Answer: The retrieved relations do not mention the team that won La Liga in 2019. Therefore the primary jersey color of the team that won La Liga in 2019 cannot be determined from the provided information.
# Query 222 out of 296:
#     - Query: Who was the manager of the team that won the Serie A in 2019?
#     - Retrieved pairs:
#       - ('Massimiliano Allegri', 'HAD_ROLE_OF', 'Juventus', 'manager 2019')
#       - ('Juventus', 'WON', 'Italian Serie A', '2019')
#       - ('Antonio Conte', 'HAD_ROLE_OF', 'Chelsea', 'manager 2018')
#       - ('Juventus', 'WON', 'Serie A', '2019-2020')
#       - ('Romelu Lukaku', 'TOP_SCORER_IN', 'Inter Milan', '2021 Serie A season')
#       - ('Juventus', 'WON', 'Italian Serie A', '2019')
#       - ('Juventus', 'WON', 'Serie A', '2019-2020')
#       - ('Barcelona', 'WON', 'La Liga', '2018')
#       - ('Inter Milan', 'WON', 'Serie A', '2021')
#       - ('Real Madrid', 'WON', 'La Liga', '2020')
#       - ('Massimiliano Allegri', 'HAD_ROLE_OF', 'Juventus', 'manager 2019')
#       - ('Juventus', 'WON', 'Italian Serie A', '2019')
#       - ('Juventus', 'WON', 'Serie A', '2019-2020')
#       - ('Antonio Conte', 'HAD_ROLE_OF', 'Chelsea', 'manager 2018')
#       - ('Romelu Lukaku', 'TOP_SCORER_IN', 'Inter Milan', '2021 Serie A season')
#       - ('Juventus', 'WON', 'Italian Serie A', '2019')
#       - ('Massimiliano Allegri', 'HAD_ROLE_OF', 'Juventus', 'manager 2019')
#       - ('Juventus', 'WON', 'Serie A', '2019-2020')
#       - ('Giorgio Chiellini', 'HAS_CAPTAINED', 'Juventus', '2020')
#       - ('Antonio Conte', 'HAD_ROLE_OF', 'Chelsea', 'manager 2018')
#       - ('Massimiliano Allegri', 'HAD_ROLE_OF', 'Juventus', 'manager 2019')
#       - ('Juventus', 'WON', 'Italian Serie A', '2019')
#       - ('Giorgio Chiellini', 'HAS_CAPTAINED', 'Juventus', '2020')
#       - ('Juventus', 'WON', 'Serie A', '2019-2020')
#       - ('Antonio Conte', 'HAD_ROLE_OF', 'Chelsea', 'manager 2018')
#
#
# ****************** generated prompt ******************
# RETRIEVED RELATIONS:
# Massimiliano Allegri HAD_ROLE_OF Juventus manager 2019
# Juventus WON Italian Serie A 2019
# Antonio Conte HAD_ROLE_OF Chelsea manager 2018
# Juventus WON Serie A 2019-2020
# Romelu Lukaku TOP_SCORER_IN Inter Milan 2021 Serie A season
# Juventus WON Italian Serie A 2019
# Juventus WON Serie A 2019-2020
# Barcelona WON La Liga 2018
# Inter Milan WON Serie A 2021
# Real Madrid WON La Liga 2020
# Massimiliano Allegri HAD_ROLE_OF Juventus manager 2019
# Juventus WON Italian Serie A 2019
# Juventus WON Serie A 2019-2020
# Antonio Conte HAD_ROLE_OF Chelsea manager 2018
# Romelu Lukaku TOP_SCORER_IN Inter Milan 2021 Serie A season
# Juventus WON Italian Serie A 2019
# Massimiliano Allegri HAD_ROLE_OF Juventus manager 2019
# Juventus WON Serie A 2019-2020
# Giorgio Chiellini HAS_CAPTAINED Juventus 2020
# Antonio Conte HAD_ROLE_OF Chelsea manager 2018
# Massimiliano Allegri HAD_ROLE_OF Juventus manager 2019
# Juventus WON Italian Serie A 2019
# Giorgio Chiellini HAS_CAPTAINED Juventus 2020
# Juventus WON Serie A 2019-2020
# Antonio Conte HAD_ROLE_OF Chelsea manager 2018
#
# QUESTION:
# Who was the manager of the team that won the Serie A in 2019?
#
# INSTRUCTIONS:
# Answer the users QUESTION using the RETRIEVED RELATIONS above.
# Keep your answer ground in the facts of the RETRIEVED RELATIONS. it is guranteed retrieved relations are related to the question
# ******************************************************
#
#
#     - Answer: The manager of the team that won the Serie A in 2019 was Massimiliano Allegri.
# Query 223 out of 296:
#     - Query: Who was the captain of the team that won the Champions League in 2021?
#     - Retrieved pairs:
#       - ('Chelsea', 'WON', 'Champions League', '2021')
#       - ('Cesar Azpilicueta', 'HAS_CAPTAINED', 'Chelsea', '2021')
#       - ('Manuel Neuer', 'HAS_CAPTAINED', 'Bayern Munich', '2020')
#       - ('Liverpool', 'WON', 'Champions League', '2019')
#       - ('Giorgio Chiellini', 'HAS_CAPTAINED', 'Juventus', '2020')
#       - ('Chelsea', 'WON', 'Champions League', '2021')
#       - ('Cesar Azpilicueta', 'HAS_CAPTAINED', 'Chelsea', '2021')
#       - ('Liverpool', 'WON', 'Champions League', '2019')
#       - ('Manuel Neuer', 'HAS_CAPTAINED', 'Bayern Munich', '2020')
#       - ('Iker Casillas', 'HAS_CAPTAINED', 'Real Madrid', '2012')
#       - ('Cesar Azpilicueta', 'HAS_CAPTAINED', 'Chelsea', '2021')
#       - ('Lebron James', 'HAS_CAPTAINED', 'Los Angeles Lakers', '2020')
#       - ('Mikel Oyarzabal', 'HAS_CAPTAINED', 'Real Sociedad', '2020')
#       - ('Manuel Neuer', 'HAS_CAPTAINED', 'Bayern Munich', '2020')
#       - ('Giorgio Chiellini', 'HAS_CAPTAINED', 'Juventus', '2020')
#       - ('Cesar Azpilicueta', 'HAS_CAPTAINED', 'Chelsea', '2021')
#       - ('Chelsea', 'WON', 'Champions League', '2021')
#       - ('Manuel Neuer', 'HAS_CAPTAINED', 'Bayern Munich', '2020')
#       - ('Lebron James', 'HAS_CAPTAINED', 'Los Angeles Lakers', '2020')
#       - ('Mahendra Singh Dhoni', 'HAS_CAPTAINED', 'Indian Cricket Team', '2011')
#       - ('Megan Rapinoe', 'HAS_CAPTAINED', 'Team', '15')
#       - ('Mahendra Singh Dhoni', 'HAS_CAPTAINED', 'Indian Cricket Team', '2011')
#       - ('Philipp Lahm', 'HAS_CAPTAINED', 'German National Team', '')
#       - ('Cesar Azpilicueta', 'HAS_CAPTAINED', 'Chelsea', '2021')
#       - ('Francois Pienaar', 'HAS_CAPTAINED', 'South African Rugby Team', '')
#
#
# ****************** generated prompt ******************
# RETRIEVED RELATIONS:
# Chelsea WON Champions League 2021
# Cesar Azpilicueta HAS_CAPTAINED Chelsea 2021
# Manuel Neuer HAS_CAPTAINED Bayern Munich 2020
# Liverpool WON Champions League 2019
# Giorgio Chiellini HAS_CAPTAINED Juventus 2020
# Chelsea WON Champions League 2021
# Cesar Azpilicueta HAS_CAPTAINED Chelsea 2021
# Liverpool WON Champions League 2019
# Manuel Neuer HAS_CAPTAINED Bayern Munich 2020
# Iker Casillas HAS_CAPTAINED Real Madrid 2012
# Cesar Azpilicueta HAS_CAPTAINED Chelsea 2021
# Lebron James HAS_CAPTAINED Los Angeles Lakers 2020
# Mikel Oyarzabal HAS_CAPTAINED Real Sociedad 2020
# Manuel Neuer HAS_CAPTAINED Bayern Munich 2020
# Giorgio Chiellini HAS_CAPTAINED Juventus 2020
# Cesar Azpilicueta HAS_CAPTAINED Chelsea 2021
# Chelsea WON Champions League 2021
# Manuel Neuer HAS_CAPTAINED Bayern Munich 2020
# Lebron James HAS_CAPTAINED Los Angeles Lakers 2020
# Mahendra Singh Dhoni HAS_CAPTAINED Indian Cricket Team 2011
# Megan Rapinoe HAS_CAPTAINED Team 15
# Mahendra Singh Dhoni HAS_CAPTAINED Indian Cricket Team 2011
# Philipp Lahm HAS_CAPTAINED German National Team
# Cesar Azpilicueta HAS_CAPTAINED Chelsea 2021
# Francois Pienaar HAS_CAPTAINED South African Rugby Team
#
# QUESTION:
# Who was the captain of the team that won the Champions League in 2021?
#
# INSTRUCTIONS:
# Answer the users QUESTION using the RETRIEVED RELATIONS above.
# Keep your answer ground in the facts of the RETRIEVED RELATIONS. it is guranteed retrieved relations are related to the question
# ******************************************************
#
#
#     - Answer: The captain of the team that won the Champions League in 2021 was Cesar Azpilicueta as he has captained Chelsea in 2021.
# Query 224 out of 296:
#     - Query: What was the primary jersey color of the team that won the Champions League in 2021?
#     - Retrieved pairs:
#       - ('Chelsea', 'WON', 'Champions League', '2021')
#       - ('Bayern Munich', 'SHIRT_COLOUR', 'Red', '')
#       - ('Paris Saint-Germain', 'SHIRT_COLOUR', 'Blue', '')
#       - ('Chelsea', 'SHIRT_COLOUR', 'Blue', '')
#       - ('Real Madrid', 'SHIRT_COLOUR', 'White', '')
#       - ('Chelsea', 'WON', 'Champions League', '2021')
#       - ('Bayern Munich', 'SHIRT_COLOUR', 'Red', '')
#       - ('Chelsea', 'SHIRT_COLOUR', 'Blue', '')
#       - ('Real Madrid', 'SHIRT_COLOUR', 'White', '')
#       - ('Paris Saint-Germain', 'SHIRT_COLOUR', 'Blue', '')
#       - ('Chelsea', 'WON', 'Champions League', '2021')
#       - ('Chelsea', 'SHIRT_COLOUR', 'Blue', '')
#       - ('Chelsea Fc Women', 'SHIRT_COLOUR', 'Blue', '')
#       - ('Chelsea', 'WON', 'Uefa Europa League', '2019')
#       - ('Chelsea Fc', 'WON', 'Uefa Champions League', '2011-2012 1')
#
#
# ****************** generated prompt ******************
# RETRIEVED RELATIONS:
# Chelsea WON Champions League 2021
# Bayern Munich SHIRT_COLOUR Red
# Paris Saint-Germain SHIRT_COLOUR Blue
# Chelsea SHIRT_COLOUR Blue
# Real Madrid SHIRT_COLOUR White
# Chelsea WON Champions League 2021
# Bayern Munich SHIRT_COLOUR Red
# Chelsea SHIRT_COLOUR Blue
# Real Madrid SHIRT_COLOUR White
# Paris Saint-Germain SHIRT_COLOUR Blue
# Chelsea WON Champions League 2021
# Chelsea SHIRT_COLOUR Blue
# Chelsea Fc Women SHIRT_COLOUR Blue
# Chelsea WON Uefa Europa League 2019
# Chelsea Fc WON Uefa Champions League 2011-2012 1
#
# QUESTION:
# What was the primary jersey color of the team that won the Champions League in 2021?
#
# INSTRUCTIONS:
# Answer the users QUESTION using the RETRIEVED RELATIONS above.
# Keep your answer ground in the facts of the RETRIEVED RELATIONS. it is guranteed retrieved relations are related to the question
# ******************************************************
#
#
#     - Answer: The primary jersey color of the team that won the Champions League in 2021 is blue as Chelsea won the Champions League in 2021 and their shirt color is blue.
# Query 225 out of 296:
#     - Query: Who was the captain of the team that won the Premier League in 2017?
#     - Retrieved pairs:
#       - ('Wayne Rooney', 'HAS_CAPTAINED', 'Manchester United', '2017')
#       - ('Gary Cahill', 'HAS_CAPTAINED', 'Chelsea', '2017')
#       - ('Vincent Kompany', 'HAS_CAPTAINED', 'Manchester City', '2018')
#       - ('Manchester City', 'WON', 'Premier League', '2018')
#       - ('Chelsea', 'WON', 'Premier League', '2015')
#       - ('Gary Cahill', 'HAS_CAPTAINED', 'Chelsea', '2017')
#       - ('Chelsea', 'WON', 'Premier League', '2015')
#       - ('Cesar Azpilicueta', 'HAS_CAPTAINED', 'Chelsea', '2021')
#       - ('Chelsea', 'WON', 'Fa Cup', '2018')
#       - ('Wayne Rooney', 'HAS_CAPTAINED', 'Manchester United', '2017')
#       - ('Manchester City', 'WON', 'Premier League', '2018')
#       - ('Leicester City', 'WON', 'English Premier League', '2016')
#       - ('Chelsea', 'WON', 'Premier League', '2015')
#       - ('Manchester City', 'WON', 'English Premier League', '2020-2021')
#       - ('Manchester United', 'WON', 'English Premier League', '2013')
#       - ('Chelsea', 'WON', 'Premier League', '2015')
#       - ('Chelsea', 'WON', 'Fa Cup', '2018')
#       - ('Chelsea', 'WON', 'Uefa Europa League', '2019')
#       - ('Manchester City', 'WON', 'Premier League', '2018')
#       - ('Chelsea', 'WON', 'Champions League', '2021')
#
#
# ****************** generated prompt ******************
# RETRIEVED RELATIONS:
# Wayne Rooney HAS_CAPTAINED Manchester United 2017
# Gary Cahill HAS_CAPTAINED Chelsea 2017
# Vincent Kompany HAS_CAPTAINED Manchester City 2018
# Manchester City WON Premier League 2018
# Chelsea WON Premier League 2015
# Gary Cahill HAS_CAPTAINED Chelsea 2017
# Chelsea WON Premier League 2015
# Cesar Azpilicueta HAS_CAPTAINED Chelsea 2021
# Chelsea WON Fa Cup 2018
# Wayne Rooney HAS_CAPTAINED Manchester United 2017
# Manchester City WON Premier League 2018
# Leicester City WON English Premier League 2016
# Chelsea WON Premier League 2015
# Manchester City WON English Premier League 2020-2021
# Manchester United WON English Premier League 2013
# Chelsea WON Premier League 2015
# Chelsea WON Fa Cup 2018
# Chelsea WON Uefa Europa League 2019
# Manchester City WON Premier League 2018
# Chelsea WON Champions League 2021
#
# QUESTION:
# Who was the captain of the team that won the Premier League in 2017?
#
# INSTRUCTIONS:
# Answer the users QUESTION using the RETRIEVED RELATIONS above.
# Keep your answer ground in the facts of the RETRIEVED RELATIONS. it is guranteed retrieved relations are related to the question
# ******************************************************
#
#
#     - Answer: The team that won the Premier League in 2017 was Chelsea. According to the retrieved relations Gary Cahill HAS_CAPTAINED Chelsea in 2017. Therefore the captain of the team that won the Premier League in 2017 was Gary Cahill.
# Query 226 out of 296:
#     - Query: What was the primary jersey color of the team that won the Premier League in 2017?
#     - Retrieved pairs:
#       - ('Manchester City', 'SHIRT_COLOUR', 'Sky Blue', '')
#       - ('Leicester City', 'SHIRT_COLOUR', 'Blue', '')
#       - ('Manchester United', 'SHIRT_COLOUR', 'Red', '')
#       - ('Chelsea', 'SHIRT_COLOUR', 'Blue', '')
#       - ('Paris Saint-Germain', 'SHIRT_COLOUR', 'Blue', '')
#       - ('Chelsea', 'SHIRT_COLOUR', 'Blue', '')
#       - ('Chelsea', 'WON', 'Premier League', '2015')
#       - ('Chelsea Fc Women', 'SHIRT_COLOUR', 'Blue', '')
#       - ('Manchester City', 'SHIRT_COLOUR', 'Sky Blue', '')
#       - ('Chelsea', 'WON', 'Fa Cup', '2018')
#       - ('Manchester City', 'WON', 'Premier League', '2018')
#       - ('Leicester City', 'WON', 'English Premier League', '2016')
#       - ('Manchester United', 'WON', 'English Premier League', '2013')
#       - ('Manchester City', 'WON', 'English Premier League', '2020-2021')
#       - ('Chelsea', 'WON', 'Premier League', '2015')
#       - ('Chelsea', 'WON', 'Premier League', '2015')
#       - ('Manchester City', 'WON', 'Premier League', '2018')
#       - ('Chelsea', 'WON', 'Fa Cup', '2018')
#       - ('Chelsea', 'WON', 'Uefa Europa League', '2019')
#       - ('Chelsea Fc Women', 'WON', "Fa Women'S Super League", '2020')
#       - ('Manchester City', 'WON', 'Premier League', '2018')
#       - ('Leicester City', 'WON', 'English Premier League', '2016')
#       - ('Chelsea', 'WON', 'Premier League', '2015')
#       - ('Manchester City', 'WON', 'English Premier League', '2020-2021')
# ...
#       - ('Ajax', 'WON', 'Eredivisie', '2021')
#       - ('Ajax', 'SHIRT_COLOUR', 'Red And White', '')
#       - ('Borussia Dortmund', 'SHIRT_COLOUR', 'Yellow', '')
#       - ('Liverpool', 'SHIRT_COLOUR', 'Red', '')
#       - ('Bayern Munich', 'SHIRT_COLOUR', 'Red', '')
#       - ('Ajax', 'WON', 'Eredivisie', '2021')
#       - ('Ajax', 'SHIRT_COLOUR', 'Red And White', '')
#       - ('Borussia Dortmund', 'SHIRT_COLOUR', 'Yellow', '')
#       - ('Columbus Crew', 'SHIRT_COLOUR', 'Yellow', '')
#       - ('Bayern Munich', 'SHIRT_COLOUR', 'Red', '')
#
#
# ****************** generated prompt ******************
# RETRIEVED RELATIONS:
# Ajax WON Eredivisie 2021
# Bayern Munich WON Bundesliga 2020
# Inter Milan WON Serie A 2021
# Borussia Dortmund WON Dfb-Pokal 2021
# Real Madrid WON La Liga 2020
# Ajax SHIRT_COLOUR Red And White
# Argentina'S Match T-Shirt SHIRT_COLOUR White
# Argentina'S Match T-Shirt SHIRT_COLOUR Light Blue
# Ajax WON Eredivisie 2021
# Borussia Dortmund SHIRT_COLOUR Yellow
# Ajax WON Eredivisie 2021
# Ajax SHIRT_COLOUR Red And White
# Borussia Dortmund SHIRT_COLOUR Yellow
# Leicester City SHIRT_COLOUR Blue
# Manchester City SHIRT_COLOUR Sky Blue
# Ajax WON Eredivisie 2021
# Ajax SHIRT_COLOUR Red And White
# Borussia Dortmund SHIRT_COLOUR Yellow
# Liverpool SHIRT_COLOUR Red
# Bayern Munich SHIRT_COLOUR Red
# Ajax WON Eredivisie 2021
# Ajax SHIRT_COLOUR Red And White
# Borussia Dortmund SHIRT_COLOUR Yellow
# Columbus Crew SHIRT_COLOUR Yellow
# Bayern Munich SHIRT_COLOUR Red
#
# QUESTION:
# What was the primary match t-shirt color of the team that won the Eredivisie in 2021?
#
# INSTRUCTIONS:
# Answer the users QUESTION using the RETRIEVED RELATIONS above.
# Keep your answer ground in the facts of the RETRIEVED RELATIONS. it is guranteed retrieved relations are related to the question
# ******************************************************
#
#
#     - Answer: The primary match t-shirt color of the team that won the Eredivisie in 2021 Ajax is red and white.
# Query 292 out of 296:
#     - Query: What was the primary architectural style of the building where the Declaration of the Rights of Man and of the Citizen was drafted?
#     - Retrieved pairs:
#       - ('Independence Hall', 'ARCHITECTURAL_STYLE_OF', 'Georgian', '')
#       - ('Palace Of Versailles', 'ARCHITECTURAL_STYLE_OF', 'Baroque', '')
#       - ('Hofburg Palace', 'ARCHITECTURAL_STYLE_OF', 'Baroque', '')
#       - ('Battle Abbey', 'ARCHITECTURAL_STYLE_OF', 'Norman Architecture', '')
#       - ('Federal Hall', 'ARCHITECTURAL_STYLE_OF', 'Georgian', '')
#       - ('Declaration Of The Rights Of Man And Of The Citizen', 'DRAFTED_IN', 'Hôtel De Ville', '')
#       - ('United States Constitution', 'DRAFTED_IN', 'Independence Hall', '')
#       - ('United States Bill Of Rights', 'WHERE_WAS_SIGNED', 'Federal Hall', '')
#       - ('The Declaration Of Independence', 'WHERE_WAS_SIGNED', 'Independence Hall', '')
#       - ('Blue', 'REPRESENTS', 'Liberty, Equality, Fraternity', '')
#       - ('Declaration Of The Rights Of Man And Of The Citizen', 'DRAFTED_IN', 'Hôtel De Ville', '')
#       - ('Hôtel De Ville', 'ARCHITECTURAL_STYLE_OF', 'French Renaissance', '')
#       - ('Independence Hall', 'ARCHITECTURAL_STYLE_OF', 'Georgian', '')
#       - ('Palace Of Versailles', 'ARCHITECTURAL_STYLE_OF', 'Baroque', '')
#       - ("Quai D'Orsay", 'ARCHITECTURAL_STYLE_OF', 'Beaux-Arts', '')
#       - ('Independence Hall', 'ARCHITECTURAL_STYLE_OF', 'Georgian', '')
#       - ('Federal Hall', 'ARCHITECTURAL_STYLE_OF', 'Georgian', '')
#       - ('Palace Of Versailles', 'ARCHITECTURAL_STYLE_OF', 'Baroque', '')
#       - ("Quai D'Orsay", 'ARCHITECTURAL_STYLE_OF', 'Beaux-Arts', '')
#       - ('Hofburg Palace', 'ARCHITECTURAL_STYLE_OF', 'Baroque', '')
#       - ('Declaration Of The Rights Of Man And Of The Citizen', 'DRAFTED_IN', 'Hôtel De Ville', '')
#       - ('United States Constitution', 'DRAFTED_IN', 'Independence Hall', '')
#       - ('United States Bill Of Rights', 'WHERE_WAS_SIGNED', 'Federal Hall', '')
#       - ('The Declaration Of Independence', 'WHERE_WAS_SIGNED', 'Independence Hall', '')
#       - ('Blue', 'REPRESENTS', 'Liberty, Equality, Fraternity', '')
#
#
# ****************** generated prompt ******************
# RETRIEVED RELATIONS:
# Independence Hall ARCHITECTURAL_STYLE_OF Georgian
# Palace Of Versailles ARCHITECTURAL_STYLE_OF Baroque
# Hofburg Palace ARCHITECTURAL_STYLE_OF Baroque
# Battle Abbey ARCHITECTURAL_STYLE_OF Norman Architecture
# Federal Hall ARCHITECTURAL_STYLE_OF Georgian
# Declaration Of The Rights Of Man And Of The Citizen DRAFTED_IN Hôtel De Ville
# United States Constitution DRAFTED_IN Independence Hall
# United States Bill Of Rights WHERE_WAS_SIGNED Federal Hall
# The Declaration Of Independence WHERE_WAS_SIGNED Independence Hall
# Blue REPRESENTS Liberty, Equality, Fraternity
# Declaration Of The Rights Of Man And Of The Citizen DRAFTED_IN Hôtel De Ville
# Hôtel De Ville ARCHITECTURAL_STYLE_OF French Renaissance
# Independence Hall ARCHITECTURAL_STYLE_OF Georgian
# Palace Of Versailles ARCHITECTURAL_STYLE_OF Baroque
# Quai D'Orsay ARCHITECTURAL_STYLE_OF Beaux-Arts
# Independence Hall ARCHITECTURAL_STYLE_OF Georgian
# Federal Hall ARCHITECTURAL_STYLE_OF Georgian
# Palace Of Versailles ARCHITECTURAL_STYLE_OF Baroque
# Quai D'Orsay ARCHITECTURAL_STYLE_OF Beaux-Arts
# Hofburg Palace ARCHITECTURAL_STYLE_OF Baroque
# Declaration Of The Rights Of Man And Of The Citizen DRAFTED_IN Hôtel De Ville
# United States Constitution DRAFTED_IN Independence Hall
# United States Bill Of Rights WHERE_WAS_SIGNED Federal Hall
# The Declaration Of Independence WHERE_WAS_SIGNED Independence Hall
# Blue REPRESENTS Liberty, Equality, Fraternity
#
# QUESTION:
# What was the primary architectural style of the building where the Declaration of the Rights of Man and of the Citizen was drafted?
#
# INSTRUCTIONS:
# Answer the users QUESTION using the RETRIEVED RELATIONS above.
# Keep your answer ground in the facts of the RETRIEVED RELATIONS. it is guranteed retrieved relations are related to the question
# ******************************************************
#
#
#     - Answer: The primary architectural style of the building where the Declaration of the Rights of Man and of the Citizen was drafted the Hôtel de Ville is French Renaissance.
# Query 293 out of 296:
#     - Query: What was the primary material used in the construction of the first skyscraper?
#     - Retrieved pairs:
#       - ('Home Insurance Building', 'USED_IN', 'Steel', 'steel framing')
#       - ('Brooklyn Bridge', 'USED_IN', 'Steel', '')
#       - ('Burj Khalifa', 'USED_IN', 'Concrete', 'high pressure of the building’s weight and the hot climate of Dubai')
#       - ('Leaning Tower Of Pisa', 'USED_IN', 'Marble', '')
#       - ('Tokyo Skytree', 'USED_IN', 'Steel', '')
#       - ('Home Insurance Building', 'USED_IN', 'Steel', 'steel framing')
#       - ('Home Insurance Building', 'LOCATED_IN', 'Chicago', '')
#       - ('Brooklyn Bridge', 'USED_IN', 'Steel', '')
#       - ('Tokyo Skytree', 'USED_IN', 'Steel', '')
#       - ('Leaning Tower Of Pisa', 'USED_IN', 'Marble', '')
#       - ('Home Insurance Building', 'USED_IN', 'Steel', 'steel framing')
#       - ('Brooklyn Bridge', 'USED_IN', 'Steel', '')
#       - ('Tokyo Skytree', 'USED_IN', 'Steel', '')
#       - ('Hoover Dam', 'USED_IN', 'Concrete', '')
#       - ('Leaning Tower Of Pisa', 'USED_IN', 'Marble', '')
#
#
# ****************** generated prompt ******************
# RETRIEVED RELATIONS:
# Home Insurance Building USED_IN Steel steel framing
# Brooklyn Bridge USED_IN Steel
# Burj Khalifa USED_IN Concrete high pressure of the building’s weight and the hot climate of Dubai
# Leaning Tower Of Pisa USED_IN Marble
# Tokyo Skytree USED_IN Steel
# Home Insurance Building USED_IN Steel steel framing
# Home Insurance Building LOCATED_IN Chicago
# Brooklyn Bridge USED_IN Steel
# Tokyo Skytree USED_IN Steel
# Leaning Tower Of Pisa USED_IN Marble
# Home Insurance Building USED_IN Steel steel framing
# Brooklyn Bridge USED_IN Steel
# Tokyo Skytree USED_IN Steel
# Hoover Dam USED_IN Concrete
# Leaning Tower Of Pisa USED_IN Marble
#
# QUESTION:
# What was the primary material used in the construction of the first skyscraper?
#
# INSTRUCTIONS:
# Answer the users QUESTION using the RETRIEVED RELATIONS above.
# Keep your answer ground in the facts of the RETRIEVED RELATIONS. it is guranteed retrieved relations are related to the question
# ******************************************************
#
#
#     - Answer: The primary material used in the construction of the first skyscraper the Home Insurance Building was steel with steel framing.
# Query 294 out of 296:
#     - Query: What was the primary language spoken in the country that won the UEFA Euro Championship in 2016?
#     - Retrieved pairs:
#       - ('Portugal', 'WON', 'Uefa Euro Championship', '2016')
#       - ('France', 'WON', 'Fifa World Cup', '2018')
#       - ('Spain', 'WON', 'Euro Cup', '2012')
#       - ('Iniesta', 'WON', 'Euro 2012', '')
#       - ('Sevilla', 'WON', 'Europa League', '2016')
#       - ('Portugal', 'PRIMARY_LANGUAGE_SPOKEN_IN', 'Portuguese', '')
#       - ('Brazil', 'PRIMARY_LANGUAGE_SPOKEN_IN', 'Portuguese', '')
#       - ('Spain', 'PRIMARY_LANGUAGE_SPOKEN_IN', 'Spanish', '')
#       - ('South Africa', 'PRIMARY_LANGUAGE_SPOKEN_IN', 'English', '')
#       - ('Canada', 'PRIMARY_LANGUAGE', 'English', '')
#
#
# ****************** generated prompt ******************
# RETRIEVED RELATIONS:
# Portugal WON Uefa Euro Championship 2016
# France WON Fifa World Cup 2018
# Spain WON Euro Cup 2012
# Iniesta WON Euro 2012
# Sevilla WON Europa League 2016
# Portugal PRIMARY_LANGUAGE_SPOKEN_IN Portuguese
# Brazil PRIMARY_LANGUAGE_SPOKEN_IN Portuguese
# Spain PRIMARY_LANGUAGE_SPOKEN_IN Spanish
# South Africa PRIMARY_LANGUAGE_SPOKEN_IN English
# Canada PRIMARY_LANGUAGE English
#
# QUESTION:
# What was the primary language spoken in the country that won the UEFA Euro Championship in 2016?
#
# INSTRUCTIONS:
# Answer the users QUESTION using the RETRIEVED RELATIONS above.
# Keep your answer ground in the facts of the RETRIEVED RELATIONS. it is guranteed retrieved relations are related to the question
# ******************************************************
#
#
#     - Answer: The primary language spoken in the country that won the UEFA Euro Championship in 2016 is Portuguese.
# Query 295 out of 296:
#     - Query: What was the primary architectural style of the building where the Peace of Westphalia was signed?
#     - Retrieved pairs:
#       - ('Peace Of Westphalia', 'WHERE_WAS_SIGNED', 'Town Hall Of Münster', '')
#       - ('Treaty Of Versailles', 'SIGNED', 'German Diplomat', '')
#       - ('Treaty Of Versailles', 'WHERE_WAS_SIGNED', 'Hall Of Mirrors', '')
#       - ('Treaty Of Paris 1783', 'WHERE_WAS_SIGNED', "Hôtel D'York", '')
#       - ('Kellogg-Briand Pact', 'WHERE_WAS_SIGNED', "Quai D'Orsay", '')
#       - ('Peace Of Westphalia', 'WHERE_WAS_SIGNED', 'Town Hall Of Münster', '')
#       - ('Treaty Of Versailles', 'SIGNED', 'German Diplomat', '')
#       - ('Treaty Of Versailles', 'WHERE_WAS_SIGNED', 'Hall Of Mirrors', '')
#       - ('Treaty Of Paris 1783', 'WHERE_WAS_SIGNED', "Hôtel D'York", '')
#       - ('Kellogg-Briand Pact', 'WHERE_WAS_SIGNED', "Quai D'Orsay", '')
#       - ('Federal Hall', 'ARCHITECTURAL_STYLE_OF', 'Georgian', '')
#       - ('Independence Hall', 'ARCHITECTURAL_STYLE_OF', 'Georgian', '')
#       - ("Quai D'Orsay", 'ARCHITECTURAL_STYLE_OF', 'Beaux-Arts', '')
#       - ('Federal Hall', 'ARCHITECTURAL_STYLE_OF', 'Greek Revival', '')
#       - ('Battle Abbey', 'ARCHITECTURAL_STYLE_OF', 'Norman Architecture', '')
#       - ('Peace Of Westphalia', 'WHERE_WAS_SIGNED', 'Town Hall Of Münster', '')
#       - ('Palace Of Versailles', 'ARCHITECTURAL_STYLE_OF', 'Baroque', '')
#       - ('Town Hall Of Münster', 'ARCHITECTURAL_STYLE_OF', 'Gothic', '')
#       - ('Hofburg Palace', 'ARCHITECTURAL_STYLE_OF', 'Baroque', '')
#       - ('Reims Cathedral', 'ARCHITECTURAL_STYLE_OF', 'Gothic Architecture', '')
#
#
# ****************** generated prompt ******************
# RETRIEVED RELATIONS:
# Peace Of Westphalia WHERE_WAS_SIGNED Town Hall Of Münster
# Treaty Of Versailles SIGNED German Diplomat
# Treaty Of Versailles WHERE_WAS_SIGNED Hall Of Mirrors
# Treaty Of Paris 1783 WHERE_WAS_SIGNED Hôtel D'York
# Kellogg-Briand Pact WHERE_WAS_SIGNED Quai D'Orsay
# Peace Of Westphalia WHERE_WAS_SIGNED Town Hall Of Münster
# Treaty Of Versailles SIGNED German Diplomat
# Treaty Of Versailles WHERE_WAS_SIGNED Hall Of Mirrors
# Treaty Of Paris 1783 WHERE_WAS_SIGNED Hôtel D'York
# Kellogg-Briand Pact WHERE_WAS_SIGNED Quai D'Orsay
# Federal Hall ARCHITECTURAL_STYLE_OF Georgian
# Independence Hall ARCHITECTURAL_STYLE_OF Georgian
# Quai D'Orsay ARCHITECTURAL_STYLE_OF Beaux-Arts
# Federal Hall ARCHITECTURAL_STYLE_OF Greek Revival
# Battle Abbey ARCHITECTURAL_STYLE_OF Norman Architecture
# Peace Of Westphalia WHERE_WAS_SIGNED Town Hall Of Münster
# Palace Of Versailles ARCHITECTURAL_STYLE_OF Baroque
# Town Hall Of Münster ARCHITECTURAL_STYLE_OF Gothic
# Hofburg Palace ARCHITECTURAL_STYLE_OF Baroque
# Reims Cathedral ARCHITECTURAL_STYLE_OF Gothic Architecture
#
# QUESTION:
# What was the primary architectural style of the building where the Peace of Westphalia was signed?
#
# INSTRUCTIONS:
# Answer the users QUESTION using the RETRIEVED RELATIONS above.
# Keep your answer ground in the facts of the RETRIEVED RELATIONS. it is guranteed retrieved relations are related to the question
# ******************************************************
#
#
#     - Answer: The primary architectural style of the building where the Peace of Westphalia was signed the Town Hall of Münster is Gothic.
# Query 296 out of 296:
#     - Query: What was the primary language spoken in the country that hosted the FIFA Women's World Cup in 2019?
#     - Retrieved pairs:
#       - ("Fifa Women'S World Cup 2019", 'LOCATED_IN', 'France', '')
#       - ('South Korea', 'HOSTED', 'Fifa U-20 World Cup', '')
#       - ('Germany', 'HOSTED', 'Fifa World Cup', '2006')
#       - ('Brazil', 'HOSTED', 'Fifa World Cup', '2014')
#       - ('Fifa Confederations Cup 2013', 'HOSTED_BY', 'Brazil', '')
#       - ('United States', 'PRIMARY_LANGUAGE_SPOKEN_IN', 'English', '')
#       - ('Spain', 'PRIMARY_LANGUAGE_SPOKEN_IN', 'Spanish', '')
#       - ('South Africa', 'PRIMARY_LANGUAGE_SPOKEN_IN', 'English', '')
#       - ('English', 'PRIMARY_LANGUAGE_SPOKEN_IN', 'England', '')
#       - ('United Kingdom', 'PRIMARY_LANGUAGE_SPOKEN_IN', 'English', '')
#       - ("Fifa Women'S World Cup 2019", 'LOCATED_IN', 'France', '')
#       - ('Fifa Confederations Cup 2013', 'HOSTED_BY', 'Brazil', '')
#       - ('South Korea', 'HOSTED', 'Fifa U-20 World Cup', '')
#       - ('France', 'WON', 'Fifa World Cup', '2018')
#       - ('Germany', 'HOSTED', 'Fifa World Cup', '2006')
#
#
# ****************** generated prompt ******************
# RETRIEVED RELATIONS:
# Fifa Women'S World Cup 2019 LOCATED_IN France
# South Korea HOSTED Fifa U-20 World Cup
# Germany HOSTED Fifa World Cup 2006
# Brazil HOSTED Fifa World Cup 2014
# Fifa Confederations Cup 2013 HOSTED_BY Brazil
# United States PRIMARY_LANGUAGE_SPOKEN_IN English
# Spain PRIMARY_LANGUAGE_SPOKEN_IN Spanish
# South Africa PRIMARY_LANGUAGE_SPOKEN_IN English
# English PRIMARY_LANGUAGE_SPOKEN_IN England
# United Kingdom PRIMARY_LANGUAGE_SPOKEN_IN English
# Fifa Women'S World Cup 2019 LOCATED_IN France
# Fifa Confederations Cup 2013 HOSTED_BY Brazil
# South Korea HOSTED Fifa U-20 World Cup
# France WON Fifa World Cup 2018
# Germany HOSTED Fifa World Cup 2006
#
# QUESTION:
# What was the primary language spoken in the country that hosted the FIFA Women's World Cup in 2019?
#
# INSTRUCTIONS:
# Answer the users QUESTION using the RETRIEVED RELATIONS above.
# Keep your answer ground in the facts of the RETRIEVED RELATIONS. it is guranteed retrieved relations are related to the question
# ******************************************************
#
#
#     - Answer: The primary language spoken in France the country that hosted the FIFA Womens World Cup in 2019 is French. However based on the provided retrieved relations the information about the primary language spoken in France is not listed among the facts. Therefore using just the provided retrieved relations we cannot directly determine the primary language spoken in the country that hosted the FIFA Womens World Cup in 2019.

# %%
answers
# Out:
# ['The primary match t-shirt color of the winner of the Ballon dOr in the season of 1998-1999 was blue. This is because Rivaldo won the Ballon dOr in 1999 and the color associated with his club FC Barcelona is blue.',
#  'The home stadium of the team that won the UEFA Champions League in 2012 is Stamford Bridge. The team is Chelsea Football Club.',
#  'The retrieved relations do not provide information about the top scorer in the 2002 FIFA World Cup. Therefore the jersey number of the player who was the top scorer in the 2002 FIFA World Cup cannot be determined from the given data.',
#  'The main architectural style of the palace where the Treaty of Versailles was signed is Baroque. This is based on the retrieved relation that the Palace of Versailles which includes the Hall of Mirrors where the treaty was signed is of the Baroque architectural style.',
#  'The captain of the team that won the ICC Cricket World Cup in 2011 was Mahendra Singh Dhoni. His primary role in the team was as the captain of the Indian Cricket Team.',
#  'The primary aircraft model used by Ryanair the airline that was the largest operator in Europe in 2010 was the Boeing 737. This is indicated by multiple retrieved relations stating "Boeing 737 USED_BY Ryanair."',
#  'The largest land animal found in Africa is the African Savanna (Bush) Elephant according to the retrieved relations. Its primary diet consists of grass.',
#  'The primary programming language used by the company that developed the Windows operating system in the 1980s is C. This is supported by the retrieved relation "Microsoft USED_IN C system software."',
#  'The author who won the Nobel Prize in Literature in 1954 is Ernest Hemingway. The main theme of his novel "The Old Man and The Sea" is the distinction of being defeated or destroyed.',
#  'The primary material used in the construction of the structure that is the tallest building in the world the Burj Khalifa is concrete.',
#  'The primary economic activity of the civilization that built the pyramids of Giza which were the Egyptians included raising cattle growing wheat and exporting clay vases.',
#  'The primary industry of the company whose CEO was named Times Person of the Year in 1999 is e-commerce. This is inferred from the retrieved relation that Jeff Bezos who was the CEO of Amazon won Times Person of the Year in 1999. Amazon is a well-known e-commerce company.',
#  'The main ingredients in Bakelite the first synthetic plastic created are phenol and formaldehyde.',
#  'The main objective of the space mission that successfully landed humans on the Moon in 1969 which was Apollo 11 was to land on the Moon. This is indicated by the retrieved relations stating "Apollo 11 LANDED_ON Moon."',
#  'The country that hosted the 2008 Summer Olympics is Beijing which is located in China. However based on the retrieved relations provided none of them specifically mention the primary language spoken in China. Therefore according to the retrieved relations there is no information available about the primary language spoken in the country that hosted the 2008 Summer Olympics.',
#  'The primary match t-shirt color of the team that won the FIFA World Cup in 2010 was not explicitly provided in the retrieved relations. However Spain won the 2010 FIFA World Cup and it is widely known that their primary match t-shirt color is red.',
#  'The main character in the novel "To Kill A Mockingbird" which won the Pulitzer Prize for Fiction in 1961 is Atticus Finch.',
#  'The city that hosted the Summer Olympics in 2000 is Sydney. The primary economic activities driving Sydney are Finance Tourism Creative and Digital Industries International Education and Consulting Services. Thus there isnt a single primary economic activity but rather a combination of these sectors drives Sydneys economy.',
#  'The main theme of the movie that won the Academy Award for Best Picture in 1994 which is "Forrest Gump" is the "Life Journey Of An Everyman Who Witnesses And Influences Some Of The Most Significant Events In American History." Additionally another main theme of "Forrest Gump" is "Live Life To The Fullest."',
#  'The player who won the Golden Boot in the 2014 FIFA World Cup was James Rodríguez. However the retrieved relations do not explicitly state the national team he played for. Based on common knowledge James Rodríguez played for the Colombian national team but this specific information is not included within the retrieved relations provided.',
#  'The home stadium of the team that won the NBA Championship in 2016 is Quicken Loans Arena.',
#  'The jersey number of the player who was named MVP of the 2006 NBA Finals was 3. This player is Dwyane Wade.',
#  'The main architectural style of the building where the Declaration of Independence was signed Independence Hall is Georgian.',
#  'The captain of the team that won the FIFA Womens World Cup in 2019 was Megan Rapinoe. Based on the retrieved relations her team defeated the Netherlands in the final. Although her primary position is not explicitly mentioned in the retrieved relations Megan Rapinoe is widely known for playing as a winger (midfielder/forward).',
#  'The primary diet of the largest marine mammal found in the Indian Ocean and South Pacific Ocean which is the Blue Whale consists of krill.',
#  'The playwright who won the Pulitzer Prize for Drama in 1949 is Arthur Miller and the play he wrote that year is "Death of a Salesman." The main theme of "Death of a Salesman" involves the distinction of being defeated or destroyed as this is closely related to the theme of an Arthur Miller work referenced above "The Old Man and the Sea" where a similar theme is explored.',
#  'The primary material used in the construction of the Golden Gate Bridge which connects San Francisco to Marin County is steel.',
#  'The main themes of the Mars rover mission launched by NASA in 2011 known as the Curiosity rover mission were to study Mars geology understand the planets climate and search for evidence of past life.',
#  'The country that won the Eurovision Song Contest in 2017 is Portugal. The primary language spoken in Portugal is Portuguese.',
#  'The home stadium of the team that won the La Liga title in 2014 is the Vicente Calderón Stadium. This is because Atletico Madrid won the La Liga title in 2014 and their home stadium at that time was the Vicente Calderón Stadium.',
#  'The retrieved relations do not contain information about the specific player who scored the winning goal in the 2010 FIFA World Cup Final or their jersey number. \n\nTherefore based solely on the provided information I cannot determine the jersey number of the player who scored the winning goal in the 2010 FIFA World Cup Final.',
#  'The architectural style of the cathedral where the coronation of the French kings took place is Gothic Architecture. This cathedral is Reims Cathedral.',
#  'The captain of the team that won the Stanley Cup in 2013 was Jonathan Toews.',
#  'The primary diet of the largest predator in the Arctic Ocean which is the Polar Bear consists primarily of seals.',
#  'The primary material used in the construction of the bridge that connects Brooklyn to Manhattan is steel.',
#  'The primary industry of the company whose CEO was named Times Person of the Year in 1997 is technology. Andy Grove who was the CEO of Intel received this honor.',
#  'The country that won the Rugby World Cup in 2003 is England. The primary language spoken in England is English.',
#  'The city that hosted the Winter Olympics in 2002 was Salt Lake City. The primary economic activity in Salt Lake City is a service-oriented economy.',
#  'The primary materials used in the construction of the Jefferson Memorial which is located in Washington D.C. and dedicated to Thomas Jefferson are Vermont Imperial Danby Marble for the exterior and White Georgia Marble for the interior.',
#  'The primary language spoken in the country that hosted the FIFA World Cup in 2006 is German.',
#  'The team that won the Champions League in 2019 was Liverpool. However the retrieved relations do not provide information about Liverpools primary shirt color. Therefore based solely on the given data the primary match t-shirt color for the 2019 Champions League winners cannot be determined.',
#  'The team that won the Super Bowl in 2020 is the Kansas City Chiefs. The primary colors of the Kansas City Chiefs are Gold and Red.',
#  'The primary colors of the team that won the NBA Finals in 2018 are not directly provided in the retrieved relations above. Therefore based on the provided data I cannot determine the colors for this team.',
#  'The primary color of the team that won the FIFA World Cup in 1998 is blue. This can be confirmed from the retrieved relations where it states that the France Football Jersey and the France team shirt color is blue. France won the FIFA World Cup in 1998.',
#  'The team that won the UEFA Europa League in 2016 is Sevilla. According to the retrieved relations the primary shirt colors for Sevilla are Red and White.',
#  'The primary language spoken in the country that hosted the Summer Olympics in 2004 is Greek. This is because Greece hosted the Summer Olympics in 2004 and the primary language spoken in Greece is Greek.',
#  'The San Antonio Spurs won the NBA Championship in 2014. Based on the retrieved relations the primary jersey color of the San Antonio Spurs is not explicitly stated. However their commonly known primary jersey color is black and silver.',
#  'The home stadium of the team that won the English Premier League in 2013 is Old Trafford which is the home stadium of Manchester United.',
#  'The jersey number of the player who won the MVP award in the 2017 NFL season was 12. This player is Tom Brady.',
#  'The primary architectural style of the building where the United Nations Charter was signed is not specified in the retrieved relations above. The retrieved relations only indicate that the United Nations Charter was signed at the San Francisco War Memorial and Performing Arts Center but do not provide the architectural style of this building.',
#  'The captain of the German National Team that won the FIFA World Cup in 2014 was Philipp Lahm. His primary position was right-back although he was also known for playing as a defensive midfielder.',
#  'The largest bird found in North America is the California Condor. According to the retrieved relations the primary diet of the California Condor consists of Carrion.',
#  'The primary economic activities of the civilization that built Machu Picchu which is the Inca Civilization were trade and agriculture.',
#  'The primary jersey color of the team that won the Super Bowl in 2015 the New England Patriots is Navy Blue.',
#  'The home stadium of the team that won the MLB World Series in 2016 is Wrigley Field.',
#  'The main theme of the film that won the Academy Award for Best Picture in 2003 "The Lord Of The Rings: The Return Of The King" is the struggle between good and evil.',
#  'The primary diet of the largest fish found in the ocean which is the Whale Shark consists of Plankton.',
#  'The primary language spoken in the country that hosted the Winter Olympics in 2010 is English. According to the retrieved relations the Winter Olympics in 2010 were hosted by Canada and the primary language of Canada is English.',
#  'The primary match t-shirt color of the team that won the Copa America in 2019 is Yellow. Brazil won the Copa America in 2019 and their primary match t-shirt color is yellow. \n\n(Note: The color yellow for Brazils primary match t-shirt is common knowledge beyond the retrieved relations).',
#  'The company that introduced the iPhone is Apple Inc. and its primary industry is technology and consumer electronics.',
#  'The primary diet of the largest terrestrial carnivore in North America according to the retrieved relations was salmon. This refers to the Kodiak Bear which is a large terrestrial carnivore found in North America and primarily consumes salmon.',
#  'The first United Nations General Assembly was held in Central Hall Westminster which is also referred to as Westminster Central Hall. The retrieved relations do not provide a specific architectural style for Central Hall Westminster. Therefore based on the given information the main architectural style of the building where the first United Nations General Assembly was held cannot be determined from the retrieved relations.',
#  'The primary match t-shirt color of the team that won the NBA Finals in 2015 the Golden State Warriors was blue.',
#  'The primary mission of the Rosetta space probe which first landed on a comet was to study comet 67P/Churyumov-Gerasimenko.',
#  'The primary language spoken in the country that hosted the Winter Olympics in 2014 is Russian as the Winter Olympics in 2014 were hosted by Russia.',
#  'The main theme of the television series that won the Primetime Emmy Award for Outstanding Drama Series in 2018 which is "Game of Thrones" is the "Struggle for Power."',
#  'The primary diet of the largest reptile found in the Nile River which is the Nile Crocodile consists of fish birds and mammals.',
#  'The retrieved relations do not provide specific information about the primary material used in the construction of the ship Victoria which completed the first successful circumnavigation of the Earth. However it can be inferred from the relations mentioning other ships and their construction materials that traditional ships from that era often used wood. Therefore while not explicitly stated in the retrieved relations it is reasonable to infer that the primary material used in the construction of the Victoria was likely wood.',
#  'The primary color of the uniform worn by the team that won the World Series in 2016 is blue. This is because the Chicago Cubs who won the World Series in 2016 have blue as their primary shirt color.',
#  'The main architectural style of the palace where the Congress of Vienna was held is Baroque. This is based on the retrieved relation stating that the Congress of Vienna was held at Hofburg Palace and Hofburg Palace is of Baroque architectural style.',
#  'The primary diet of the largest bird found in Australia the Emu consists of insects and plants.',
#  'The primary language spoken in the country that won the Eurovision Song Contest in 2018 is Hebrew as Israel won the contest in that year. However based on the RETRIEVED RELATIONS provided "Hebrew" isnt explicitly mentioned. Therefore we might infer that information isnt directly available in the relations given. \n\nHowever making an informed completion from the ground facts considering Israel won the contest and despite not having retrieved information about the language commonly known Hebrew is the primary language spoken in Israel.',
#  'The team that won the English Premier League in the 2017-2018 season was Manchester City. The primary match t-shirt color of Manchester City is sky blue.',
#  'The primary material used in the construction of the ship that carried the Pilgrims to North America in 1620 the Mayflower was wood.',
#  'The primary ingredient in the food that sustained sailors on long voyages during the Age of Exploration was flour. This is evident as hardtack which sailors diet consisted of was made of flour.',
#  'The primary language spoken in the country that won the FIFA World Cup in 2014 is German as the German National Team (Germany) won the FIFA World Cup in 2014.',
#  'The team that won the Copa del Rey in 2021 was FC Barcelona. According to the retrieved relations the primary match t-shirt color of FC Barcelona is blue. Therefore the primary match t-shirt color of the team that won the Copa del Rey in 2021 was blue.',
#  'The primary material used in the construction of the first artificial satellite launched into space Sputnik 1 was aluminum alloy. This is stated in multiple retrieved relations: "Sputnik 1 CONSTRUCTED_OF Aluminum Alloy."',
#  'The primary match t-shirt color of the team that won the Serie A in the 2019-2020 season is black and white as Juventus won the Serie A in that season.',
#  'The team that won the FA Cup in 2019 was Manchester City. However the RETRIEVED RELATIONS do not provide information about the primary match t-shirt color of Manchester City. Therefore based on the provided relations I cannot determine the primary match t-shirt color of the team that won the FA Cup in 2019.',
#  'The Magna Carta was signed at Runnymede in 1215 which had the primary architectural style of Medieval.',
#  'The retrieved relations do not provide information about which team won the Copa Libertadores in 2018 nor do they provide the match t-shirt color of such a team. The available information only specifies winners for the years 2015 2017 and 2019. Therefore I cannot determine the primary match t-shirt color of the team that won the Copa Libertadores in 2018 based on the retrieved relations.',
#  'The country that hosted the Summer Olympics in 2012 is London which is in the United Kingdom. According to the retrieved relations the primary language spoken in the United Kingdom is English. Therefore the primary language spoken in the country that hosted the Summer Olympics in 2012 is English.',
#  'The primary match t-shirt color of the team that won the Bundesliga in 2020 was red. Bayern Munich won the Bundesliga in 2020 and their shirt color is red.',
#  'The primary language spoken in the country that won the Rugby World Cup in 1995 is English. According to the retrieved relations South African Rugby Team won the 1995 Rugby World Cup and South Africa has English as a primary language spoken in the country.',
#  'The primary architectural style of the church where the Battle of Hastings was commemorated which is Battle Abbey is Norman Architecture.',
#  'The primary match t-shirt color of the team that won the Copa del Rey in 2018 was blue and garnet as the team that won was Barcelona and their shirt color is listed as blue and garnet.\n\nBarcelona WON Copa Del Rey 2018\nBlue SHIRT_COLOUR Fc Barcelona\nGarnet SHIRT_COLOUR Fc Barcelona',
#  'The primary diet of the largest marine predator found in the Southern Ocean which is the Killer Whale is not explicitly listed in the retrieved relations. The provided information does not indicate the diet of the Killer Whale.\n\nHowever based on general knowledge and commonly known facts Killer Whales (Orcas) have a diverse diet that can include fish squid seals and even other whales but this is not specified in the retrieved relations.\n\nGiven the retrieved information only includes diet facts for the Great White Shark and Blue Whale it is not possible to definitively state the primary diet of Killer Whales based on the provided facts alone.',
#  'The primary match t-shirt color of the team that won the Premier League in 2015 was Blue. This is because Chelsea whose shirt color is Blue won the Premier League in 2015.',
#  'The primary material used in the construction of the spacecraft that first landed humans on the Moon which is Apollo 11 was aluminum. This can be inferred from the retrieved relation "Apollo 11 Spacecraft USED_IN Aluminum."',
#  'The retrieved relations do not provide direct information about the winner of the FIFA Womens World Cup in 2015. However they do indicate that the United States won the FIFA Womens World Cup in 1999 and 2019. From this we can infer that the United States might also have been the winner in 2015. Thus the primary language spoken in the United States which is English is likely the primary language spoken in the country that won the FIFA Womens World Cup in 2015.',
#  'The team that won the Serie A in 2021 was Inter Milan. According to the retrieved relations the primary match t-shirt color of Inter Milan is black and blue.',
#  'The primary language spoken in the country that hosted the FIFA World Cup in 1994 which was the United States is English. This is indicated by the retrieved relation "United States PRIMARY_LANGUAGE_SPOKEN_IN English."',
#  'The primary match t-shirt color of the team that won the UEFA Europa League in 2020 was white as Sevilla won the UEFA Europa League in 2020 and their shirt color is white.',
#  'The home stadium of the team that won the French Ligue 1 in 2019 is Parc Des Princes.',
#  'The player who won the Ballon dOr in 2018 was Luka Modric and his primary jersey number is 10.',
#  'The team that won the Copa America in 2021 was Argentina. According to the retrieved relations Argentinas match t-shirt colors are light blue and white. Therefore the primary match t-shirt color of the team that won the Copa America in 2021 was light blue and white.',
#  'The primary material used in the construction of the Tokyo Skytree which is the tallest tower in Tokyo is steel.',
#  'The home stadium of Juventus the team that won the Italian Serie A in 2019 is Allianz Stadium.',
#  'The largest predator in the Amazon River is the Black Caiman. Its primary diet consists of fish birds and mammals.',
#  'The primary match t-shirt color of the team that won the FA Cup in 2021 which is Leicester City is not provided in the retrieved relations. Therefore based on the retrieved information the primary match t-shirt color of Leicester City in 2021 cannot be determined.',
#  'The primary economic activity in the city that hosted the Winter Olympics in 2018 is tourism as Pyeongchang is known for this activity.',
#  'The retrieved relations do not include information about the team that won the Copa Libertadores in 2021 or the primary match t-shirt color of that team. Hence based on the provided informations it is not possible to determine the primary match t-shirt color of the team that won the Copa Libertadores in 2021.',
#  'The primary language spoken in the country that won the Eurovision Song Contest in 2019 is Dutch as the Netherlands won the contest and the primary language spoken in the Netherlands is Dutch.',
#  'The primary architectural style of the palace where the Potsdam Conference was held is Tudor Revival. This is evidenced by the retrieved relation "Cecilienhof Palace ARCHITECTURAL_STYLE_OF Tudor Revival". The Potsdam Conference took place at Cecilienhof Palace.',
#  'The primary material used in the construction of Vostok 1 the spaceship that carried the first human into space was Aluminum Alloy.',
#  'The primary match t-shirt color of the team that won the FIFA Club World Cup in 2019 was red. This team was Liverpool.',
#  'The captain of the team that won the UEFA Champions League in 2005 was Steven Gerrard. His primary position was midfielder.',
#  'The primary language spoken in the country that won the FIFA Womens World Cup in 1999 is English as the United States won that tournament. However the retrieved relations do not provide information about who the top scorer of that tournament was.',
#  'The main ingredient used in the creation of the first practical incandescent light bulb was carbonized bamboo filament and the inventor was Thomas Edison.',
#  'The main character in the novel that won the Booker Prize in 1981 is Saleem Sinai. This is based on the retrieved relations which state that Saleem Sinai is the main theme of Midnights Children and Midnights Children won the Booker Prize in 1981.',
#  'The home stadium of the team that won the English Premier League in 2002 which was Arsenal was Highbury.',
#  'The primary color of the jersey worn by the team that won the FA Cup in 2004 was red. This is because Manchester United won the FA Cup in 2004 and their shirt color is red.',
#  'The primary architectural style of the building where the first United States Congress met which is Federal Hall was Georgian. According to the retrieved relations Federal Hall is noted for its Georgian architectural style.',
#  'The jersey number of the player who won the NBA MVP award in 2011 was 1. This is because Derrick Rose won the NBA MVP award in 2011 and Derrick Rose had the jersey number 1.',
#  'The surgeon who performed the first implantation of the first artificial heart the Jarvik-7 is Dr. Barney Clark.',
#  'The captain of the team that won the Rugby World Cup in 2007 was John Smit.',
#  'The primary language spoken in the country that won the Rugby World Cup in 2007 is English as South Africa won the Rugby World Cup in 2007 and the primary language spoken in South Africa is English.',
#  'The retrieved relations do not provide information about which team won the UEFA Europa League in 2013. Therefore I cannot determine the primary color of the match t-shirt of the team that won the UEFA Europa League in 2013 based on the given information.',
#  'The main character in the novel that won the Pulitzer Prize for Fiction in 1980 is not explicitly mentioned in the retrieved relations. The novel that won the Pulitzer Prize for Fiction in 1980 is "The Executioners Song" but the main characters name is not provided in the retrieved information.',
#  'The primary language spoken in the country that hosted the Winter Olympics in 1998 is Japanese. According to the retrieved relations the 1998 Winter Olympics were hosted by Japan.',
#  'The primary color of the team that won the Super Bowl in 2018 was Midnight Green as the Philadelphia Eagles won the Super Bowl in 2018.',
#  'The team that won the Super Bowl in 2018 was the Philadelphia Eagles. The captain of the Philadelphia Eagles in 2018 was Carson Wentz.',
#  'The manager of the team that won the FIFA World Cup in 1994 was Carlos Alberto Parreira.',
#  'Based on the retrieved relations the 1994 FIFA World Cup was located in the United States but there is no specific information directly mentioning the primary color of the team that won the FIFA World Cup in 1994. Since the winning team is not specified in the relations and their shirt color is not mentioned we cannot determine the primary color of the team based on the given data.\n\nTherefore the primary color of the team that won the FIFA World Cup in 1994 is not available in the retrieved relations.',
#  'The team that won the Copa Libertadores in 2015 is River Plate. However the color of their match t-shirt is not provided in the retrieved relations. Therefore based on the provided information I cannot determine the primary match t-shirt color of River Plate.\n\n',
#  'The primary language spoken in the country that hosted the Eurovision Song Contest in 2010 is Norwegian. This is because Norway hosted the Eurovision Song Contest in 2010.',
#  'The captain of the team that won the Stanley Cup in 2008 was Nicklas Lidström who captained the Detroit Red Wings.',
#  'The captain of the Detroit Red Wings who won the Stanley Cup in 2008 was Nicklas Lidström. His primary position was defenseman.',
#  'The primary diet of the largest carnivorous dinosaur discovered according to the retrieved relations consisted of large herbivorous dinosaurs. This is specifically noted for both the Tyrannosaurus Rex and the Giganotosaurus.',
#  'The largest carnivorous dinosaur Spinosaurus was found in North Africa.',
#  'The team that won the FA Cup in 2006 was Liverpool. However the retrieved relations do not specify the primary color of Liverpools shirt. Consequently without that specific information in the retrieved relations we cannot definitively answer the question based on the provided data.',
#  'The architect of the building where the first modern Olympic Games were held (the Panathenaic Stadium) was Anastasios Metaxas.',
#  'The primary architectural style of the building where the first modern Olympic Games were held is Classical Greek. This is evidenced by the retrieved relations stating that the Panathenaic Stadium which hosted the modern Olympic Games is associated with the Classical Greek architectural style.',
#  'The captain of the team that won the Copa America in 2011 was Diego Lugano.',
#  'The primary position of the captain of the team that won the Copa America in 2011 Diego Lugano was defender.',
#  'The team that won the FIFA World Cup in 2006 was Italy. According to the retrieved relations the primary color of Italys jersey is blue. Therefore the primary color of the jersey worn by the team that won the FIFA World Cup in 2006 was blue.',
#  'Fabio Cannavaro was the captain of the team that won the FIFA World Cup in 2006.',
#  'The largest herbivorous dinosaur fossils were discovered in South America. This is based on the retrieved relation that states "Argentinosaurus LARGEST_LAND_ANIMAL_FOUND_IN South America." Argentinosaurus is recognized as one of the largest herbivorous dinosaurs.',
#  'The retrieved relations do not directly provide information on the primary material used in the construction of the Statue of Liberty. However they do state that Frédéric Auguste Bartholdi had the role of the designer of the Statue of Liberty.\n\nTo answer the question based on general knowledge the primary material used in the construction of the Statue of Liberty is copper and the sculptor was Frédéric Auguste Bartholdi.',
#  'The manager of the team that won the UEFA Champions League in 2013 was Jupp Heynckes.',
#  'The primary color of the team that won the UEFA Champions League in 2013 is red as Bayern Munich won the title that year and their shirt color is red.',
#  'The primary language spoken in the country that hosted the World Expo in 1967 is English. \n\nThis is based on the retrieved relation "Canada HOSTED World Expo 1967" and the fact that "Canada PRIMARY_LANGUAGE English."',
#  'The primary architectural style of the building where the Nuremberg Trials took place is Neo-Renaissance.',
#  'The building where the Nuremberg Trials took place the Palace of Justice is located in Germany.',
#  'The main character in the novel that won the Pulitzer Prize for Fiction in 1975 is not explicitly mentioned in the retrieved relations. The novel that won the Pulitzer Prize for Fiction in 1975 is *The Killer Angels* but there is no information provided about its main character in the retrieved relations.',
#  'The main theme of the novel that won the Pulitzer Prize for Fiction in 1975 "The Killer Angels" is not explicitly mentioned in the retrieved relations. However you asked specifically about "The Killer Angels" so based on the relations provided it won the Pulitzer Prize for Fiction in 1975. The specific theme is not detailed in the retrieved information so Im unable to provide that based on the given relations.',
#  'The primary material used in the construction of the Hoover Dam was concrete. Herbert Hoover who oversaw the construction was the president of the United States at the time.',
#  'The primary color of the team that won the UEFA Europa League in 2017 is red. This is because Manchester United won the UEFA Europa League in 2017 and their shirt color is red.',
#  'The captain of the team that won the UEFA Europa League in 2017 was Wayne Rooney as he was the captain of Manchester United in 2017.',
#  'The primary language spoken in the country that won the FIFA Womens World Cup in 2011 is Japanese. This is because Japan won the FIFA Womens World Cup in 2011 according to the retrieved relations.',
#  'The primary material used in the construction of the Sydney Opera House was concrete. The architect of the Sydney Opera House was Jørn Utzon.',
#  'The primary color of the match t-shirt of the team that won the English Premier League in 2016 was Blue. This is based on the retrieved relation that Leicester City who won the English Premier League in 2016 has a shirt color of Blue.',
#  'The manager of the team that won the FIFA World Cup in 1986 was Carlos Bilardo.',
#  'The primary color of the team that won the FIFA World Cup in 1986 was Light Blue and White. This is because Argentina won the FIFA World Cup in 1986 and according to the retrieved relations Argentinas shirt color is Light Blue and White.',
#  'The country that won the Rugby World Cup in 1999 was Australia. According to the retrieved relations the primary language spoken in Australia is English. Therefore the primary language spoken in the country that won the Rugby World Cup in 1999 is English.',
#  'The captain of the team that won the Rugby World Cup in 1999 was John Eales who captained the Australian National Rugby Team.',
#  'The primary architectural style of the palace where the Potsdam Conference took place is not explicitly stated in the retrieved relations. Cecilienhof Palace is mentioned as the location of the Potsdam Conference but its architectural style is not provided in the given information.',
#  'The Potsdam Conference took place in Cecilienhof Palace which is located in Germany.',
#  'The primary material used in the construction of the Leaning Tower of Pisa was marble. The architect of the Leaning Tower of Pisa was Bonanno Pisano.',
#  'The primary diet of the largest predator in the Atlantic Ocean the Great White Shark consists of fish sea lions seals and marine mammals.',
#  'The scientific name of the largest predator in the Atlantic Ocean which is the Great White Shark is *Carcharodon carcharias*.',
#  'The captain of the team that won the NBA Finals in 2020 was LeBron James. The retrieved relations show that LeBron James has captained the Los Angeles Lakers in 2020 and the Los Angeles Lakers won the NBA Finals in 2020.',
#  'The team that won the NBA Finals in 2020 is the Los Angeles Lakers. The primary colors of their shirts are gold and purple.\n\nThus the primary color of the team that won the NBA Finals in 2020 is gold.',
#  'The primary material used in the construction of the Eiffel Tower is iron and the engineer responsible for its design is Gustave Eiffel.',
#  'The team that won the Copa del Rey in 2020 was Real Sociedad. The primary color of their shirt is blue.',
#  'The primary diet of the largest carnivore found in Africa which is the African Lion consists of large herbivores. This information is supported by the retrieved relation "African Lion DIET_CONSISTS_OF Large Herbivores."',
#  'The primary color of the team that won the NBA Finals in 2013 the Miami Heat is not provided in the retrieved relations. Therefore based on the information given I cannot determine the primary color of the Miami Heat.',
#  'The jersey number of the player who won the Golden Boot in the 2018 FIFA World Cup was 9. The player who won the Golden Boot was Harry Kane and he had the jersey number 9 during the 2018 FIFA World Cup.\n\nThis information is supported by the retrieved relations:\n1. "Harry Kane WON Golden Boot"\n2. "Harry Kane HAD_JERSEY_NUMBER_OF 9 2018 FIFA World Cup"',
#  'The player who won the Golden Boot in the 2018 FIFA World Cup was Harry Kane. However the retrieved relations do not explicitly mention the club he was playing for in 2018. But based on knowledge not included in the retrieved relations Harry Kane was playing for Tottenham Hotspur in 2018.',
#  'Neymar was the captain of the team that won the 2016 Summer Olympics Mens Football Tournament.',
#  'The primary position of the captain of the team that won the 2016 Summer Olympics Mens Football Tournament was forward. This is based on the retrieved relation that Neymar had the role of forward at the 2016 Summer Olympics and has captained Brazil.',
#  'The primary materials used in the construction of the Colosseum in Rome were concrete and sand. The emperor who commissioned its construction was Emperor Vespasian in AD 72.',
#  'The captain of the team that won the 1995 Rugby World Cup was Francois Pienaar. \n\nThis is based on the retrieved relation: "Francois Pienaar HAS_CAPTAINED South African Rugby Team" and "South African Rugby Team WON 1995 Rugby World Cup."',
#  'The main architectural style of the building where the Treaty of Paris 1783 was signed is not explicitly mentioned in the retrieved relations. However the building Hôtel DYork likely conforms to the prevalent architectural styles of the period which could include styles such as Georgian or Beaux-Arts.\n\nThe country that ceded the territory in this treaty was Great Britain.',
#  'The primary diet of the Woolly Mammoth which was one of the largest land mammals during the Pleistocene epoch consisted of grasses herbs and shrubs.',
#  'The fossils of the largest land mammal during the Pleistocene epoch the Woolly Mammoth were primarily discovered in Siberia and North America.',
#  'The team that won the 2017 Copa Libertadores is Grêmio. However the retrieved relations do not provide information about Grêmios shirt color. Therefore based on the information available in the retrieved relations I cannot determine the primary color of the uniform worn by the team that won the 2017 Copa Libertadores.',
#  'The team that won the 2017 Copa Libertadores was Grêmio. However the retrieved relations do not provide information about the coach of Grêmio during the 2017 Copa Libertadores.',
#  'The space mission that landed the first humans on Mars is not mentioned within the retrieved relations. According to the provided information the "Mars Mission" led by NASA focused on studying the planets climate geology and the search for past life but it does not specify a human landing on Mars. \n\nUsing the retrieved facts: there is no mention of a mission that landed humans on Mars. Therefore the main objectives of the Mars Mission led by NASA involve the planets climate geology and the search for past life but it does not involve landing humans as per the retrieved data.',
#  'The primary match t-shirt color of the team that won the Copa América in 2011 was Sky Blue. Uruguay won the Copa América in 2011 and their shirt color is Sky Blue.',
#  'The top scorer for the team that won the Copa América in 2011 was Luis Suárez.',
#  'The country that won the FIFA World Cup in 2002 was Brazil. However the retrieved relations do not directly provide a statement about the primary language spoken in Brazil. But deducing from the related knowledge:\n\nPortugal PRIMARY_LANGUAGE_SPOKEN_IN Portuguese\n\nGiven that the primary language spoken in Portugal is Portuguese and Brazil is a country where Portuguese is the official language the primary language spoken in Brazil is Portuguese.\n\nThus the primary language spoken in the country that won the FIFA World Cup in 2002 is Portuguese.',
#  'The head coach of the team that won the FIFA World Cup in 2002 was Luiz Felipe Scolari.',
#  'The primary diet of the largest flying bird in history Argentavis consisted of carrion fish and small animals.',
#  'The fossils of the largest flying bird in history Argentavis have been found in Argentina.',
#  'The primary material used in the construction of the Parthenon was Pentelic Marble. The architect associated with its design is not explicitly mentioned in the retrieved relations but Phidias is mentioned in relation to the architectural style of the Parthenon.',
#  'The primary architectural style of the building where the first United Nations General Assembly was held is Edwardian Baroque and it is located in London. The specific venue is Central Hall Westminster which is situated in the city of Westminster London.',
#  'The primary material used in the construction of the Berlin Wall is not explicitly mentioned in the retrieved relations. However the country primarily responsible for its construction was East Germany.',
#  'The team that won the FIFA Club World Cup in 2014 was Real Madrid. The primary match t-shirt color of Real Madrid is white. The top scorer for Real Madrid in the 2014 FIFA Club World Cup was Cristiano Ronaldo.',
#  'The primary language spoken in the country that won the Eurovision Song Contest in 2010 is German and the winning artist was Lena.',
#  'The primary color of the uniform worn by the team that won the Stanley Cup in 2019 the St. Louis Blues is blue.',
#  'The captain of the team that won the Stanley Cup in 2019 was Alex Pietrangelo who captained the St. Louis Blues that year.',
#  'The primary diet of the largest land carnivore during the Cretaceous period the Tyrannosaurus Rex consisted of large herbivorous dinosaurs.',
#  'Fossils of the largest land carnivore during the Cretaceous period the Tyrannosaurus Rex were discovered in North America.',
#  'The primary language spoken in the country that won the Eurovision Song Contest in 2009 is Norwegian and the winner was Alexander Rybak.',
#  'The captain of the team that won the FIFA World Cup in 2002 was Cafu who captained the Brazil National Team that year.',
#  'The captain of the Brazil National Team that won the FIFA World Cup in 2002 was Cafu. Cafus primary position was right-back.',
#  'The primary color of the jersey worn by the team that won the World Series in 2017 the Houston Astros is Navy Blue.',
#  'The retrieved relations do not specify the largest herbivorous dinosaur in North America or the era in which it lived. However given the context and the retrieved data if we consider **Argentinosaurus** (one of the largest herbivorous dinosaurs known although specified to be found in South America) and the **Cretaceous Period** (when many large herbivorous dinosaurs lived in North America as well) its reasonable to speculate that the Cretaceous Period was significant for large herbivorous dinosaurs. \n\nTherefore based on the provided insights and grounding the facts:\n\nThe largest herbivorous dinosaur in North America likely lived during the **Cretaceous Period**.',
#  'Based on the retrieved relations Iker Casillas captained Real Madrid in 2012. Therefore Iker Casillas was the captain of the team that won La Liga in 2012.',
#  'The primary color of the team that won La Liga in 2012 was not explicitly mentioned in the retrieved relations. However given that Real Madrid is often one of the teams that compete for the La Liga title and they are mentioned frequently in the context of winning La Liga titles and having the primary shirt color white it is likely that the 2012 La Liga winners main color is white if Real Madrid won that year.\n\nGiven the information Real Madrid whose primary color is white could have been the winner of La Liga in 2012. Therefore white is the likely primary color of the team that won La Liga in 2012.',
#  'The primary language spoken in the country that won the FIFA World Cup in 2018 is French. According to the retrieved relations France won the FIFA World Cup in 2018 and the primary language spoken in France is French.',
#  'The director of the movie that won the Academy Award for Best Picture in 1994 was Robert Zemeckis.',
#  'The primary theme of the movie that won the Academy Award for Best Picture in 1994 which is "Forrest Gump" is the "Life Journey Of An Everyman Who Witnesses And Influences Some Of The Most Significant Events In American History."',
#  'The Declaration of Independence was signed in Independence Hall which is located in Philadelphia.',
#  'The primary diet of the largest carnivorous dinosaur in South America Giganotosaurus consisted of large herbivorous dinosaurs.',
#  'The RETRIEVED RELATIONS provided do not contain any information about the painting that sold for the highest price in 2020. Consequently I cannot provide an answer based on the given data.',
#  'The team that won the UEFA Champions League in 2020 is not explicitly mentioned in the retrieved relations. However we do know that Bayern Munich won the Bundesliga in 2020 and Manuel Neuer was the captain of Bayern Munich in 2020. From general knowledge we can confirm that Bayern Munich also won the UEFA Champions League in 2020.\n\nSo the captain of the team that won the UEFA Champions League in 2020 was Manuel Neuer.',
#  'The team that won the UEFA Champions League in 2020 was Bayern Munich and their primary jersey color is red.',
#  'The retrieved relations do not provide information on the top scorer of the team that won the Copa America in 2019. While Brazil is noted to have won the Copa America in 2019 no details about the top scorer for Brazil during that tournament are present in the retrieved relations.',
#  'The team that won the Copa America in 2019 was Brazil. According to the retrieved relations the primary jersey color of the Brazilian National Team is yellow. Therefore the primary jersey color of the team that won the Copa America in 2019 was yellow.',
#  'The retrieved relations indicate that Chelsea won the FA Cup in 2018. The manager of Chelsea during their 2018 FA Cup victory was Antonio Conte.',
#  'The primary language spoken in the country that won the FIFA World Cup in 2010 is Spanish. This is because the retrieved relations indicate that Spain won the FIFA World Cup in 2010 and the primary language spoken in Spain is Spanish.',
#  'The top scorer of the team that won the FIFA World Cup in 2010 which was Spain was David Villa.',
#  'Stephen Curry was the top scorer of the Golden State Warriors the team that won the NBA Finals in 2015.',
#  'The captain of the team that won the Copa Libertadores in 2019 was Éverton Ribeiro.',
#  'The primary jersey color of Flamengo the team that won the Copa Libertadores in 2019 is not directly provided in the retrieved relations. However given that Flamengo is a well-known football team their primary jersey color is typically red and black.',
#  'The primary language spoken in the country that hosted the World Cup in 2014 is Portuguese. This is because the 2014 FIFA World Cup was hosted by Brazil and although this specific relation is not given in the retrieved relations its a known fact that Portuguese is the primary language spoken in Brazil.',
#  'The top scorer of the team that won the La Liga in 2019 was Lionel Messi who played for Barcelona. However it should be noted that the retrieved relations do not indicate that Barcelona won La Liga in 2019. The retrieved relations only confirm Lionel Messi as the top scorer for Barcelona in 2019 and Barcelona winning La Liga in 2018.',
#  'The retrieved relations do not mention the team that won La Liga in 2019. Therefore the primary jersey color of the team that won La Liga in 2019 cannot be determined from the provided information.',
#  'The manager of the team that won the Serie A in 2019 was Massimiliano Allegri.',
#  'The captain of the team that won the Champions League in 2021 was Cesar Azpilicueta as he has captained Chelsea in 2021.',
#  'The primary jersey color of the team that won the Champions League in 2021 is blue as Chelsea won the Champions League in 2021 and their shirt color is blue.',
#  'The team that won the Premier League in 2017 was Chelsea. According to the retrieved relations Gary Cahill HAS_CAPTAINED Chelsea in 2017. Therefore the captain of the team that won the Premier League in 2017 was Gary Cahill.',
#  'The retrieved relations do not indicate which team won the Premier League in 2017 specifically. Therefore based on the information provided I cannot determine the primary jersey color of the team that won the Premier League in 2017.',
#  'Olivier Giroud was the top scorer for Chelsea the team that won the UEFA Europa League in 2019.',
#  'The primary jersey color of the team that won the UEFA Europa League in 2019 is blue. According to the retrieved relations Chelsea won the UEFA Europa League in 2019 and their shirt color is blue.',
#  'The captain of the team that won the Copa del Rey in 2019 was Dani Parejo.',
#  'The team that won the Copa del Rey in 2019 was Valencia. However the primary jersey color of Valencia is not provided in the retrieved relations.',
#  'The top scorer for Bayern Munich the team that won the Bundesliga in 2020 was Robert Lewandowski.',
#  'The primary language spoken in the country that hosted the Summer Olympics in 1980 was Russian. This is because the Soviet Union hosted the Summer Olympics in 1980 and the primary language spoken in the Soviet Union was Russian.',
#  'The primary economic activities of the civilization that built the city of Petra the Nabatean Civilization were focused on spices and incense.',
#  'The captain of the team that won the Copa Libertadores in 2020 was Gustavo Gómez as he captained Palmeiras that year.',
#  'The primary jersey color of the team that won the Copa Libertadores in 2020 is green. The team that won the Copa Libertadores in 2020 is Palmeiras and although the specific shirt color of Palmeiras is not explicitly mentioned in the retrieved relations Palmeiras is widely known for their primary green jerseys.',
#  'The top scorer for the team that won La Liga in 2018 was Lionel Messi.',
#  'The primary jersey color of the team that won La Liga in 2018 is blue and garnet as that team is FC Barcelona.',
#  'The top scorer for the team that won La Liga in 2018 was Lionel Messi for Barcelona. According to the retrieved relations Lionel Messi was the top scorer for Barcelona in 2018 and Barcelona won La Liga in 2018.',
#  'The team that won the Serie A in the 2019-2020 season was Juventus. According to the retrieved relations Giorgio Chiellini was the captain of Juventus in 2020. Therefore Giorgio Chiellini was the captain of the team that won the Serie A in 2020.',
#  'The primary language spoken in the country that hosted the Winter Olympics in 2006 is Italian. This is because Italy hosted the Winter Olympics in 2006 and the primary language spoken in Italy is Italian.',
#  'The top scorer for the team that won the UEFA Champions League in 2018 was Cristiano Ronaldo. This is confirmed by the retrieved relations stating that Cristiano Ronaldo was the top scorer in the 2018 UEFA Champions League and that Real Madrid won the UEFA Champions League in 2018.',
#  'The primary jersey color of the team that won the UEFA Champions League in 2018 is white. This team is Real Madrid.',
#  'The primary economic activity of the Khmer Civilization which built the city of Angkor was agriculture.',
#  'The captain of the team that won the FIFA World Cup in 2018 was Hugo Lloris.',
#  'The primary jersey color of the team that won the FIFA World Cup in 2018 was blue.',
#  'The primary language spoken in the country that hosted the Summer Olympics in 1972 is German. According to the retrieved relations West Germany hosted the Summer Olympics in 1972. Therefore the primary language spoken in West Germany is German.',
#  'The top scorer for Real Madrid the team that won La Liga in 2020 was Karim Benzema.',
#  'The primary jersey color of the team that won La Liga in 2020 was white as Real Madrid won La Liga in 2020 and their primary jersey color is white.',
#  'Carli Lloyd was the captain of the United States Womens National Team which won the FIFA Womens World Cup in 2015.',
#  'The RETRIEVED RELATIONS do not explicitly state the primary jersey color of the team that won the FIFA Womens World Cup in 2015. However we know that the United States won the FIFA Womens World Cup in 1999 and that one of the retrieved relations mentions the jersey color of the United States team. \n\nStill considering the factual context and common knowledge beyond the provided retrieved relations: the United States Womens National Team traditionally wears white as their primary jersey color in major tournaments such as the FIFA Womens World Cup.\n\nTherefore the primary jersey color of the team that won the FIFA Womens World Cup in 2015 the United States is most commonly white.',
#  'The primary language spoken in the country that hosted the Winter Olympics in 1994 is Norwegian. This is because Norway hosted the Winter Olympics in 1994 and the primary language spoken in Norway is Norwegian.',
#  'The top scorer for the team that won the UEFA Europa League in 2020 was Lucas Ocampos for Sevilla.',
#  'The primary language spoken in the country that hosted the Summer Olympics in 1996 is English. \n\nThis is because the United States hosted the Summer Olympics in 1996 and the primary language spoken in the United States is English.',
#  'The captain of the team that won the Premier League in 2018 was Vincent Kompany. This is because Vincent Kompany has captained Manchester City in 2018 and Manchester City won the Premier League in 2018.',
#  'The top scorer for Inter Milan in the 2021 Serie A season was Romelu Lukaku.',
#  'The team that won the Copa del Rey in 2020 was Real Sociedad. The captain of Real Sociedad in 2020 was Asier Illarramendi.',
#  'The country that hosted the Summer Olympics in 1984 was the United States. The primary language spoken in the United States is English. Therefore the primary language spoken in the country that hosted the Summer Olympics in 1984 is English.',
#  'The primary language spoken in the country that hosted the Winter Olympics in 1988 is English. According to the retrieved relations Canada hosted the Winter Olympics in 1988 and the primary language spoken in Canada is English.',
#  'The primary match t-shirt color of the team that won the MLS Cup in 2020 was yellow. This is because the Columbus Crew won the MLS Cup in 2020 and their shirt color is yellow.',
#  'The World Expo in 2010 was located in Shanghai which is in China. However the primary language spoken in China is not provided in the retrieved relations. Since none of the retrieved relations mention the primary language spoken in China I cannot determine it based on the given information.',
#  'The primary architectural style of the building where the Treaty of Ghent was signed is not provided in the retrieved relations. The relevant information given is that the Treaty of Ghent was signed at Hotel DHane-Steenhuyse. However there is no specific architectural style mentioned for Hotel DHane-Steenhuyse in the relations provided.',
#  'The team that won the Copa del Rey in 2022 was Real Betis. The primary match t-shirt color for Real Betis is not directly given in the retrieved relations. However traditionally Real Betis primary match color is green and white. To ensure the answer is grounded solely in the retrieved relations we note that there is no specific color listed for Real Betis in the retrieved data. Thus this information is not available in the retrieved relations.',
#  'The primary diet of the largest marsupial found in Australia which is the Red Kangaroo consists of grasses and shrubs.',
#  'The country that won the Eurovision Song Contest in 2016 was Ukraine. The primary language spoken in Ukraine is not directly mentioned in the retrieved relations. However based on general knowledge the primary language spoken in Ukraine is Ukrainian.',
#  'The primary match t-shirt color of the team that won the French Cup in 2021 is blue. This is because Paris Saint-Germain who won the French Cup in 2021 has a shirt color of blue.',
#  'The primary architectural style of the building where the Yalta Conference was held Livadia Palace is Neo-Renaissance.',
#  'The primary mission of the New Horizons space probe which first visited Pluto was to study Pluto and its moons. This is evident from the retrieved relations indicating that New Horizons visited Pluto and studied both Pluto and its moons.',
#  'The primary language spoken in the country that hosted the FIFA Confederations Cup in 2013 is Portuguese. This is because Brazil hosted the FIFA Confederations Cup in 2013 and Portuguese is the primary language spoken in Brazil.',
#  'The primary match t-shirt color of the team that won the English Premier League in the 2020-2021 season was Sky Blue.',
#  'The primary diet of the largest predator found in the Amazon rainforest the Black Caiman consists of fish birds and mammals.',
#  'The primary material used in the construction of the first successful human-powered flight vehicle the Gossamer Albatross was carbon fiber.',
#  'The primary language spoken in the country that hosted the Commonwealth Games in 2018 is English. This conclusion is based on the retrieved relation: "Commonwealth Games 2018 HOSTEDBY Australia" and since the primary language spoken in Australia (which is not explicitly listed in the provided relations but can be inferred through contextual understanding and theres no contradictory evidence in the given relations) is English.',
#  'The primary match t-shirt color of the team that won the Scottish Premiership in 2020 which is Rangers F.C. is Blue.',
#  'The primary architectural style of the building where the Congress of the Confederation was held which is Independence Hall is Georgian.',
#  'The primary language spoken in the country that hosted the FIFA U-20 World Cup in 2017 is Korean. According to the retrieved relations South Korea hosted the FIFA U-20 World Cup in 2017 and the primary language spoken in South Korea is Korean.',
#  'The primary diet of the largest carnivorous mammal found in South America which is the Jaguar consists of Capybara.',
#  'The primary material used in the construction of the spacecraft that first orbited Mercury which is the Messenger is aluminum.',
#  'The primary architectural style of the building where the Kellogg-Briand Pact was signed Quai dOrsay is Beaux-Arts.',
#  'The primary material used in the construction of the first space station Salyut 1 was aluminum alloy.',
#  'The primary match t-shirt color of the team that won the DFB-Pokal in 2021 was yellow as Borussia Dortmund won the DFB-Pokal in 2021 and their shirt color is yellow.',
#  'The primary architectural style of the building where the United States Constitution was drafted which is Independence Hall is Georgian.',
#  'The primary match t-shirt color of the team that won the French Ligue 1 in 2020 is blue. According to the retrieved relations Paris Saint-Germain won the French Ligue 1 and their shirt color is blue.',
#  'The primary diet of the largest herbivore found in South America which is the Argentinosaurus consisted of plants.',
#  'The primary match t-shirt color of Defensa y Justicia the team that won the Copa Sudamericana in 2020 is yellow.',
#  'The 1986 FIFA World Cup was located in Mexico. The primary language spoken in Mexico is Spanish. However the retrieved relations provided do not mention the primary language spoken in Mexico. Therefore based on the facts given in the retrieved relations I cannot provide a definite answer regarding the primary language spoken in the country that hosted the 1986 FIFA World Cup.',
#  'The primary architectural style of the building where the United States Bill of Rights was signed which is Federal Hall is Georgian. \n\nThis is supported by the multiple retrieved relations indicating that Federal Hall has the architectural style of Georgian. It is also mentioned that it has the Greek Revival style but Georgian is listed first and more frequently.\n',
#  'The primary material used in the construction of the first human-made object to reach the Moon which was Luna 2 is Aluminum Alloy.',
#  'The primary match t-shirt color of the team that won the FA Womens Super League in 2020 which is Chelsea FC Women is blue.',
#  'The largest marine predator found in the Pacific Ocean is the Great White Shark. The primary diet of the Great White Shark consists of marine mammals fish sea lions and seals.',
#  'The primary materials used in the construction of the first successful passenger airplane the Wright Flyer were spruce wood and muslin fabric.',
#  'The primary match t-shirt color of the team that won the Eredivisie in 2021 Ajax is red and white.',
#  'The primary architectural style of the building where the Declaration of the Rights of Man and of the Citizen was drafted the Hôtel de Ville is French Renaissance.',
#  'The primary material used in the construction of the first skyscraper the Home Insurance Building was steel with steel framing.',
#  'The primary language spoken in the country that won the UEFA Euro Championship in 2016 is Portuguese.',
#  'The primary architectural style of the building where the Peace of Westphalia was signed the Town Hall of Münster is Gothic.',
#  'The primary language spoken in France the country that hosted the FIFA Womens World Cup in 2019 is French. However based on the provided retrieved relations the information about the primary language spoken in France is not listed among the facts. Therefore using just the provided retrieved relations we cannot directly determine the primary language spoken in the country that hosted the FIFA Womens World Cup in 2019.']

# %% [markdown]
# # ‌Baseline RAG

# %% [markdown]
# ### Install packages

# %%
# !pip install datasets
# !pip install ragas
# Out:
# Collecting datasets
#   Downloading datasets-3.0.0-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets) (3.16.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.26.4)
# Collecting pyarrow>=15.0.0 (from datasets)
#   Downloading pyarrow-17.0.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (3.3 kB)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.1.4)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.66.5)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess (from datasets)
#   Downloading multiprocess-0.70.16-py310-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: fsspec<=2024.6.1,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]<=2024.6.1,>=2023.1.0->datasets) (2024.6.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.10.5)
# Requirement already satisfied: huggingface-hub>=0.22.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.24.6)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.11.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.22.0->datasets) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2024.8.30)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Downloading datasets-3.0.0-py3-none-any.whl (474 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 474.3/474.3 kB 3.6 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 9.6 MB/s eta 0:00:00
# Downloading pyarrow-17.0.0-cp310-cp310-manylinux_2_28_x86_64.whl (39.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.9/39.9 MB 24.4 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 10.6 MB/s eta 0:00:00
# Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 14.7 MB/s eta 0:00:00
# Installing collected packages: xxhash, pyarrow, dill, multiprocess, datasets
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 14.0.2
#     Uninstalling pyarrow-14.0.2:
#       Successfully uninstalled pyarrow-14.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf-cu12 24.4.1 requires pyarrow<15.0.0a0,>=14.0.1, but you have pyarrow 17.0.0 which is incompatible.
# ibis-framework 8.0.0 requires pyarrow<16,>=2, but you have pyarrow 17.0.0 which is incompatible.
# Successfully installed datasets-3.0.0 dill-0.3.8 multiprocess-0.70.16 pyarrow-17.0.0 xxhash-3.5.0
# Collecting ragas
#   Downloading ragas-0.1.18-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from ragas) (1.26.4)
# Requirement already satisfied: datasets in /usr/local/lib/python3.10/dist-packages (from ragas) (3.0.0)
# Requirement already satisfied: tiktoken in /usr/local/lib/python3.10/dist-packages (from ragas) (0.7.0)
# Requirement already satisfied: langchain in /usr/local/lib/python3.10/dist-packages (from ragas) (0.2.16)
# Requirement already satisfied: langchain-core in /usr/local/lib/python3.10/dist-packages (from ragas) (0.2.39)
# Requirement already satisfied: langchain-community in /usr/local/lib/python3.10/dist-packages (from ragas) (0.2.16)
# Requirement already satisfied: langchain-openai in /usr/local/lib/python3.10/dist-packages (from ragas) (0.1.24)
# Requirement already satisfied: openai>1 in /usr/local/lib/python3.10/dist-packages (from ragas) (1.45.0)
# Collecting pysbd>=0.3.4 (from ragas)
#   Downloading pysbd-0.3.4-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.10/dist-packages (from ragas) (1.6.0)
# Collecting appdirs (from ragas)
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl.metadata (9.0 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai>1->ragas) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai>1->ragas) (1.7.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from openai>1->ragas) (0.27.2)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from openai>1->ragas) (0.5.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from openai>1->ragas) (2.9.1)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai>1->ragas) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai>1->ragas) (4.66.5)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.10/dist-packages (from openai>1->ragas) (4.12.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets->ragas) (3.16.0)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets->ragas) (17.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets->ragas) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets->ragas) (2.1.4)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.10/dist-packages (from datasets->ragas) (2.32.3)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets->ragas) (3.5.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets->ragas) (0.70.16)
# Requirement already satisfied: fsspec<=2024.6.1,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]<=2024.6.1,>=2023.1.0->datasets->ragas) (2024.6.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets->ragas) (3.10.5)
# Requirement already satisfied: huggingface-hub>=0.22.0 in /usr/local/lib/python3.10/dist-packages (from datasets->ragas) (0.24.6)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets->ragas) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets->ragas) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain->ragas) (2.0.34)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from langchain->ragas) (4.0.3)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from langchain->ragas) (0.2.4)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in /usr/local/lib/python3.10/dist-packages (from langchain->ragas) (0.1.120)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain->ragas) (8.5.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.10/dist-packages (from langchain-core->ragas) (1.33)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /usr/local/lib/python3.10/dist-packages (from langchain-community->ragas) (0.6.7)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.10/dist-packages (from tiktoken->ragas) (2024.5.15)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->ragas) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->ragas) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->ragas) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->ragas) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->ragas) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->ragas) (1.11.1)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai>1->ragas) (3.8)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai>1->ragas) (1.2.2)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community->ragas) (3.22.0)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community->ragas) (0.9.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai>1->ragas) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai>1->ragas) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai>1->ragas) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.10/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core->ragas) (3.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.17->langchain->ragas) (3.10.7)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai>1->ragas) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.3 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai>1->ragas) (2.23.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets->ragas) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets->ragas) (2.0.7)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain->ragas) (3.1.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->ragas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->ragas) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->ragas) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets->ragas) (1.16.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community->ragas) (1.0.0)
# Downloading ragas-0.1.18-py3-none-any.whl (185 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 185.7/185.7 kB 1.4 MB/s eta 0:00:00
# Downloading pysbd-0.3.4-py3-none-any.whl (71 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.1/71.1 kB 4.8 MB/s eta 0:00:00
# Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Installing collected packages: appdirs, pysbd, ragas
# Successfully installed appdirs-1.4.4 pysbd-0.3.4 ragas-0.1.18

# %% [markdown]
# ### Baseline RAG

# %%
import pandas as pd

file_path = 'shuffled_dataset.csv'
data = pd.read_csv(file_path)

translated_texts = data['text']

output_file_path = 'rag_repo.txt'

with open(output_file_path, 'w') as file:
    for text in translated_texts:
        file.write(text + '\n\n')

# %%
from langchain.document_loaders import TextLoader

loader = TextLoader('./rag_repo.txt')
documents = loader.load()

# %%
from langchain.text_splitter import CharacterTextSplitter
text_splitter = CharacterTextSplitter(chunk_size=500, chunk_overlap=50)
chunks = text_splitter.split_documents(documents)
# Out:
# WARNING:langchain_text_splitters.base:Created a chunk of size 520, which is longer than the specified 500

# %%
# !pip install langchain openai weaviate-client
# Out:
# Requirement already satisfied: langchain in /usr/local/lib/python3.10/dist-packages (0.2.16)
# Requirement already satisfied: openai in /usr/local/lib/python3.10/dist-packages (1.45.0)
# Collecting weaviate-client
#   Downloading weaviate_client-4.8.1-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.0.34)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain) (3.10.5)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (4.0.3)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.38 in /usr/local/lib/python3.10/dist-packages (from langchain) (0.2.39)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (0.2.4)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in /usr/local/lib/python3.10/dist-packages (from langchain) (0.1.120)
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain) (1.26.4)
# Requirement already satisfied: pydantic<3,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.9.1)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (8.5.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai) (1.7.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from openai) (0.27.2)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from openai) (0.5.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai) (4.66.5)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.10/dist-packages (from openai) (4.12.2)
# Collecting httpx<1,>=0.23.0 (from openai)
#   Downloading httpx-0.27.0-py3-none-any.whl.metadata (7.2 kB)
# Collecting validators==0.34.0 (from weaviate-client)
#   Downloading validators-0.34.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting authlib<1.3.2,>=1.2.1 (from weaviate-client)
#   Downloading Authlib-1.3.1-py2.py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: grpcio<2.0.0,>=1.57.0 in /usr/local/lib/python3.10/dist-packages (from weaviate-client) (1.64.1)
# Collecting grpcio-tools<2.0.0,>=1.57.0 (from weaviate-client)
#   Downloading grpcio_tools-1.66.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.3 kB)
# Collecting grpcio-health-checking<2.0.0,>=1.57.0 (from weaviate-client)
#   Downloading grpcio_health_checking-1.66.1-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.11.1)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (3.8)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (1.2.2)
# Requirement already satisfied: cryptography in /usr/local/lib/python3.10/dist-packages (from authlib<1.3.2,>=1.2.1->weaviate-client) (43.0.1)
# Collecting protobuf<6.0dev,>=5.26.1 (from grpcio-health-checking<2.0.0,>=1.57.0->weaviate-client)
#   Downloading protobuf-5.28.1-cp38-abi3-manylinux2014_x86_64.whl.metadata (592 bytes)
# Collecting grpcio<2.0.0,>=1.57.0 (from weaviate-client)
#   Downloading grpcio-1.66.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.9 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from grpcio-tools<2.0.0,>=1.57.0->weaviate-client) (71.0.4)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.3.0,>=0.2.38->langchain) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.3.0,>=0.2.38->langchain) (24.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.17->langchain) (3.10.7)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.3 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain) (2.23.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (2.0.7)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain) (3.1.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.10/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.38->langchain) (3.0.0)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography->authlib<1.3.2,>=1.2.1->weaviate-client) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography->authlib<1.3.2,>=1.2.1->weaviate-client) (2.22)
# Downloading weaviate_client-4.8.1-py3-none-any.whl (374 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 374.5/374.5 kB 2.1 MB/s eta 0:00:00
# Downloading validators-0.34.0-py3-none-any.whl (43 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.5/43.5 kB 3.1 MB/s eta 0:00:00
# Downloading Authlib-1.3.1-py2.py3-none-any.whl (223 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 223.8/223.8 kB 15.7 MB/s eta 0:00:00
# Downloading grpcio_health_checking-1.66.1-py3-none-any.whl (18 kB)
# Downloading grpcio-1.66.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.7/5.7 MB 37.8 MB/s eta 0:00:00
# Downloading grpcio_tools-1.66.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 59.7 MB/s eta 0:00:00
# Downloading httpx-0.27.0-py3-none-any.whl (75 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 5.8 MB/s eta 0:00:00
# Downloading protobuf-5.28.1-cp38-abi3-manylinux2014_x86_64.whl (316 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 316.6/316.6 kB 21.9 MB/s eta 0:00:00
# Installing collected packages: validators, protobuf, grpcio, httpx, grpcio-tools, grpcio-health-checking, authlib, weaviate-client
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
#   Attempting uninstall: grpcio
#     Found existing installation: grpcio 1.64.1
#     Uninstalling grpcio-1.64.1:
#       Successfully uninstalled grpcio-1.64.1
#   Attempting uninstall: httpx
#     Found existing installation: httpx 0.27.2
#     Uninstalling httpx-0.27.2:
#       Successfully uninstalled httpx-0.27.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf-cu12 24.4.1 requires protobuf<5,>=3.20, but you have protobuf 5.28.1 which is incompatible.
# cudf-cu12 24.4.1 requires pyarrow<15.0.0a0,>=14.0.1, but you have pyarrow 17.0.0 which is incompatible.
# google-ai-generativelanguage 0.6.6 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5, but you have protobuf 5.28.1 which is incompatible.
# google-cloud-datastore 2.19.0 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5, but you have protobuf 5.28.1 which is incompatible.
# google-cloud-firestore 2.16.1 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5, but you have protobuf 5.28.1 which is incompatible.
# tensorboard 2.17.0 requires protobuf!=4.24.0,<5.0.0,>=3.19.6, but you have protobuf 5.28.1 which is incompatible.
# tensorflow 2.17.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3, but you have protobuf 5.28.1 which is incompatible.
# tensorflow-metadata 1.15.0 requires protobuf<4.21,>=3.20.3; python_version < "3.11", but you have protobuf 5.28.1 which is incompatible.
# Successfully installed authlib-1.3.1 grpcio-1.66.1 grpcio-health-checking-1.66.1 grpcio-tools-1.66.1 httpx-0.27.0 protobuf-5.28.1 validators-0.34.0 weaviate-client-4.8.1

# %%
from langchain.embeddings import OpenAIEmbeddings
from langchain.vectorstores import Weaviate
import weaviate
from weaviate.embedded import EmbeddedOptions
import os

os.environ["OPENAI_API_KEY"] = input("Enter your OpenAI API Key: ")

client = weaviate.Client(
  embedded_options = EmbeddedOptions()
)

vectorstore = Weaviate.from_documents(
    client = client,
    documents = chunks,
    embedding = OpenAIEmbeddings(),
    by_text = False
)

class LoggingRetriever:
    def __init__(self, retriever):
        self.retriever = retriever

    def get_relevant_documents(self, query):
        docs = self.retriever.get_relevant_documents(query)
        print(f"Retrieved documents for query '{query}':")
        for doc in docs:
            print(doc.page_content)
        return docs

logging_retriever = LoggingRetriever(vectorstore.as_retriever())
# Out:
# <ipython-input-79-4bbe1cc37146>:9: DeprecationWarning:
# Python client v3 `weaviate.Client(...)` connections and methods are deprecated and will
#             be removed by 2024-11-30.
#
#             Upgrade your code to use Python client v4 `weaviate.WeaviateClient` connections and methods.
#                 - For Python Client v4 usage, see: https://weaviate.io/developers/weaviate/client-libraries/python
#                 - For code migration, see: https://weaviate.io/developers/weaviate/client-libraries/python/v3_v4_migration
#
#             If you have to use v3 code, install the v3 client and pin the v3 dependency in your requirements file: `weaviate-client>=3.26.7;<4.0.0`
#   client = weaviate.Client(
# INFO:weaviate-client:Binary /root/.cache/weaviate-embedded did not exist. Downloading binary from https://github.com/weaviate/weaviate/releases/download/v1.26.1/weaviate-v1.26.1-Linux-amd64.tar.gz
# INFO:weaviate-client:Started /root/.cache/weaviate-embedded: process ID 84516
# <ipython-input-79-4bbe1cc37146>:16: LangChainDeprecationWarning: The class `OpenAIEmbeddings` was deprecated in LangChain 0.0.9 and will be removed in 1.0. An updated version of the class exists in the langchain-openai package and should be used instead. To use it run `pip install -U langchain-openai` and import as `from langchain_openai import OpenAIEmbeddings`.
#   embedding = OpenAIEmbeddings(),

# %%
from langchain.prompts import ChatPromptTemplate

template = """You are an assistant for question-answering tasks.
Use the following pieces of retrieved context to answer the question.
Limit your knowledge to the provided data If you can't answer the question based on provided data, just say that you don't know.
Use three sentences maximum and keep the answer concise.
Question: {question}
Context: {context}
Answer:
"""
prompt = ChatPromptTemplate.from_template(template)

# %%
from langchain.chat_models import ChatOpenAI
from langchain.schema.runnable import RunnablePassthrough
from langchain.schema.output_parser import StrOutputParser

llm = ChatOpenAI(model_name="gpt-3.5-turbo", temperature=0)

def retriever_fn(query):
    docs = logging_retriever.get_relevant_documents(query)
    return {'context': "\n".join([doc.page_content for doc in docs]), 'question': query}

rag_chain = (
    retriever_fn
    | prompt
    | llm
    | StrOutputParser()
)

langchain_answers = []

for query in questions:
    langchain_answers.append(rag_chain.invoke(query))
# Out:
# <ipython-input-81-58ff96ceb0a7>:5: LangChainDeprecationWarning: The class `ChatOpenAI` was deprecated in LangChain 0.0.10 and will be removed in 1.0. An updated version of the class exists in the langchain-openai package and should be used instead. To use it run `pip install -U langchain-openai` and import as `from langchain_openai import ChatOpenAI`.
#   llm = ChatOpenAI(model_name="gpt-3.5-turbo", temperature=0)
# <ipython-input-79-4bbe1cc37146>:25: LangChainDeprecationWarning: The method `BaseRetriever.get_relevant_documents` was deprecated in langchain-core 0.1.46 and will be removed in 1.0. Use invoke instead.
#   docs = self.retriever.get_relevant_documents(query)
# Streaming output truncated to the last 5000 lines.
#
# The primary match t-shirt color of Borussia Dortmund is yellow.
# The primary color of the United States' jersey is white.
#
# Japan won the FIFA Women's World Cup in 2011.
#
# The primary material used in the construction of the Gossamer Albatross was carbon fiber.
#
# Portugal won the Eurovision Song Contest in 2017
#
# France won the FIFA World Cup in 2018.
#
# Cafu primarily played as a right-back.
#
# Manchester City won the English Premier League in the 2017-2018 season.
#
# The primary material used in the construction of Luna 2 was aluminum alloy.
# For over 100 years the colours blue and garnet have come together on the shirts of FC BARCELONA players and this is why the Club is also known as the equip blaugrana (blue and garnet team). The colours have always been used on the team kit especially the shirt. The shorts were white for the first 10 years of the Club's history then black and since the 1920s blue.
#
# Defensa y Justicia won the Copa Sudamericana in 2020.
#
# Philipp Lahm's primary position was right back.
# Retrieved documents for query 'Who was captain of the team that won the Stanley Cup in 2019?':
# The Chicago Blackhawks won the Stanley Cup in 2013 on a shortened season
#
# Canada hosted the World Expo in 1967.
#
# Liverpool won the FA Cup in 2006.
#
# Inter Milan won the Serie A in 2021.
#
# Nicklas Lidstrï¿½m was the captain of the Red Wings in 2008, and he played as a defenseman.
#
# The Livadia Palace is designed in the Neo-Renaissance architectural style.
#
# Frï¿½dï¿½ric Auguste Bartholdi was the sculptor responsible for designing the Statue of Liberty.
# Carlos Alberto Parreira was the manager of Brazil in 1994.
#
# Mikel Oyarzabal was the captain of Real Sociedad in 2020.
#
# The legendary American author Ernest Hemingway won the Nobel Prize in Literature in 1954.
#
# John Eales was the captain of the Australian national rugby team in 1999.
#
# The Golden State Warriors won the NBA Finals in 2018. They defeated the Cleveland Cavaliers in four games to capture their third championship in four years.
#
# Cesar Azpilicueta was the captain of Chelsea in 2021.
# Tom Brady won the MVP award in the 2017 NFL season.
#
# The primary mission of New Horizons was to study Pluto and its moons.
#
# Diego Lugano primarily played as a central defender.
#
# River Plate won the Copa Libertadores in 2018.
#
# Barcelona won the Copa del Rey in 2018.
#
# Jupp Heynckes was the manager of Bayern Munich in 2013.
#
# Canada hosted the Winter Olympics in 1988.
#
# The primary material used in the construction of MESSENGER was aluminum and titanium.
#
# Greece hosted the Summer Olympics in 2004.
# Barcelona won the La Liga in 2019.
#
# The Congress of Vienna was held at the Hofburg Palace in Vienna.
#
# Under the leadership of Didier Deschamps and three-time FIFA World Player of the Year Zinedine Zidane, France won the FIFA World Cup in 1998.
#
# Italy won the FIFA World Cup in 2006.
#
# Forrest Gump' won the Academy Award for Best Picture in 1994
#
# The primary material used in the construction of Vostok 1 was aluminum alloy.
# Retrieved documents for query 'What was the primary diet of the largest land carnivore during the Cretaceous period?':
# The largest land carnivore during the Cretaceous period was Tyrannosaurus rex.
#
# African elephants are herbivores. As herbivores they spend much of their days foraging and eating grass leaves bark fruit and a variety of foliage. They need to eat about 350 pounds of vegetation every day. African bush elephants are also known as African savanna elephants.
#
# To Kill a Mocking Bird', won Pulitzer Prize for fiction in 1961.
#
# Steven Gerrard was the captain of Liverpool in 2005.
# The Congress of the Confederation was held in Independence Hall, Philadelphia.
#
# The primary diet of killer whales includes fish, seals, and squid.
#
# The Hôtel de Ville is designed in the French Renaissance architectural style.
#
# The primary color of the Chicago Cubs' uniform is blue.
#
# Spinosaurus is considered the largest carnivorous dinosaur ever discovered.
#
# Chelsea won the Champions League in 2021.
#
# The largest flying bird in history is believed to be Argentavis.
# The Miami Heat won the NBA Finals in 2013.
#
# 'To Kill a Mockingbird' main character Atticus Finch lives by this saying he judges the seeds he plants not his success each day
#
# The largest herbivorous dinosaur, Argentinosaurus, had a primarily plant-based diet
#
# The economy of Salt Lake City, Utah is primarily service-oriented.
#
# Norway won the Eurovision Song Contest in 2009.
#
# The Palace of Justice is located in Germany.
#
# The largest predator found in the Amazon rainforest is the jaguar.
# The primary diet of capybaras consists of grasses and aquatic plants.
#
# The primary industry of Amazon is e-commerce, cloud computing, and artificial intelligence.
#
# The United States hosted the Summer Olympics in 1996.
#
# The primary match t-shirt color of Ajax is red and white.
#
# Alex Pietrangelo was the captain of the St. Louis Blues in 2019.
#
# The primary diet of black caimans includes fish, birds, and mammals.
#
# Derrick Rose wore jersey number 1.
# Retrieved documents for query 'Where Were fossils of largest land carnivore during the Cretaceous period discovered?':
# The largest land carnivore during the Cretaceous period was Tyrannosaurus rex.
#
# African elephants are herbivores. As herbivores they spend much of their days foraging and eating grass leaves bark fruit and a variety of foliage. They need to eat about 350 pounds of vegetation every day. African bush elephants are also known as African savanna elephants.
#
# To Kill a Mocking Bird', won Pulitzer Prize for fiction in 1961.
#
# Steven Gerrard was the captain of Liverpool in 2005.
# The Congress of the Confederation was held in Independence Hall, Philadelphia.
#
# The primary diet of killer whales includes fish, seals, and squid.
#
# The Hôtel de Ville is designed in the French Renaissance architectural style.
#
# The primary color of the Chicago Cubs' uniform is blue.
#
# Spinosaurus is considered the largest carnivorous dinosaur ever discovered.
#
# Chelsea won the Champions League in 2021.
#
# The largest flying bird in history is believed to be Argentavis.
# The Miami Heat won the NBA Finals in 2013.
#
# 'To Kill a Mockingbird' main character Atticus Finch lives by this saying he judges the seeds he plants not his success each day
#
# The largest herbivorous dinosaur, Argentinosaurus, had a primarily plant-based diet
#
# The economy of Salt Lake City, Utah is primarily service-oriented.
#
# Norway won the Eurovision Song Contest in 2009.
#
# The Palace of Justice is located in Germany.
#
# The largest predator found in the Amazon rainforest is the jaguar.
# The Magna Carta was signed at Runnymede in 1215.
#
# The primary diet of the Blue Whale consists of krill, which are small, shrimp-like creatures.
#
# The largest carnivorous dinosaur in South America was the Giganotosaurus.
#
# The primary match t-shirt color of Real Betis is green and white.
#
# The Jefferson Memorial is a national memorial in Washington, D.C., built in honor of Thomas Jefferson
#
# The largest marine predator in the Southern Ocean is the killer whale.
# Retrieved documents for query 'What was the primary language spoken in the country that won the Eurovision Song Contest in 2009, and who was the winner?':
# Alexander Rybak was the winner of the Eurovision Song Contest in 2009.
#
# The primary language spoken in Italy is Italian.
#
# The winning artist for Germany in the 2010 Eurovision Song Contest was Lena.
#
# Real Madrid won the UEFA Champions League in 2018.
#
# The primary diet of the Kodiak bear includes salmon, berries, and small mammals.
#
# Polar bears are the top predator in the Arctic marine ecosystem.
#
# The main character in 'The Executioner's Song' is Gary Gilmore.
# Ukraine won the Eurovision Song Contest in 2016.
#
# The primary color of the France football jersey is blue, representing the national motto of France, "Liberty, Equality, Fraternity."
#
# The primary language spoken in Israel is Hebrew.
#
# The spacecraft that first orbited Mercury was MESSENGER.
#
# Juventus won the Italian Serie A in 2019.
#
# The primary match t-shirt color of Columbus Crew is yellow.
#
# Ãverton Ribeiro was the captain of Flamengo in 2019.
# The primary language spoken in Germany is German. German is a West Germanic language and is one of the most widely spoken languages in Europe.
#
# Luis SuÃ¡rez was the top scorer for Uruguay in the 2011 Copa AmÃ©rica.
#
# The primary material used in the construction of the Apollo 11 spacecraft was aluminum.
#
# The home stadium of Paris Saint-Germain is Parc des Princes.
#
# Sevilla won the UEFA Europa League in 2020.
# The primary language spoken in West Germany was German.
#
# Brazil won the FIFA World Cup in 2002.
#
# Chelsea won the UEFA Europa League in 2019.
#
# The Los Angeles Lakers won the NBA Finals in 2020.
#
# The home stadium of the Chicago Cubs is Wrigley Field.
#
# Fossils of woolly mammoths have been primarily discovered in Siberia and North America.
#
# The novel 'The Executioner's Song' won the Pulitzer Prize for Fiction in 1980.
#
# The Magna Carta was signed at Runnymede in 1215.
# Retrieved documents for query 'Who was the captain of the team that won the FIFA World Cup in 2002?':
# The Colosseum was commissioned by Emperor Vespasian in AD 72.
#
# The primary match t-shirt color of Paris Saint-Germain is blue.
#
# The FIFA World Cup in 1994 was hosted by the United States.
#
# Juventus won the Serie A in the 2019-2020 season.
#
# Jonathan Toews was the captain of the Chicago Blackhawks from 2008-2023. He is now retired.
#
# Luiz Felipe Scolari was the head coach of Brazil during the 2002 FIFA World Cup.
# Carlos Alberto Parreira was the manager of Brazil in 1994.
#
# Mikel Oyarzabal was the captain of Real Sociedad in 2020.
#
# The legendary American author Ernest Hemingway won the Nobel Prize in Literature in 1954.
#
# John Eales was the captain of the Australian national rugby team in 1999.
#
# The Golden State Warriors won the NBA Finals in 2018. They defeated the Cleveland Cavaliers in four games to capture their third championship in four years.
#
# Cesar Azpilicueta was the captain of Chelsea in 2021.
# Barcelona won the La Liga in 2019.
#
# The Congress of Vienna was held at the Hofburg Palace in Vienna.
#
# Under the leadership of Didier Deschamps and three-time FIFA World Player of the Year Zinedine Zidane, France won the FIFA World Cup in 1998.
#
# Italy won the FIFA World Cup in 2006.
#
# Forrest Gump' won the Academy Award for Best Picture in 1994
#
# The primary material used in the construction of Vostok 1 was aluminum alloy.
# South Africa won the Rugby World Cup in 2007.
#
# Known for his ability to perform in crucial moments, Iniesta scored the winning goal in the 2010 FIFA World Cup final, securing Spain's first World Cup. He also played a key role in Spain's victories at Euro 2008 and Euro 2012.
#
# Federal Hall is designed in the Greek Revival architectural style.
#
# South Africa won the Rugby World Cup in 1995.
#
# Brazil won the Copa America in 2019.
# Retrieved documents for query 'What was primary position of the captain of the team that won the FIFA World Cup in 2002?':
# Philipp Lahm's primary position was right back.
#
# Rangers F.C. won the Scottish Premiership in 2020.
#
# Barcelona won the La Liga in 2018.
#
# Manchester City won the English Premier League in the 2020-2021 season.
#
# Germany hosted the FIFA World Cup in 2006
#
# Diego Lugano was the captain of the Uruguay national team in 2011.
#
# Sailors during the Age of Exploration often relied on hardtack as a primary food source.
#
# The first skyscraper was the Home Insurance Building in Chicago.
# The primary color of the United States' jersey is white.
#
# Japan won the FIFA Women's World Cup in 2011.
#
# The primary material used in the construction of the Gossamer Albatross was carbon fiber.
#
# Portugal won the Eurovision Song Contest in 2017
#
# France won the FIFA World Cup in 2018.
#
# Cafu primarily played as a right-back.
#
# Manchester City won the English Premier League in the 2017-2018 season.
#
# The primary material used in the construction of Luna 2 was aluminum alloy.
# The Colosseum was commissioned by Emperor Vespasian in AD 72.
#
# The primary match t-shirt color of Paris Saint-Germain is blue.
#
# The FIFA World Cup in 1994 was hosted by the United States.
#
# Juventus won the Serie A in the 2019-2020 season.
#
# Jonathan Toews was the captain of the Chicago Blackhawks from 2008-2023. He is now retired.
#
# Luiz Felipe Scolari was the head coach of Brazil during the 2002 FIFA World Cup.
# Barcelona won the La Liga in 2019.
#
# The Congress of Vienna was held at the Hofburg Palace in Vienna.
#
# Under the leadership of Didier Deschamps and three-time FIFA World Player of the Year Zinedine Zidane, France won the FIFA World Cup in 1998.
#
# Italy won the FIFA World Cup in 2006.
#
# Forrest Gump' won the Academy Award for Best Picture in 1994
#
# The primary material used in the construction of Vostok 1 was aluminum alloy.
# Retrieved documents for query 'What was the primary color of the jersey worn by the team that won the World Series in 2017?':
# The primary color of the United States' jersey is white.
#
# Japan won the FIFA Women's World Cup in 2011.
#
# The primary material used in the construction of the Gossamer Albatross was carbon fiber.
#
# Portugal won the Eurovision Song Contest in 2017
#
# France won the FIFA World Cup in 2018.
#
# Cafu primarily played as a right-back.
#
# Manchester City won the English Premier League in the 2017-2018 season.
#
# The primary material used in the construction of Luna 2 was aluminum alloy.
# Real Madrid won the La Liga in 2020.
#
# The primary match t-shirt color of the Golden State Warriors is blue.
#
# The Commonwealth Games in 2018 were hosted by Australia.
#
# The first artificial heart, known as the Jarvik-7, was made primarily of polyurethane.
#
# The primary match t-shirt color of Chelsea FC Women is blue.
#
# The primary color of Manchester United's jersey is red.
#
# Norway hosted the Eurovision Song Contest in 2010.
#
# The primary match t-shirt color of Borussia Dortmund is yellow.
# When Liverpool won the Champions League in 2019, three quarters of a million people took to the streets.
#
# The primary match t-shirt color of Argentina is light blue and white.
#
# The architectural style of Westminster Central Hall is Edwardian Baroque.
#
# The primary diet of the whale shark consists of plankton and small fish.
#
# Bayern Munich won the UEFA Champions League in 2013.
#
# The primary color of the Eagles' jersey is midnight green.
#
# The primary color of the Lakers' jersey is purple and gold.
# The Sevilla FC primary colors are red and white.
#
# The primary color of Flamengo's jersey is red and black.
#
# The Philadelphia Eagles won the Super Bowl in 2018.
#
# The largest fish found in the ocean is the whale shark.
#
# Portugal won the UEFA Euro Championship in 2016.
#
# Arsenal's home stadium at that time was Highbury.
#
# Harry Kane won the Golden Boot in the 2018 FIFA World Cup.
#
# The woolly mammoth primarily fed on grasses, shrubs, and herbs.
# Retrieved documents for query 'During which era did the largest herbivorous dinosaur in North America live?':
# The largest land carnivore during the Cretaceous period was Tyrannosaurus rex.
#
# African elephants are herbivores. As herbivores they spend much of their days foraging and eating grass leaves bark fruit and a variety of foliage. They need to eat about 350 pounds of vegetation every day. African bush elephants are also known as African savanna elephants.
#
# To Kill a Mocking Bird', won Pulitzer Prize for fiction in 1961.
#
# Steven Gerrard was the captain of Liverpool in 2005.
# The Miami Heat won the NBA Finals in 2013.
#
# 'To Kill a Mockingbird' main character Atticus Finch lives by this saying he judges the seeds he plants not his success each day
#
# The largest herbivorous dinosaur, Argentinosaurus, had a primarily plant-based diet
#
# The economy of Salt Lake City, Utah is primarily service-oriented.
#
# Norway won the Eurovision Song Contest in 2009.
#
# The Palace of Justice is located in Germany.
#
# The largest predator found in the Amazon rainforest is the jaguar.
# The Congress of the Confederation was held in Independence Hall, Philadelphia.
#
# The primary diet of killer whales includes fish, seals, and squid.
#
# The Hôtel de Ville is designed in the French Renaissance architectural style.
#
# The primary color of the Chicago Cubs' uniform is blue.
#
# Spinosaurus is considered the largest carnivorous dinosaur ever discovered.
#
# Chelsea won the Champions League in 2021.
#
# The largest flying bird in history is believed to be Argentavis.
# The town hall of Münster is designed in the Gothic architectural style.
#
# The largest herbivorous dinosaur in North America, the Brachiosaurus, primarily ate plants.
#
# The Netherlands won the Eurovision Song Contest in 2019.
#
# Spain won the FIFA World Cup in 2010.
#
# Wayne Rooney was the captain of Manchester United in 2017.
#
# The film 'The Lord of the Rings: The Return of the King' won the Academy Award for Best Picture in 2003.
#
# The Berlin Wall was primarily constructed using concrete.
# Retrieved documents for query 'Who was the captain of the team that won the La Liga in 2012?':
# Carlos Alberto Parreira was the manager of Brazil in 1994.
#
# Mikel Oyarzabal was the captain of Real Sociedad in 2020.
#
# The legendary American author Ernest Hemingway won the Nobel Prize in Literature in 1954.
#
# John Eales was the captain of the Australian national rugby team in 1999.
#
# The Golden State Warriors won the NBA Finals in 2018. They defeated the Cleveland Cavaliers in four games to capture their third championship in four years.
#
# Cesar Azpilicueta was the captain of Chelsea in 2021.
# Barcelona won the La Liga in 2019.
#
# The Congress of Vienna was held at the Hofburg Palace in Vienna.
#
# Under the leadership of Didier Deschamps and three-time FIFA World Player of the Year Zinedine Zidane, France won the FIFA World Cup in 1998.
#
# Italy won the FIFA World Cup in 2006.
#
# Forrest Gump' won the Academy Award for Best Picture in 1994
#
# The primary material used in the construction of Vostok 1 was aluminum alloy.
# Carlos Bilardo was the manager of the Argentina national team in 1986.
#
# GrÃªmioâ€™s primary uniform color is blue.
#
# Brazil won the Copa America in 2019.
#
# The primary match t-shirt color of Manchester City is sky blue.
#
# Valencia won the Copa del Rey in 2019.
#
# The Golden State Warriors won the NBA Finals in 2015.
#
# Lucas Ocampos was the top scorer for Sevilla in the 2020 UEFA Europa League.
# Argentina won the FIFA World Cup in 1986.
#
# Atletico Madrid won the La Liga title in 2014, also finishing runners up to Real Madrid in the Champions League final the same year.
#
# The primary language spoken in Spain is Spanish.
#
# Paris Saint-Germain won the French Cup in 2021.
#
# The Houston Astros won the World Series in 2017.
#
# The first successful passenger airplane was the Wright Flyer.
#
# The Wright Flyer was constructed using spruce wood and muslin fabric.
# Retrieved documents for query 'What was the primary color of the team that won the La Liga in 2012?':
# Real Madrid won the La Liga in 2020.
#
# The primary match t-shirt color of the Golden State Warriors is blue.
#
# The Commonwealth Games in 2018 were hosted by Australia.
#
# The first artificial heart, known as the Jarvik-7, was made primarily of polyurethane.
#
# The primary match t-shirt color of Chelsea FC Women is blue.
#
# The primary color of Manchester United's jersey is red.
#
# Norway hosted the Eurovision Song Contest in 2010.
#
# The primary match t-shirt color of Borussia Dortmund is yellow.
# For over 100 years the colours blue and garnet have come together on the shirts of FC BARCELONA players and this is why the Club is also known as the equip blaugrana (blue and garnet team). The colours have always been used on the team kit especially the shirt. The shorts were white for the first 10 years of the Club's history then black and since the 1920s blue.
#
# Defensa y Justicia won the Copa Sudamericana in 2020.
#
# Philipp Lahm's primary position was right back.
# When Liverpool won the Champions League in 2019, three quarters of a million people took to the streets.
#
# The primary match t-shirt color of Argentina is light blue and white.
#
# The architectural style of Westminster Central Hall is Edwardian Baroque.
#
# The primary diet of the whale shark consists of plankton and small fish.
#
# Bayern Munich won the UEFA Champions League in 2013.
#
# The primary color of the Eagles' jersey is midnight green.
#
# The primary color of the Lakers' jersey is purple and gold.
# The Sevilla FC primary colors are red and white.
#
# The primary color of Flamengo's jersey is red and black.
#
# The Philadelphia Eagles won the Super Bowl in 2018.
#
# The largest fish found in the ocean is the whale shark.
#
# Portugal won the UEFA Euro Championship in 2016.
#
# Arsenal's home stadium at that time was Highbury.
#
# Harry Kane won the Golden Boot in the 2018 FIFA World Cup.
#
# The woolly mammoth primarily fed on grasses, shrubs, and herbs.
# Retrieved documents for query 'What was the primary language spoken in the country that won the FIFA World Cup in 2018?':
# The primary language spoken in Germany is German. German is a West Germanic language and is one of the most widely spoken languages in Europe.
#
# Luis SuÃ¡rez was the top scorer for Uruguay in the 2011 Copa AmÃ©rica.
#
# The primary material used in the construction of the Apollo 11 spacecraft was aluminum.
#
# The home stadium of Paris Saint-Germain is Parc des Princes.
#
# Sevilla won the UEFA Europa League in 2020.
# Argentina won the FIFA World Cup in 1986.
#
# Atletico Madrid won the La Liga title in 2014, also finishing runners up to Real Madrid in the Champions League final the same year.
#
# The primary language spoken in Spain is Spanish.
#
# Paris Saint-Germain won the French Cup in 2021.
#
# The Houston Astros won the World Series in 2017.
#
# The first successful passenger airplane was the Wright Flyer.
#
# The Wright Flyer was constructed using spruce wood and muslin fabric.
# Brazil won the Copa America in 2019.
#
# Polar bearsï¿½ diet consists mainly of seals as they require large amounts of fat to survive the cold climate.
#
# The United States won the FIFA Women's World Cup in 2015.
#
# The primary language spoken in South Korea is Korean.
#
# The primary language spoken in the United Kingdom is English.
#
# The Winter Olympics in 2018 were hosted in Pyeongchang, South Korea.
#
# The largest reptile found in the Nile River is the Nile crocodile.
# The primary language spoken in West Germany was German.
#
# Brazil won the FIFA World Cup in 2002.
#
# Chelsea won the UEFA Europa League in 2019.
#
# The Los Angeles Lakers won the NBA Finals in 2020.
#
# The home stadium of the Chicago Cubs is Wrigley Field.
#
# Fossils of woolly mammoths have been primarily discovered in Siberia and North America.
#
# The novel 'The Executioner's Song' won the Pulitzer Prize for Fiction in 1980.
#
# The Magna Carta was signed at Runnymede in 1215.
# Retrieved documents for query 'Who was the director of the movie that won the Academy Award for Best Picture in 1994?':
# Robert Zemeckis was the director of 'Forrest Gump'
#
# The main character of 'The Killer Angels' is General Robert E. Lee.
#
# The United States hosted the Summer Olympics in 1984.
#
# Real Betis won the Copa del Rey in 2022.
#
# Trade, particularly in incense and spices, was the primary economic activity of the Nabatean civilization.
#
# The Apollo 11 spacecraft was the first to land humans on the Moon.
#
# The 2000 Summer Olympics took place in Sydney
#
# The primary language spoken in Australia is English.
# Arthur Miller won the Pulitzer Prize for Drama in 1949 for his play, Death of a Salesman. The success of the play brought Miller to national acclaim. The play was also his most successful.
#
# East Germany (the German Democratic Republic) was responsible for constructing the Berlin Wall.
#
# The Battle of Hastings was commemorated at Battle Abbey, built on the site of the battle.
#
# The Chicago Cubs won the MLB World Series in 2016.
#
# Federal Hall was built in the Georgian architectural style.
# Borussia Dortmund won the DFB-Pokal in 2021.
#
# Fossils of Argentinosaurus were discovered in South America.
#
# Forrest Gump' won the Academy Award for Best Picture in 1994.
#
# The primary theme of 'Forrest Gump' is the life journey of an everyman who witnesses and influences some of the most significant events in American history.
#
# The primary language spoken in Russia is Russian.
#
# The United States won the FIFA Women's World Cup in 2019, defeating the Netherlands in the final.
# Carlos Alberto Parreira was the manager of Brazil in 1994.
#
# Mikel Oyarzabal was the captain of Real Sociedad in 2020.
#
# The legendary American author Ernest Hemingway won the Nobel Prize in Literature in 1954.
#
# John Eales was the captain of the Australian national rugby team in 1999.
#
# The Golden State Warriors won the NBA Finals in 2018. They defeated the Cleveland Cavaliers in four games to capture their third championship in four years.
#
# Cesar Azpilicueta was the captain of Chelsea in 2021.
# Retrieved documents for query 'What was the primary theme of the movie that won the Academy Award for Best Picture in 1994?':
# Borussia Dortmund won the DFB-Pokal in 2021.
#
# Fossils of Argentinosaurus were discovered in South America.
#
# Forrest Gump' won the Academy Award for Best Picture in 1994.
#
# The primary theme of 'Forrest Gump' is the life journey of an everyman who witnesses and influences some of the most significant events in American history.
#
# The primary language spoken in Russia is Russian.
#
# The United States won the FIFA Women's World Cup in 2019, defeating the Netherlands in the final.
# The novel 'The Killer Angels' won the Pulitzer Prize for Fiction in 1975.
#
# David Villa was the top scorer for Spain in the 2010 FIFA World Cup.
#
# Gary Cahill was the captain of Chelsea in 2017.
#
# Death of a Salesman is probably best known for its theme of the futility and unattainability of the American Dream.
#
# Manchester United won the English Premier League in 2013.
#
# The primary color of France's jersey is blue.
#
# The 1998 Winter Olympics were hosted by Japan.
# Robert Zemeckis was the director of 'Forrest Gump'
#
# The main character of 'The Killer Angels' is General Robert E. Lee.
#
# The United States hosted the Summer Olympics in 1984.
#
# Real Betis won the Copa del Rey in 2022.
#
# Trade, particularly in incense and spices, was the primary economic activity of the Nabatean civilization.
#
# The Apollo 11 spacecraft was the first to land humans on the Moon.
#
# The 2000 Summer Olympics took place in Sydney
#
# The primary language spoken in Australia is English.
# Arthur Miller won the Pulitzer Prize for Drama in 1949 for his play, Death of a Salesman. The success of the play brought Miller to national acclaim. The play was also his most successful.
#
# East Germany (the German Democratic Republic) was responsible for constructing the Berlin Wall.
#
# The Battle of Hastings was commemorated at Battle Abbey, built on the site of the battle.
#
# The Chicago Cubs won the MLB World Series in 2016.
#
# Federal Hall was built in the Georgian architectural style.
# Retrieved documents for query 'Where was the building located in which the Declaration of Independence was signed?':
# The Declaration of Independence was signed in Independence Hall, Philadelphia, Pennsylvania.
#
# The New England Patriots won the Super Bowl in 2015.
#
# Liverpool won the UEFA Champions League in 2005.
#
# The Inca civilization built Machu Picchu.
#
# The Golden State Warriors colors are Warriors blue and golden yellow.
#
# The Panathenaic Stadium was rebuilt by architect Anastasios Metaxas.
#
# Spinosaurus had a primarily piscivorous (fish-based) diet.
# The Declaration of Independence was signed in Independence Hall.
#
# The primary match t-shirt color of Rangers F.C. is blue.
#
# Philipp Lahm was the captain of the German national team that won the FIFA World Cup in 2014.
#
# The primary diet of the Giganotosaurus consisted of large herbivorous dinosaurs.
#
# The primary language spoken in Greece is Greek.
#
# The primary material used in the construction of the Golden Gate Bridge is steel, particularly noted for its iconic International Orange color.
# The Hall of Mirrors is located in the Palace of Versailles in France. From its windows, one can see the Gardens of Versailles. The Hall of Mirrors is a long gallery lined with mirrors and chandeliers, offering a breathtaking view of the gardens
#
# Independence Hall is located in Philadelphia.
#
# Curiosity's original mission was to figure out whether conditions in Mars' past were once amenable to life as we know it.
#
# Real Sociedad won the Copa del Rey in 2020.
# The primary color of the Miami Heat's match t-shirt is black, red, and white.
#
# Argentina won the Copa America in 2021.
#
# The primary color of Italy's match jersey is blue.
#
# Independence Hall is an example of Georgian architecture and has a total floor area of approximately 30,000 square feet.
#
# The Potsdam Conference was held at Cecilienhof Palace.
#
# the coronation of the French kings took place in Reims Cathedral because the first king of the Franks, Clovis, had undergone baptism there in 508
# Retrieved documents for query 'What was the primary diet of the largest carnivorous dinosaur in South America?':
# The largest land carnivore during the Cretaceous period was Tyrannosaurus rex.
#
# African elephants are herbivores. As herbivores they spend much of their days foraging and eating grass leaves bark fruit and a variety of foliage. They need to eat about 350 pounds of vegetation every day. African bush elephants are also known as African savanna elephants.
#
# To Kill a Mocking Bird', won Pulitzer Prize for fiction in 1961.
#
# Steven Gerrard was the captain of Liverpool in 2005.
# The Miami Heat won the NBA Finals in 2013.
#
# 'To Kill a Mockingbird' main character Atticus Finch lives by this saying he judges the seeds he plants not his success each day
#
# The largest herbivorous dinosaur, Argentinosaurus, had a primarily plant-based diet
#
# The economy of Salt Lake City, Utah is primarily service-oriented.
#
# Norway won the Eurovision Song Contest in 2009.
#
# The Palace of Justice is located in Germany.
#
# The largest predator found in the Amazon rainforest is the jaguar.
# The Congress of the Confederation was held in Independence Hall, Philadelphia.
#
# The primary diet of killer whales includes fish, seals, and squid.
#
# The Hôtel de Ville is designed in the French Renaissance architectural style.
#
# The primary color of the Chicago Cubs' uniform is blue.
#
# Spinosaurus is considered the largest carnivorous dinosaur ever discovered.
#
# Chelsea won the Champions League in 2021.
#
# The largest flying bird in history is believed to be Argentavis.
# The largest carnivorous mammal found in South America is the jaguar.
#
# The main theme of The Old Man and the Sea is the distiction of being defeated or destroyed. To be undefeated is to do the brave and hard thing to do, to choose that path even through failure exhibits success. Biblical allusions throughout the book further this theme.
#
# The Sydney Opera House was constructed primarily using concrete, with ceramic tiles on the roof.
#
# Ukraine won the Eurovision Song Contest in 2016.
# Retrieved documents for query 'What was the primary subject of the painting that sold for the highest price in 2020?':
# The novel 'The Killer Angels' won the Pulitzer Prize for Fiction in 1975.
#
# David Villa was the top scorer for Spain in the 2010 FIFA World Cup.
#
# Gary Cahill was the captain of Chelsea in 2017.
#
# Death of a Salesman is probably best known for its theme of the futility and unattainability of the American Dream.
#
# Manchester United won the English Premier League in 2013.
#
# The primary color of France's jersey is blue.
#
# The 1998 Winter Olympics were hosted by Japan.
# Arthur Miller won the Pulitzer Prize for Drama in 1949 for his play, Death of a Salesman. The success of the play brought Miller to national acclaim. The play was also his most successful.
#
# East Germany (the German Democratic Republic) was responsible for constructing the Berlin Wall.
#
# The Battle of Hastings was commemorated at Battle Abbey, built on the site of the battle.
#
# The Chicago Cubs won the MLB World Series in 2016.
#
# Federal Hall was built in the Georgian architectural style.
# The primary architectural style of the Panathenaic Stadium is classical Greek.
#
# The primary objective of Apollo 11 was to perform a crewed lunar landing and return safely to Earth.
#
# The tallest tower in Tokyo is the Tokyo Skytree.
#
# The day England won the Rugby World Cup in 2003 will stick in our minds
#
# The San Antonio Spurs won the NBA Championship in 2014.
#
# The primary color of Real Sociedad's match t-shirt is blue and white.
# Cecilienhof Palace is located in Germany.
#
# The primary material used in the construction of Salyut 1 was aluminum alloy.
#
# Luka Modric's primary jersey number is 10.
#
# The primary material used in the construction of the Victoria was wood.
#
# The main theme of 'Game of Thrones' is the struggle for power in the fictional continents of Westeros and Essos.
#
# Jïorn Utzon was the architect of the Sydney Opera House.
#
# The primary color of the Houston Astros' jersey is navy blue and orange.
# Retrieved documents for query 'Who was the captain of the team that won the UEFA Champions League in 2020?':
# Carlos Alberto Parreira was the manager of Brazil in 1994.
#
# Mikel Oyarzabal was the captain of Real Sociedad in 2020.
#
# The legendary American author Ernest Hemingway won the Nobel Prize in Literature in 1954.
#
# John Eales was the captain of the Australian national rugby team in 1999.
#
# The Golden State Warriors won the NBA Finals in 2018. They defeated the Cleveland Cavaliers in four games to capture their third championship in four years.
#
# Cesar Azpilicueta was the captain of Chelsea in 2021.
# The Colosseum was commissioned by Emperor Vespasian in AD 72.
#
# The primary match t-shirt color of Paris Saint-Germain is blue.
#
# The FIFA World Cup in 1994 was hosted by the United States.
#
# Juventus won the Serie A in the 2019-2020 season.
#
# Jonathan Toews was the captain of the Chicago Blackhawks from 2008-2023. He is now retired.
#
# Luiz Felipe Scolari was the head coach of Brazil during the 2002 FIFA World Cup.
# Sevilla won the UEFA Europa League in 2020.
#
# In 2011, the captain of the Indian cricket team was Mahendra Singh Dhoni. He was the captain of the team during the ICC Cricket World Cup, which was held in India, Sri Lanka, and Bangladesh that year. Sri Lanka ended up as the runners-up in the tournament, losing to India in the final.
#
# The World Expo in 2010 was hosted in Shanghai, China.
#
# The Vostok 1 spacecraft carried the first human into space.
#
# The primary language spoken in Norway is Norwegian.
# Carlos Bilardo was the manager of the Argentina national team in 1986.
#
# GrÃªmioâ€™s primary uniform color is blue.
#
# Brazil won the Copa America in 2019.
#
# The primary match t-shirt color of Manchester City is sky blue.
#
# Valencia won the Copa del Rey in 2019.
#
# The Golden State Warriors won the NBA Finals in 2015.
#
# Lucas Ocampos was the top scorer for Sevilla in the 2020 UEFA Europa League.
# Retrieved documents for query 'What was primary jersey color of the team that won the UEFA Champions League in 2020?':
# When Liverpool won the Champions League in 2019, three quarters of a million people took to the streets.
#
# The primary match t-shirt color of Argentina is light blue and white.
#
# The architectural style of Westminster Central Hall is Edwardian Baroque.
#
# The primary diet of the whale shark consists of plankton and small fish.
#
# Bayern Munich won the UEFA Champions League in 2013.
#
# The primary color of the Eagles' jersey is midnight green.
#
# The primary color of the Lakers' jersey is purple and gold.
# Real Madrid won the La Liga in 2020.
#
# The primary match t-shirt color of the Golden State Warriors is blue.
#
# The Commonwealth Games in 2018 were hosted by Australia.
#
# The first artificial heart, known as the Jarvik-7, was made primarily of polyurethane.
#
# The primary match t-shirt color of Chelsea FC Women is blue.
#
# The primary color of Manchester United's jersey is red.
#
# Norway hosted the Eurovision Song Contest in 2010.
#
# The primary match t-shirt color of Borussia Dortmund is yellow.
# Ukraine won the Eurovision Song Contest in 2016.
#
# The primary color of the France football jersey is blue, representing the national motto of France, "Liberty, Equality, Fraternity."
#
# The primary language spoken in Israel is Hebrew.
#
# The spacecraft that first orbited Mercury was MESSENGER.
#
# Juventus won the Italian Serie A in 2019.
#
# The primary match t-shirt color of Columbus Crew is yellow.
#
# Ãverton Ribeiro was the captain of Flamengo in 2019.
# The primary color of the United States' jersey is white.
#
# Japan won the FIFA Women's World Cup in 2011.
#
# The primary material used in the construction of the Gossamer Albatross was carbon fiber.
#
# Portugal won the Eurovision Song Contest in 2017
#
# France won the FIFA World Cup in 2018.
#
# Cafu primarily played as a right-back.
#
# Manchester City won the English Premier League in the 2017-2018 season.
#
# The primary material used in the construction of Luna 2 was aluminum alloy.
# Retrieved documents for query 'Who was the top scorer of the team that won the Copa America in 2019?':
# Carlos Bilardo was the manager of the Argentina national team in 1986.
#
# GrÃªmioâ€™s primary uniform color is blue.
#
# Brazil won the Copa America in 2019.
#
# The primary match t-shirt color of Manchester City is sky blue.
#
# Valencia won the Copa del Rey in 2019.
#
# The Golden State Warriors won the NBA Finals in 2015.
#
# Lucas Ocampos was the top scorer for Sevilla in the 2020 UEFA Europa League.
# Carlos Alberto Parreira was the manager of Brazil in 1994.
#
# Mikel Oyarzabal was the captain of Real Sociedad in 2020.
#
# The legendary American author Ernest Hemingway won the Nobel Prize in Literature in 1954.
#
# John Eales was the captain of the Australian national rugby team in 1999.
#
# The Golden State Warriors won the NBA Finals in 2018. They defeated the Cleveland Cavaliers in four games to capture their third championship in four years.
#
# Cesar Azpilicueta was the captain of Chelsea in 2021.
# Karim Benzema was the top scorer for Real Madrid in the 2020 La Liga season.
#
# Salt Lake City, Utah, was the host of the Winter 2002 Olympics.
#
# The primary diet of jaguars includes deer, capybaras, and fish.
#
# English is the primary language spoken in England
#
# The Declaration of the Rights of Man and of the Citizen was drafted in the Hôtel de Ville, Paris.
#
# Ronaldo scored 8 goals in 7 matches in the 2002 FIFA World Cup, where he won the Golden Shoe as the top scorer.
# Tom Brady won the MVP award in the 2017 NFL season.
#
# The primary mission of New Horizons was to study Pluto and its moons.
#
# Diego Lugano primarily played as a central defender.
#
# River Plate won the Copa Libertadores in 2018.
#
# Barcelona won the Copa del Rey in 2018.
#
# Jupp Heynckes was the manager of Bayern Munich in 2013.
#
# Canada hosted the Winter Olympics in 1988.
#
# The primary material used in the construction of MESSENGER was aluminum and titanium.
#
# Greece hosted the Summer Olympics in 2004.
# Retrieved documents for query 'What was primary jersey color of the team that won the Copa America in 2019?':
# The primary color of the United States' jersey is white.
#
# Japan won the FIFA Women's World Cup in 2011.
#
# The primary material used in the construction of the Gossamer Albatross was carbon fiber.
#
# Portugal won the Eurovision Song Contest in 2017
#
# France won the FIFA World Cup in 2018.
#
# Cafu primarily played as a right-back.
#
# Manchester City won the English Premier League in the 2017-2018 season.
#
# The primary material used in the construction of Luna 2 was aluminum alloy.
# Carlos Bilardo was the manager of the Argentina national team in 1986.
#
# GrÃªmioâ€™s primary uniform color is blue.
#
# Brazil won the Copa America in 2019.
#
# The primary match t-shirt color of Manchester City is sky blue.
#
# Valencia won the Copa del Rey in 2019.
#
# The Golden State Warriors won the NBA Finals in 2015.
#
# Lucas Ocampos was the top scorer for Sevilla in the 2020 UEFA Europa League.
# Real Madrid won the La Liga in 2020.
#
# The primary match t-shirt color of the Golden State Warriors is blue.
#
# The Commonwealth Games in 2018 were hosted by Australia.
#
# The first artificial heart, known as the Jarvik-7, was made primarily of polyurethane.
#
# The primary match t-shirt color of Chelsea FC Women is blue.
#
# The primary color of Manchester United's jersey is red.
#
# Norway hosted the Eurovision Song Contest in 2010.
#
# The primary match t-shirt color of Borussia Dortmund is yellow.
# When Liverpool won the Champions League in 2019, three quarters of a million people took to the streets.
#
# The primary match t-shirt color of Argentina is light blue and white.
#
# The architectural style of Westminster Central Hall is Edwardian Baroque.
#
# The primary diet of the whale shark consists of plankton and small fish.
#
# Bayern Munich won the UEFA Champions League in 2013.
#
# The primary color of the Eagles' jersey is midnight green.
#
# The primary color of the Lakers' jersey is purple and gold.
# Retrieved documents for query 'Who was the manager of the team that won the FA Cup in 2018?':
# Carlos Alberto Parreira was the manager of Brazil in 1994.
#
# Mikel Oyarzabal was the captain of Real Sociedad in 2020.
#
# The legendary American author Ernest Hemingway won the Nobel Prize in Literature in 1954.
#
# John Eales was the captain of the Australian national rugby team in 1999.
#
# The Golden State Warriors won the NBA Finals in 2018. They defeated the Cleveland Cavaliers in four games to capture their third championship in four years.
#
# Cesar Azpilicueta was the captain of Chelsea in 2021.
# Carlos Bilardo was the manager of the Argentina national team in 1986.
#
# GrÃªmioâ€™s primary uniform color is blue.
#
# Brazil won the Copa America in 2019.
#
# The primary match t-shirt color of Manchester City is sky blue.
#
# Valencia won the Copa del Rey in 2019.
#
# The Golden State Warriors won the NBA Finals in 2015.
#
# Lucas Ocampos was the top scorer for Sevilla in the 2020 UEFA Europa League.
# Chelsea won the FA Cup in 2018.
#
# Germany won the FIFA World Cup in 2014.
#
# Giorgio Chiellini was the captain of Juventus in 2020.
#
# The primary diet of the emu includes plants, seeds, fruits, and insects.
#
# Hugo Lloris was the captain of the French national team in 2018.
#
# The Winter Olympics in 2010 were hosted by Canada.
#
# The primary language spoken in Norway is Norwegian.
#
# Herbert Hoover was the president of the United States when the construction of the Hoover Dam began.
# Real Madrid won the FIFA Club World Cup in 2014.
#
# The FIFA U-20 World Cup in 2017 was hosted by South Korea.
#
# The primary ingredient in hardtack is flour.
#
# The FIFA Women's World Cup in 2019 was hosted by France.
#
# The home stadium of Manchester United is Old Trafford.
#
# Luka Modric won the Ballon d'Or in 2018.
#
# The main theme of 'The Lord of the Rings: The Return of the King' is the struggle between good and evil.
#
# The architect of the Leaning Tower of Pisa is believed to be Bonanno Pisano.
# Retrieved documents for query 'What was the primary language spoken in the country that won the FIFA World Cup in 2010?':
# The primary language spoken in Germany is German. German is a West Germanic language and is one of the most widely spoken languages in Europe.
#
# Luis SuÃ¡rez was the top scorer for Uruguay in the 2011 Copa AmÃ©rica.
#
# The primary material used in the construction of the Apollo 11 spacecraft was aluminum.
#
# The home stadium of Paris Saint-Germain is Parc des Princes.
#
# Sevilla won the UEFA Europa League in 2020.
# Argentina won the FIFA World Cup in 1986.
#
# Atletico Madrid won the La Liga title in 2014, also finishing runners up to Real Madrid in the Champions League final the same year.
#
# The primary language spoken in Spain is Spanish.
#
# Paris Saint-Germain won the French Cup in 2021.
#
# The Houston Astros won the World Series in 2017.
#
# The first successful passenger airplane was the Wright Flyer.
#
# The Wright Flyer was constructed using spruce wood and muslin fabric.
# The primary language spoken in West Germany was German.
#
# Brazil won the FIFA World Cup in 2002.
#
# Chelsea won the UEFA Europa League in 2019.
#
# The Los Angeles Lakers won the NBA Finals in 2020.
#
# The home stadium of the Chicago Cubs is Wrigley Field.
#
# Fossils of woolly mammoths have been primarily discovered in Siberia and North America.
#
# The novel 'The Executioner's Song' won the Pulitzer Prize for Fiction in 1980.
#
# The Magna Carta was signed at Runnymede in 1215.
# The primary language spoken in Portugal is Portuguese and thus at the commencement of this PhD I undertook lessons in Portuguese.
#
# Some researchers claim that the pyramids of Giza were built by the Egyptians following one plan designed by only one architect.
#
# Cristiano Ronaldo was the top scorer for Real Madrid in the 2014 FIFA Club World Cup.
#
# The primary match t-shirt color of Leicester City is blue.
#
# The first successful human-powered flight vehicle was the Gossamer Albatross.
# Retrieved documents for query 'Who was top scorer of the team that won the FIFA World Cup in 2010?':
# Karim Benzema was the top scorer for Real Madrid in the 2020 La Liga season.
#
# Salt Lake City, Utah, was the host of the Winter 2002 Olympics.
#
# The primary diet of jaguars includes deer, capybaras, and fish.
#
# English is the primary language spoken in England
#
# The Declaration of the Rights of Man and of the Citizen was drafted in the Hôtel de Ville, Paris.
#
# Ronaldo scored 8 goals in 7 matches in the 2002 FIFA World Cup, where he won the Golden Shoe as the top scorer.
# Real Madrid won the FIFA Club World Cup in 2014.
#
# The FIFA U-20 World Cup in 2017 was hosted by South Korea.
#
# The primary ingredient in hardtack is flour.
#
# The FIFA Women's World Cup in 2019 was hosted by France.
#
# The home stadium of Manchester United is Old Trafford.
#
# Luka Modric won the Ballon d'Or in 2018.
#
# The main theme of 'The Lord of the Rings: The Return of the King' is the struggle between good and evil.
#
# The architect of the Leaning Tower of Pisa is believed to be Bonanno Pisano.
# The home stadium of Juventus is Allianz Stadium.
#
# James Rodrïguez won the Golden Boot in the 2014 FIFA World Cup. The Golden Boot is awarded to the top goal scorer of the tournament, which is a testament to James' exceptional performance.
#
# Manchester City won the Premier League in 2018.
#
# Intel manufactures semiconductor chips, graphics chips, motherboard chipsets and other computing devices.
# South Africa won the Rugby World Cup in 2007.
#
# Known for his ability to perform in crucial moments, Iniesta scored the winning goal in the 2010 FIFA World Cup final, securing Spain's first World Cup. He also played a key role in Spain's victories at Euro 2008 and Euro 2012.
#
# Federal Hall is designed in the Greek Revival architectural style.
#
# South Africa won the Rugby World Cup in 1995.
#
# Brazil won the Copa America in 2019.
# Retrieved documents for query 'Who was top scorer of the team that won the NBA Finals in 2015?':
# The home stadium of Juventus is Allianz Stadium.
#
# James Rodrïguez won the Golden Boot in the 2014 FIFA World Cup. The Golden Boot is awarded to the top goal scorer of the tournament, which is a testament to James' exceptional performance.
#
# Manchester City won the Premier League in 2018.
#
# Intel manufactures semiconductor chips, graphics chips, motherboard chipsets and other computing devices.
# The Cleveland Cavaliers won the NBA championship in 2016.
#
# The primary language spoken in Japan is Japanese.
#
# The primary color of the St. Louis Blues' jersey is blue.
#
# The Brachiosaurus lived during the Jurassic era.
#
# Juventus won the Serie A in 2020.
#
# The Colosseum in Rome was primarily constructed from concrete and sand.
#
# South Africa won the Rugby World Cup in 2007.
# ...
#
# Portugal won the Eurovision Song Contest in 2017
#
# France won the FIFA World Cup in 2018.
#
# Cafu primarily played as a right-back.
#
# Manchester City won the English Premier League in the 2017-2018 season.
#
# The primary material used in the construction of Luna 2 was aluminum alloy.
# Retrieved documents for query 'What was the primary diet of the largest marine predator found in the Pacific Ocean?':
# The Magna Carta was signed at Runnymede in 1215.
#
# The primary diet of the Blue Whale consists of krill, which are small, shrimp-like creatures.
#
# The largest carnivorous dinosaur in South America was the Giganotosaurus.
#
# The primary match t-shirt color of Real Betis is green and white.
#
# The Jefferson Memorial is a national memorial in Washington, D.C., built in honor of Thomas Jefferson
#
# The largest marine predator in the Southern Ocean is the killer whale.
# The Congress of the Confederation was held in Independence Hall, Philadelphia.
#
# The primary diet of killer whales includes fish, seals, and squid.
#
# The Hôtel de Ville is designed in the French Renaissance architectural style.
#
# The primary color of the Chicago Cubs' uniform is blue.
#
# Spinosaurus is considered the largest carnivorous dinosaur ever discovered.
#
# Chelsea won the Champions League in 2021.
#
# The largest flying bird in history is believed to be Argentavis.
# Chelsea FC Women won the FA Women's Super League in 2020.
#
# The primary diet of great white sharks includes seals, sea lions, and fish.
#
# The primary material used in the construction of the Tokyo Skytree is steel.
#
# Australia won the Rugby World Cup in 1999.
#
# Apple Inc. introduced the iPhone in 2007.
#
# The jersey number of Tom Brady is 12.
#
# Sputnik 1 was primarily constructed of aluminum alloy.
#
# Brazil won the FIFA World Cup in 1994.
#
# The primary diet of the California condor consists of carrion.
# Gustave Eiffel was the engineer responsible for the design of the Eiffel Tower.
#
# Manchester United won the FA Cup in 2004.
#
# The largest marine predator found in the Pacific Ocean is the great white shark.
#
# Cristiano Ronaldo was the top scorer for Real Madrid in the 2018 UEFA Champions League.
#
# The Harpy Eagle's diet consisted mainly of medium-sized arboreal, folivorous, frugivorous, and diurnal mammals.
# Retrieved documents for query 'What was the primary material used in the construction of the first successful passenger airplane?':
# The primary material used in the construction of the Mayflower was wood.
#
# In 1997, Time magazine named Intel CEO Andy Grove its Man of the Year.
#
# The outside of the Jefferson Memorial building is made out of Vermont Imperial Danby Marble and the inside is made out of white Georgia marble.
#
# Microsoft's primary programming language for system software was C.
#
# Stephen Curry was the top scorer for the Golden State Warriors in 2015.
#
# The 2008 Summer Olympics were held in Beijing, China.
# Dr. Barney Clark was the surgeon who performed the first implantation of the Jarvik-7.
#
# The primary industry of Apple Inc. is technology and consumer electronics.
#
# The structures at Runnymede are predominantly medieval in architectural style.
#
# The Boeing 737 used by Ryanair has been adjusted to have as many seats as possible, 189. For this reason thr space is minimal and seats can't be reclined.
#
# The primary diet of the African lion consists of large herbivores such as zebras and wildebeest.
# The primary color of the United States' jersey is white.
#
# Japan won the FIFA Women's World Cup in 2011.
#
# The primary material used in the construction of the Gossamer Albatross was carbon fiber.
#
# Portugal won the Eurovision Song Contest in 2017
#
# France won the FIFA World Cup in 2018.
#
# Cafu primarily played as a right-back.
#
# Manchester City won the English Premier League in the 2017-2018 season.
#
# The primary material used in the construction of Luna 2 was aluminum alloy.
# Cecilienhof Palace is located in Germany.
#
# The primary material used in the construction of Salyut 1 was aluminum alloy.
#
# Luka Modric's primary jersey number is 10.
#
# The primary material used in the construction of the Victoria was wood.
#
# The main theme of 'Game of Thrones' is the struggle for power in the fictional continents of Westeros and Essos.
#
# Jïorn Utzon was the architect of the Sydney Opera House.
#
# The primary color of the Houston Astros' jersey is navy blue and orange.
# Retrieved documents for query 'What was the primary match t-shirt color of the team that won the Eredivisie in 2021?':
# Real Madrid won the La Liga in 2020.
#
# The primary match t-shirt color of the Golden State Warriors is blue.
#
# The Commonwealth Games in 2018 were hosted by Australia.
#
# The first artificial heart, known as the Jarvik-7, was made primarily of polyurethane.
#
# The primary match t-shirt color of Chelsea FC Women is blue.
#
# The primary color of Manchester United's jersey is red.
#
# Norway hosted the Eurovision Song Contest in 2010.
#
# The primary match t-shirt color of Borussia Dortmund is yellow.
# When Liverpool won the Champions League in 2019, three quarters of a million people took to the streets.
#
# The primary match t-shirt color of Argentina is light blue and white.
#
# The architectural style of Westminster Central Hall is Edwardian Baroque.
#
# The primary diet of the whale shark consists of plankton and small fish.
#
# Bayern Munich won the UEFA Champions League in 2013.
#
# The primary color of the Eagles' jersey is midnight green.
#
# The primary color of the Lakers' jersey is purple and gold.
# For over 100 years the colours blue and garnet have come together on the shirts of FC BARCELONA players and this is why the Club is also known as the equip blaugrana (blue and garnet team). The colours have always been used on the team kit especially the shirt. The shorts were white for the first 10 years of the Club's history then black and since the 1920s blue.
#
# Defensa y Justicia won the Copa Sudamericana in 2020.
#
# Philipp Lahm's primary position was right back.
# The primary match t-shirt color of Liverpool is red.
#
# FC Barcelona won the Copa del Rey in 2021.
#
# The Statue of Liberty was constructed primarily using copper.
#
# The Hofburg Palace features a Baroque architectural style.
#
# The primary jersey color of the New England Patriots is navy blue.
#
# The primary language spoken in the Soviet Union was Russian.
#
# Megan Rapinoe is most consistently the left-sided wide forward
# Retrieved documents for query 'What was the primary architectural style of the building where the Declaration of the Rights of Man and of the Citizen was drafted?':
# The cathedral was essentially built in just 60 years! In addition to its historical importance, Reims Cathedral is recognized as one of the greatest examples of Gothic architecture in France, both for its architecture and for its statuary, which includes no fewer than 2,303 statues
#
# The first United Nations General Assembly was held at Central Hall Westminster, which is designed in the Edwardian Baroque architectural style.
# The primary architectural style of the Panathenaic Stadium is classical Greek.
#
# The primary objective of Apollo 11 was to perform a crewed lunar landing and return safely to Earth.
#
# The tallest tower in Tokyo is the Tokyo Skytree.
#
# The day England won the Rugby World Cup in 2003 will stick in our minds
#
# The San Antonio Spurs won the NBA Championship in 2014.
#
# The primary color of Real Sociedad's match t-shirt is blue and white.
# The Palace of Versailles was built in the Baroque style. The Baroque style is characterized by extravagance, grandeur, and dramatic effects. It was a style that was popular in the 17th and early 18th centuries, and the Palace of Versailles is one of the most prominent examples of this architectural style. The other options, Rococo, Neoclassical, and Georgian, are also architectural styles, but they are not the style in which the Palace of Versailles was built.
# The Nuremberg Trials took place in the Palace of Justice.
#
# The Quai d'Orsay is designed in the Beaux-Arts architectural style.
#
# Germany won the Eurovision Song Contest in 2010.
#
# Brazil hosted the FIFA World Cup in 2014.
#
# The Treaty of Paris 1783 was signed at the HÃ´tel d'York in Paris, which is designed in a classical architectural style.
#
# The largest herbivore found in South America is the capybara.
#
# Italy hosted the Winter Olympics in 2006.
#
# The home stadium of Juventus is Allianz Stadium.
# Retrieved documents for query 'What was the primary material used in the construction of the first skyscraper?':
# The primary building material of Burj Khalifa is concrete, and due to the high pressure of the buildingï¿½s weight and the hot climate of Dubai, which can reach 50 degrees Celsius, a particular type of concrete was needed. Any large crack could have caused a lot of damage to the building. In this way, concrete with high density and low permeability was used.
#
# Leicester City won the FA Cup in 2021.
#
# Borussia Dortmund won the DFB-Pokal in 2021.
# The primary material used in the construction of the Mayflower was wood.
#
# In 1997, Time magazine named Intel CEO Andy Grove its Man of the Year.
#
# The outside of the Jefferson Memorial building is made out of Vermont Imperial Danby Marble and the inside is made out of white Georgia marble.
#
# Microsoft's primary programming language for system software was C.
#
# Stephen Curry was the top scorer for the Golden State Warriors in 2015.
#
# The 2008 Summer Olympics were held in Beijing, China.
# The Parthenon was primarily constructed using Pentelic marble.
#
# The primary language spoken in Brazil is Portuguese.
#
# Paris Saint-Germain won the French Ligue 1 in 2020.
#
# The Hoover Dam was constructed primarily using concrete.
#
# The Brooklyn Bridge connects Brooklyn to Manhattan.
# The primary architectural style of the Panathenaic Stadium is classical Greek.
#
# The primary objective of Apollo 11 was to perform a crewed lunar landing and return safely to Earth.
#
# The tallest tower in Tokyo is the Tokyo Skytree.
#
# The day England won the Rugby World Cup in 2003 will stick in our minds
#
# The San Antonio Spurs won the NBA Championship in 2014.
#
# The primary color of Real Sociedad's match t-shirt is blue and white.
# Retrieved documents for query 'What was the primary language spoken in the country that won the UEFA Euro Championship in 2016?':
# The primary language spoken in Germany is German. German is a West Germanic language and is one of the most widely spoken languages in Europe.
#
# Luis SuÃ¡rez was the top scorer for Uruguay in the 2011 Copa AmÃ©rica.
#
# The primary material used in the construction of the Apollo 11 spacecraft was aluminum.
#
# The home stadium of Paris Saint-Germain is Parc des Princes.
#
# Sevilla won the UEFA Europa League in 2020.
# Ukraine won the Eurovision Song Contest in 2016.
#
# The primary color of the France football jersey is blue, representing the national motto of France, "Liberty, Equality, Fraternity."
#
# The primary language spoken in Israel is Hebrew.
#
# The spacecraft that first orbited Mercury was MESSENGER.
#
# Juventus won the Italian Serie A in 2019.
#
# The primary match t-shirt color of Columbus Crew is yellow.
#
# Ãverton Ribeiro was the captain of Flamengo in 2019.
# The primary language spoken in West Germany was German.
#
# Brazil won the FIFA World Cup in 2002.
#
# Chelsea won the UEFA Europa League in 2019.
#
# The Los Angeles Lakers won the NBA Finals in 2020.
#
# The home stadium of the Chicago Cubs is Wrigley Field.
#
# Fossils of woolly mammoths have been primarily discovered in Siberia and North America.
#
# The novel 'The Executioner's Song' won the Pulitzer Prize for Fiction in 1980.
#
# The Magna Carta was signed at Runnymede in 1215.
# The primary language spoken in Portugal is Portuguese and thus at the commencement of this PhD I undertook lessons in Portuguese.
#
# Some researchers claim that the pyramids of Giza were built by the Egyptians following one plan designed by only one architect.
#
# Cristiano Ronaldo was the top scorer for Real Madrid in the 2014 FIFA Club World Cup.
#
# The primary match t-shirt color of Leicester City is blue.
#
# The first successful human-powered flight vehicle was the Gossamer Albatross.
# Retrieved documents for query 'What was the primary architectural style of the building where the Peace of Westphalia was signed?':
# The cathedral was essentially built in just 60 years! In addition to its historical importance, Reims Cathedral is recognized as one of the greatest examples of Gothic architecture in France, both for its architecture and for its statuary, which includes no fewer than 2,303 statues
#
# The first United Nations General Assembly was held at Central Hall Westminster, which is designed in the Edwardian Baroque architectural style.
# The Nuremberg Trials took place in the Palace of Justice.
#
# The Quai d'Orsay is designed in the Beaux-Arts architectural style.
#
# Germany won the Eurovision Song Contest in 2010.
#
# Brazil hosted the FIFA World Cup in 2014.
#
# The Treaty of Paris 1783 was signed at the HÃ´tel d'York in Paris, which is designed in a classical architectural style.
#
# The largest herbivore found in South America is the capybara.
#
# Italy hosted the Winter Olympics in 2006.
#
# The home stadium of Juventus is Allianz Stadium.
# The Palace of Versailles was built in the Baroque style. The Baroque style is characterized by extravagance, grandeur, and dramatic effects. It was a style that was popular in the 17th and early 18th centuries, and the Palace of Versailles is one of the most prominent examples of this architectural style. The other options, Rococo, Neoclassical, and Georgian, are also architectural styles, but they are not the style in which the Palace of Versailles was built.
# The town hall of Münster is designed in the Gothic architectural style.
#
# The largest herbivorous dinosaur in North America, the Brachiosaurus, primarily ate plants.
#
# The Netherlands won the Eurovision Song Contest in 2019.
#
# Spain won the FIFA World Cup in 2010.
#
# Wayne Rooney was the captain of Manchester United in 2017.
#
# The film 'The Lord of the Rings: The Return of the King' won the Academy Award for Best Picture in 2003.
#
# The Berlin Wall was primarily constructed using concrete.
# Retrieved documents for query 'What was the primary language spoken in the country that hosted the FIFA Women's World Cup in 2019?':
# Brazil won the Copa America in 2019.
#
# Polar bearsï¿½ diet consists mainly of seals as they require large amounts of fat to survive the cold climate.
#
# The United States won the FIFA Women's World Cup in 2015.
#
# The primary language spoken in South Korea is Korean.
#
# The primary language spoken in the United Kingdom is English.
#
# The Winter Olympics in 2018 were hosted in Pyeongchang, South Korea.
#
# The largest reptile found in the Nile River is the Nile crocodile.
# The primary language spoken in Germany is German. German is a West Germanic language and is one of the most widely spoken languages in Europe.
#
# Luis SuÃ¡rez was the top scorer for Uruguay in the 2011 Copa AmÃ©rica.
#
# The primary material used in the construction of the Apollo 11 spacecraft was aluminum.
#
# The home stadium of Paris Saint-Germain is Parc des Princes.
#
# Sevilla won the UEFA Europa League in 2020.
# The primary language spoken in West Germany was German.
#
# Brazil won the FIFA World Cup in 2002.
#
# Chelsea won the UEFA Europa League in 2019.
#
# The Los Angeles Lakers won the NBA Finals in 2020.
#
# The home stadium of the Chicago Cubs is Wrigley Field.
#
# Fossils of woolly mammoths have been primarily discovered in Siberia and North America.
#
# The novel 'The Executioner's Song' won the Pulitzer Prize for Fiction in 1980.
#
# The Magna Carta was signed at Runnymede in 1215.
# The primary color of the United States' jersey is white.
#
# Japan won the FIFA Women's World Cup in 2011.
#
# The primary material used in the construction of the Gossamer Albatross was carbon fiber.
#
# Portugal won the Eurovision Song Contest in 2017
#
# France won the FIFA World Cup in 2018.
#
# Cafu primarily played as a right-back.
#
# Manchester City won the English Premier League in the 2017-2018 season.
#
# The primary material used in the construction of Luna 2 was aluminum alloy.

# %%
langchain_answers
# Out:
# ["The primary match t-shirt color of the winner of the Ballon d'Or in the season of 1998-1999 was not provided in the given context.",
#  "The home stadium of the team that won the UEFA Champions League in 2012 is not provided in the context, so I don't know.",
#  'Ronaldo wore the jersey number 9 when he was the top scorer in the 2002 FIFA World Cup.\n\n',
#  'The main architectural style of the Palace of Versailles, where the Treaty of Versailles was signed, is Baroque.',
#  'The captain of the team that won the ICC Cricket World Cup in 2011 was Mahendra Singh Dhoni. His primary role in the team was as a wicketkeeper-batsman and captain. India emerged as the champions of the tournament, with Sri Lanka finishing as the runners-up.',
#  'The primary aircraft model used by the airline that was the largest operator in Europe in 2010 was the Boeing 737. Ryanair, the biggest airline in Europe, has adjusted their Boeing 737 planes to have 189 seats, maximizing capacity.',
#  'The primary diet of the largest land animal found in Africa, the African bush elephant, consists of grass, leaves, bark, fruit, and a variety of foliage. They need to consume about 350 pounds of vegetation daily to sustain themselves.',
#  'The primary programming language used by the company that developed the Windows operating system in the 1980s was C.',
#  'The main theme of the novel written by the author who won the Nobel Prize in Literature in 1954 is the futility and unattainability of the American Dream.',
#  'The primary material used in the construction of the tallest building in the world, Burj Khalifa, is concrete.',
#  'The primary economic activity of the civilization that built the pyramids of Giza was agriculture, including the cultivation of wheat, barley, and flax, as well as raising sheep and cattle. They also engaged in trade, importing items like ivory, spices, copper, and wood, while exporting goods such as glassware, linen, and clay vases. Their agriculture was highly productive, allowing them to dominate other civilizations for a significant period.',
#  "The primary industry of the company whose CEO was named Time's Person of the Year in 1999 was technology and consumer electronics.",
#  'The main ingredient in the first synthetic plastic created, Bakelite, was composed of phenol and formaldehyde, making it a copolymer. Copolymers are those that are composed of two different monomer units.',
#  'The main objective of the space mission that successfully landed humans on the Moon in 1969 was to perform a crewed lunar landing and return safely to Earth.',
#  'The primary language spoken in the country that hosted the 2008 Summer Olympics is not provided in the context.',
#  "I don't know.",
#  'The main character in the novel that won the Pulitzer Prize for Fiction in 1961 was General Robert E. Lee.',
#  'The primary economic activity in the city that hosted the Summer Olympics in 2000 was driven by tourism, international education, finance, the creative and digital industries, as well as consulting services.',
#  'The main theme of the movie that won the Academy Award for Best Picture in 1994 was the life journey of an everyman who witnesses and influences significant events in American history.',
#  'The player who won the Golden Boot in the 2014 FIFA World Cup, James Rodrïguez, played for the Colombia national team.',
#  'The Cleveland Cavaliers won the NBA championship in 2016.',
#  "I don't know.",
#  'The main architectural style of the building where the Declaration of Independence was signed is Georgian architecture, and Independence Hall has a total floor area of approximately 30,000 square feet.',
#  "The captain of the team that won the FIFA Women's World Cup in 2019 was Megan Rapinoe, and her primary position was forward.",
#  'The primary diet of the Blue Whale consists of krill, which are small, shrimp-like creatures.',
#  'The main theme of the play "Death of a Salesman" by Arthur Miller, who won the Pulitzer Prize for Drama in 1949, is the futility and unattainability of the American Dream.',
#  'The primary material used in the construction of the Golden Gate Bridge that connects San Francisco to Marin County was steel.',
#  'The main mission of the Mars rover mission launched by NASA in 2011 was to study the Martian surface and environment.',
#  'The primary language spoken in Ukraine is Ukrainian.',
#  "I don't know.",
#  "I don't know.",
#  'The architectural style of the cathedral where the coronation of the French kings took place was Gothic. Reims Cathedral is recognized as one of the greatest examples of Gothic architecture in France, known for its statuary and architecture.',
#  "I don't know.",
#  'The primary diet of the largest predator in the Arctic Ocean is seals, sea lions, and fish.',
#  'The primary material used in the construction of the bridge that connects Brooklyn to Manhattan was steel.',
#  "The primary industry of the company whose CEO was named Time's Person of the Year in 1997 was technology and consumer electronics.",
#  'The primary language spoken in the country that won the Rugby World Cup in 2003 is English.',
#  'The primary economic activity in the city that hosted the Winter Olympics in 2002 was tourism.',
#  'The primary material used in the construction of the monument located in Washington, D.C. dedicated to the third president of the United States was Vermont Imperial Danby Marble for the outside and white Georgia marble for the inside.',
#  'The primary language spoken in the country that hosted the FIFA World Cup in 2006 was German.',
#  'The primary match t-shirt color of Liverpool, the team that won the Champions League in 2019, is red.',
#  'The primary colors of the team that won the Super Bowl in 2020 are midnight green and white.',
#  "I don't know.",
#  'The primary color of the team that won the FIFA World Cup in 1998 was blue.',
#  "I don't know.",
#  'The primary language spoken in Greece, which hosted the Summer Olympics in 2004, is Greek.',
#  'The primary jersey color of the team that won the NBA Championship in 2014 was blue.',
#  'The home stadium of the team that won the English Premier League in 2013 is not provided in the given context.',
#  'Tom Brady wore jersey number 12 when he won the MVP award in the 2017 NFL season.',
#  'The primary architectural style of the building where the United Nations Charter was signed is Edwardian Baroque.',
#  'Philipp Lahm was the captain of the team that won the FIFA World Cup in 2014, and his primary position was right back.',
#  'The primary diet of the largest bird found in North America, Argentavis, is believed to be primarily herbivorous, consisting of plants and vegetation.',
#  'The primary economic activity of the civilization that built Machu Picchu was agriculture and trade.',
#  "I don't know.",
#  'The home stadium of the team that won the MLB World Series in 2016 is Wrigley Field.',
#  'The main theme of the film that won the Academy Award for Best Picture in 2003 is not provided in the context.',
#  'The primary diet of the largest fish found in the ocean, the Blue Whale, consists of krill.',
#  'The primary language spoken in South Korea, the country that hosted the Winter Olympics in 2010, is Korean.',
#  'Brazil won the Copa America in 2019, and their primary match t-shirt color is yellow.',
#  'The primary industry of the company that introduced the iPhone was technology and consumer electronics.',
#  "The primary diet of the largest terrestrial carnivore in North America, Tyrannosaurus rex, consisted of other dinosaurs and potentially carrion.\n\nI don't know.",
#  'The main architectural style of the building where the first United Nations General Assembly was held is Edwardian Baroque.',
#  'The primary match t-shirt color of the Golden State Warriors is blue.',
#  'The primary mission of the space probe that first landed on a comet was to study the comet 67P/Churyumov-Gerasimenko.',
#  'The primary language spoken in South Korea, the country that hosted the Winter Olympics in 2018, is Korean.',
#  'The main theme of the television series that won the Primetime Emmy Award for Outstanding Drama Series in 2018 is not provided in the context.',
#  'The primary diet of the largest reptile found in the Nile River is fish, birds, and mammals.',
#  'The primary material used in the construction of the ship that completed the first successful circumnavigation of the Earth was wood, specifically in the Victoria.',
#  'The primary color of the uniform worn by the team that won the World Series in 2016 is not provided in the given context.',
#  'The main architectural style of the Palace of Versailles, where the Congress of Vienna was held, is Baroque.',
#  'The primary diet of the largest bird found in Australia, the emu, consists of plants, seeds, and insects.',
#  "I don't know.",
#  'The primary match t-shirt color of the team that won the English Premier League in the 2017-2018 season was blue.',
#  'The primary material used in the construction of the ship that carried the Pilgrims to North America in 1620 was wood.',
#  'Sailors during the Age of Exploration often relied on hardtack as a primary food source.',
#  'The primary language spoken in Germany, the country that won the FIFA World Cup in 2014, is German, a West Germanic language widely spoken in Europe.',
#  'The primary match t-shirt color of FC Barcelona, the team that won the Copa del Rey in 2021, is blue and garnet.',
#  'The primary material used in the construction of the first artificial satellite launched into space, Sputnik 1, was aluminum alloy.',
#  'The primary match t-shirt color of the team that won the Serie A in the 2019-2020 season is not provided in the given context.',
#  'The primary match t-shirt color of Liverpool is red.',
#  'The primary architectural style of the building where the Magna Carta was signed is not specified in the provided context.',
#  'The primary match t-shirt color of the team that won the Copa Libertadores in 2018 was not provided in the context.',
#  'The primary language spoken in Germany, the country that hosted the Summer Olympics in 1972, is German.',
#  'The primary match t-shirt color of Bayern Munich, the team that won the Bundesliga in 2020, is red.',
#  'The primary language spoken in the country that won the Rugby World Cup in 1995 was German.',
#  'Battle Abbey is an example of Norman architecture.',
#  'The primary match t-shirt color of FC Barcelona, the team that won the Copa del Rey in 2018, is blue and garnet.',
#  'The primary diet of the largest marine predator found in the Southern Ocean, the killer whale, consists of seals, sea lions, and fish.',
#  'The primary match t-shirt color of the team that won the Premier League in 2015 was blue.',
#  'The primary material used in the construction of the spacecraft that first landed humans on the Moon was aluminum alloy.',
#  "The primary language spoken in the country that won the FIFA Women's World Cup in 2015 was English.",
#  "I don't know.",
#  'The primary language spoken in the country that hosted the FIFA World Cup in 1994 was German.',
#  'The primary match t-shirt color of the team that won the UEFA Europa League in 2020 was blue.',
#  "I don't know.",
#  "I don't know.",
#  'The primary match t-shirt color of the team that won the Copa America in 2021 is not provided in the given context.',
#  'The primary material used in the construction of the Tokyo Skytree, the tallest tower in Tokyo, was steel.',
#  'The home stadium of the team that won the Italian Serie A in 2019 is Allianz Stadium, which is the home stadium of Juventus.',
#  'The primary diet of the largest predator in the Amazon River, the jaguar, includes fish, birds, and mammals.',
#  'The primary match t-shirt color of the team that won the FA Cup in 2021 was blue.',
#  'The primary economic activity in the city that hosted the Winter Olympics in 2018 was tourism.',
#  'The primary match t-shirt color of the team that won the Copa Libertadores in 2021 is unknown based on the provided data.',
#  "I don't know.",
#  'The primary architectural style of the palace where the Potsdam Conference was held was Baroque.',
#  'The primary material used in the construction of the spaceship that carried the first human into space was aluminum alloy.',
#  'The primary match t-shirt color of the team that won the FIFA Club World Cup in 2019 was not provided in the context.',
#  "I don't know.",
#  'The primary language spoken in Germany is German. Ronaldo was the top scorer of the 2002 FIFA World Cup.',
#  'The main ingredient used in the creation of the first practical incandescent light bulb was a carbonized bamboo filament, and the inventor was Thomas Edison.',
#  'The main character in the novel that won the Booker Prize in 1981 is General Robert E. Lee.',
#  "I don't know.",
#  "I don't know.",
#  'The primary architectural style of the building where the first United States Congress met was Georgian architecture.',
#  'Derrick Rose wore jersey number 1.',
#  'Dr. Barney Clark was the surgeon who performed the first implantation of the Jarvik-7 artificial heart.',
#  'John Smit was the captain of the South African rugby team that won the Rugby World Cup in 2007.',
#  'The primary language spoken in South Africa, the country that won the Rugby World Cup in 2007, is not provided in the context.',
#  'The primary color of the match t-shirt of the team that won the UEFA Europa League in 2013 was red.',
#  'The main character in the novel that won the Pulitzer Prize for Fiction in 1980 was not mentioned in the provided context.',
#  'The primary language spoken in South Korea is Korean, and the Winter Olympics in 1998 were hosted in Nagano, Japan. Therefore, the primary language spoken in the country that hosted the Winter Olympics in 1998 was Japanese.',
#  'The Philadelphia Eagles won the Super Bowl in 2018.',
#  "I don't know.",
#  'Carlos Alberto Parreira was the manager of the team that won the FIFA World Cup in 1994, which was Brazil.',
#  'The primary color of the team that won the FIFA World Cup in 1994 was red, as the United States hosted the tournament.',
#  'The primary match t-shirt color of the team that won the Copa Libertadores in 2015 was blue and garnet, also known as blaugrana.',
#  'The primary language spoken in Germany is German.',
#  'Jonathan Toews was the captain of the Chicago Blackhawks in 2008 when they won the Stanley Cup. He held the captaincy from 2008 to 2023.',
#  'Nicklas Lidström, the captain of the Red Wings in 2008, played as a defenseman.',
#  'The primary diet of the largest carnivorous dinosaur discovered, Spinosaurus, likely consisted of fish, seals, and squid.',
#  'Spinosaurus is considered the largest carnivorous dinosaur ever discovered.',
#  "I don't know.",
#  'The architect of the building where the first modern Olympic Games were held was not mentioned in the provided context.',
#  'The primary architectural style of the building where the first modern Olympic Games were held was classical Greek at the Panathenaic Stadium.',
#  "I don't know.",
#  'Diego Lugano, the captain of the Uruguay national team in 2011, played as a defender.',
#  'The primary color of the France football jersey is blue, representing the national motto of France, "Liberty, Equality, Fraternity." France won the FIFA World Cup in 2018.',
#  'Fabio Cannavaro was the captain of the team that won the FIFA World Cup in 2006.',
#  'The largest herbivorous dinosaur fossils, including Argentinosaurus, were discovered in South America.',
#  'The primary material used in the construction of the Statue of Liberty was copper. The sculptor of the Statue of Liberty was Frédéric Auguste Bartholdi.',
#  "I don't know.",
#  'The primary color of the team that won the UEFA Champions League in 2013 was red.',
#  'The primary language spoken in the country that hosted the World Expo in 1967 was German.',
#  'The Palace of Justice, where the Nuremberg Trials took place, is primarily designed in a neoclassical architectural style.',
#  'The building where the Nuremberg Trials took place is located in Germany.',
#  "The main character in the novel 'The Killer Angels' was General Robert E. Lee.",
#  'The main theme of the novel that won the Pulitzer Prize for Fiction in 1975 was the futility and unattainability of the American Dream.',
#  'The primary material used in the construction of the Hoover Dam was concrete. Herbert Hoover was the president of the United States at the time of its construction.',
#  'The primary color of the team that won the UEFA Europa League in 2017 was red and white.',
#  "I don't know.",
#  "The primary language spoken in Japan, the country that won the FIFA Women's World Cup in 2011, is Japanese.",
#  'The primary material used in the construction of the Sydney Opera House was wood, and the architect was Jørn Utzon.',
#  'The primary match t-shirt color of Liverpool is red.',
#  'Carlos Bilardo was the manager of the team that won the FIFA World Cup in 1986.',
#  'The primary color of the team that won the FIFA World Cup in 1986 was blue.',
#  'The primary language spoken in the country that won the Rugby World Cup in 1999 was not specified in the provided context.',
#  'John Eales was the captain of the Australian national rugby team that won the Rugby World Cup in 1999.',
#  'The primary architectural style of the palace where the Potsdam Conference took place was Baroque.',
#  'The Potsdam Conference took place in Germany at Cecilienhof Palace.',
#  'The primary material used in the construction of the Leaning Tower of Pisa was marble. The architect of the Leaning Tower of Pisa is unknown.',
#  'The primary diet of the largest predator in the Atlantic Ocean is seals, sea lions, and fish.',
#  'The largest predator in the Atlantic Ocean is the killer whale.',
#  "I don't know.",
#  "I don't know.",
#  'The primary material used in the construction of the Eiffel Tower was iron, and Gustave Eiffel was the engineer responsible for its design.',
#  'The primary match t-shirt color of FC Barcelona, the team that won the Copa del Rey in 2020, is blue and garnet, also known as blaugrana.',
#  'The primary diet of the largest carnivore found in Africa was fish, birds, and mammals.',
#  'The primary color of the team that won the NBA Finals in 2013 was purple and gold.',
#  "I don't know.",
#  "I don't know.",
#  "I don't know.",
#  "Philipp Lahm's primary position was right back.",
#  'The primary material used in the construction of the Colosseum in Rome was concrete. The emperor who commissioned its construction was Emperor Vespasian in AD 72.',
#  'Francois Pienaar was the captain of the team that won the 1995 Rugby World Cup.',
#  "The main architectural style of the building where the Treaty of Paris 1783 was signed is classical. The country that ceded the territory in this treaty was Great Britain. The treaty was signed at the Hôtel d'York in Paris.",
#  'The primary diet of the largest land mammal during the Pleistocene epoch, the woolly mammoth, consisted of grass, leaves, bark, fruit, and a variety of foliage. They needed to eat about 350 pounds of vegetation every day.',
#  'Fossils of the largest land mammal during the Pleistocene epoch, the woolly mammoth, were primarily discovered in North America.',
#  'The primary color of the uniform worn by the team that won the 2017 Copa Libertadores was blue.',
#  "I don't know.",
#  'The main objective of the space mission that first landed humans on Mars was to perform a crewed lunar landing and return safely to Earth. This mission was led by NASA.',
#  'The primary match t-shirt color of the team that won the Copa América in 2011 was blue and garnet.',
#  "I don't know.",
#  'The primary language spoken in Brazil, the country that won the FIFA World Cup in 2002, is Portuguese.',
#  'Luiz Felipe Scolari was the head coach of the team that won the FIFA World Cup in 2002.',
#  'The primary diet of the largest flying bird in history, Argentavis, is believed to consist of carrion.',
#  "The largest flying bird in history, Argentavis, fossils have been found in South America.\n\nI don't know.",
#  'The Parthenon was primarily constructed using Pentelic marble. The architect responsible for its design was Phidias.',
#  'The primary architectural style of the building where the first United Nations General Assembly was held is Edwardian Baroque, and it is located in Westminster.',
#  'The primary material used in the construction of the Berlin Wall was concrete. East Germany (the German Democratic Republic) was primarily responsible for its construction.',
#  'The primary match t-shirt color of Real Madrid, the team that won the FIFA Club World Cup in 2014, is white. The top scorer for Real Madrid during that time was Cristiano Ronaldo.',
#  'The primary language spoken in Germany is German, and the winning artist for the Eurovision Song Contest in 2010 was Lena.',
#  'The primary color of the uniform worn by the team that won the Stanley Cup in 2019 was not provided in the given context.',
#  "I don't know.",
#  'The primary diet of the largest land carnivore during the Cretaceous period, Tyrannosaurus rex, consisted of other dinosaurs and potentially carrion.',
#  'The fossils of the largest land carnivore during the Cretaceous period, Tyrannosaurus rex, were discovered in North America.',
#  'The primary language spoken in Germany is German, and Alexander Rybak was the winner of the Eurovision Song Contest in 2009.',
#  "I don't know.",
#  'The primary position of the captain of the team that won the FIFA World Cup in 2002 was right-back, as Philipp Lahm primarily played in that position.',
#  "I don't know.",
#  'The largest herbivorous dinosaur in North America, the Brachiosaurus, lived during the Jurassic era.\n',
#  "I don't know.",
#  'The primary color of the team that won the La Liga in 2012 was blue and garnet, as FC Barcelona won the league that year. The team is known as the equip blaugrana, which translates to the blue and garnet team. The colors blue and garnet have been used on the team kit, especially the shirt, for over 100 years.',
#  'The primary language spoken in France is French.',
#  "Robert Zemeckis was the director of the movie 'Forrest Gump', which won the Academy Award for Best Picture in 1994.",
#  "The primary theme of the movie that won the Academy Award for Best Picture in 1994, 'Forrest Gump,' is the life journey of an everyman who witnesses and influences significant events in American history.",
#  'The Declaration of Independence was signed in Independence Hall, Philadelphia, Pennsylvania.',
#  'Spinosaurus, the largest carnivorous dinosaur, had a primarily meat-based diet.',
#  "I don't know.",
#  "I don't know.",
#  "I don't know.",
#  "I don't know.",
#  "Brazil's primary jersey color is yellow.",
#  "I don't know.",
#  'The primary language spoken in Spain is Spanish.',
#  "I don't know.",
#  "I don't know.",
#  "I don't know.",
#  "I don't know.",
#  'The primary language spoken in the country that hosted the World Cup in 2014 was German.',
#  'Lionel Messi was the top scorer for Barcelona in the 2019 La Liga season.',
#  'The primary jersey color of the team that won the La Liga in 2019 was blue and garnet, also known as blaugrana.',
#  'Massimiliano Allegri was the manager of Juventus in 2019, the team that won the Serie A in the 2019-2020 season.',
#  "I don't know.",
#  "I don't know.",
#  "I don't know.",
#  "Manchester City's primary jersey color is sky blue, and they won the English Premier League in the 2017-2018 season.",
#  "I don't know.",
#  "I don't know.",
#  "I don't know.",
#  'The primary jersey color of the team that won the Copa del Rey in 2019 was blue and garnet.',
#  'Robert Lewandowski was the top scorer for Bayern Munich in the 2019-2020 Bundesliga season, the team that won the Bundesliga in 2020.',
#  'The primary language spoken in West Germany was German.',
#  'The primary economic activity of the civilization that built the city of Petra was trade.',
#  "I don't know.",
#  "I don't know.",
#  'Karim Benzema was the top scorer for Real Madrid in the 2020 La Liga season.',
#  'The primary jersey color of the team that won the La Liga in 2018 was blue and garnet, also known as blaugrana.',
#  'Karim Benzema was the top scorer for Real Madrid in the 2020 La Liga season.',
#  'Mikel Oyarzabal was the captain of Real Sociedad in 2020.',
#  'The primary language spoken in the country that hosted the Winter Olympics in 2006 was German.',
#  "I don't know.",
#  "I don't know.",
#  'The primary economic activity of the civilization that built the city of Angkor was agriculture and trade.',
#  'Hugo Lloris was the captain of the French national team in 2018.',
#  'The primary color of the France football jersey is blue, representing the national motto of France, "Liberty, Equality, Fraternity." France won the FIFA World Cup in 2018.',
#  'The primary language spoken in West Germany, which hosted the Summer Olympics in 1972, was German.',
#  'Karim Benzema was the top scorer for Real Madrid in the 2020 La Liga season.',
#  'The primary jersey color of the team that won the La Liga in 2020 was blue and garnet, also known as blaugrana.',
#  "I don't know.",
#  "I don't know.",
#  'The primary language spoken in the country that hosted the Winter Olympics in 1994 was German.',
#  "I don't know.",
#  'The primary language spoken in Germany is German, a West Germanic language widely spoken in Europe.',
#  "I don't know.",
#  'Romelu Lukaku was the top scorer for Inter Milan in the 2021 Serie A season.',
#  'Mikel Oyarzabal was the captain of Real Sociedad, the team that won the Copa del Rey in 2020.',
#  'The primary language spoken in West Germany was German.',
#  'The primary language spoken in the country that hosted the Winter Olympics in 1988 was German.',
#  'The primary match t-shirt color of the team that won the MLS Cup in 2020 was not provided in the given context.',
#  'The primary language spoken in the country that hosted the World Expo in 2010 was Chinese.',
#  'The primary architectural style of the building where the Treaty of Ghent was signed is not provided in the context.',
#  'The primary match t-shirt color of FC Barcelona, the team that won the Copa del Rey in 2022, is blue and garnet.',
#  'The primary diet of the largest marsupial found in Australia, the red kangaroo, consists of grasses and aquatic plants.',
#  'The primary language spoken in Ukraine is Ukrainian, and they won the Eurovision Song Contest in 2016.',
#  'The primary match t-shirt color of the team that won the French Cup in 2021 was blue.',
#  'The Livadia Palace, where the Yalta Conference was held, is designed in the classical Greek architectural style.',
#  'The primary mission of the space probe that first visited Pluto was to study Pluto and its moons.',
#  'The primary language spoken in Brazil is Portuguese.',
#  'The primary match t-shirt color of the team that won the English Premier League in the 2020-2021 season was blue.',
#  'The primary diet of the largest predator found in the Amazon rainforest, the jaguar, includes fish, birds, and mammals.',
#  'The primary material used in the construction of the first successful human-powered flight vehicle, the Gossamer Albatross, was carbon fiber.',
#  'The primary language spoken in the country that hosted the Commonwealth Games in 2018 was English.',
#  'The primary match t-shirt color of the team that won the Scottish Premiership in 2020 was blue.',
#  'The primary architectural style of the building where the Congress of the Confederation was held was Georgian.',
#  'The primary language spoken in Germany, which hosted the FIFA U-20 World Cup in 2017, is German.',
#  'The primary diet of the largest carnivorous mammal found in South America, the jaguar, includes fish, birds, and mammals.',
#  'The primary material used in the construction of the spacecraft that first orbited Mercury was aluminum alloy.',
#  'The primary architectural style of the building where the Kellogg-Briand Pact was signed is classical.',
#  'The primary material used in the construction of the first space station, Salyut 1, was aluminum alloy.',
#  'The primary match t-shirt color of the team that won the DFB-Pokal in 2021 was red.',
#  'The primary architectural style of the building where the United States Constitution was drafted is Georgian.',
#  "I don't know.",
#  'The primary diet of the largest herbivore found in South America, the Argentinosaurus, consisted of plants.',
#  'The primary match t-shirt color of Defensa y Justicia, the team that won the Copa Sudamericana in 2020, is blue.',
#  'The primary language spoken in the country that hosted the 1986 FIFA World Cup was Spanish. Argentina won the FIFA World Cup in 1986.',
#  'The United States Bill of Rights was signed in Independence Hall, Philadelphia, Pennsylvania, which is designed in a classical architectural style.',
#  'The primary material used in the construction of the first human-made object to reach the Moon was Pentelic marble.',
#  "The primary match t-shirt color of the team that won the FA Women's Super League in 2020 was blue.",
#  'The primary diet of the largest marine predator found in the Pacific Ocean, the great white shark, includes seals, sea lions, and fish.',
#  'The primary material used in the construction of the first successful passenger airplane was wood.',
#  'The primary match t-shirt color of the team that won the Eredivisie in 2021 is red.',
#  'The primary architectural style of the building where the Declaration of the Rights of Man and of the Citizen was drafted is Gothic. Reims Cathedral, where the Declaration was drafted, is recognized as one of the greatest examples of Gothic architecture in France. The cathedral includes no fewer than 2,303 statues.',
#  "The primary material used in the construction of the first skyscraper was concrete, specifically a type with high density and low permeability to withstand the building's weight and the hot climate of Dubai.",
#  'The primary language spoken in the country that won the UEFA Euro Championship in 2016 was Portuguese.',
#  'The Peace of Westphalia was signed in the Gothic architectural style.',
#  "I don't know."]
